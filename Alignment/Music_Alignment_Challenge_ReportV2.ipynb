# %% [markdown]
# # Music Alignment
#
# In Music Alignment the goal is to match multiple versions of the same musical piece together, e.g. if you have a music performance as a MIDI file and a score in MusicXML, but you can do this with two audio-files, or one audio-file and one symbolic-music file as well. In our case, we perform an alignment of a music performance and the corresponding score in an offline scenario, thus the entire performance and the entire score is given to process and has not to be analysed in real-time when playing.

# %% [markdown]
# The musical performance and the score are given as CSV-files. At first an analysis is performed on the data to conclude the best method for music alignment.

# %% [markdown]
# ## Importing Data
#
# For importing the data, the method `load_dataset()` can be used from the challenge_utils.py file. This external python-file contains this method, which can be used to load an entire directory at once into python. E.g. in our case, we want to load the training-data which is stored in the folder "trainingset". In this folder, there are many subdirectories labelled by the name of the performance and the musical piece, e.g. "Chopin_op10_no3_p01" means, that the piece which is played is No3 of the 10th opus of Chopin and p01 means "performance01". In it, there is the "part"-file, which contains the score. The "ppart"-file (also performance-part) corresponds to the performed piano piece and the "align"-file corresponds to the ground-truth-alignment for training. The "zalign"-file has to be overwritten with our own alignment.
#
# Generally, the data comes from the Vienna 4x22 dataset. This dataset contains 22 different performances of 4 different piano-pieces played by different pianists with different expressiveness (this is the reason for the name 4x22). Therefore, we can conclude, that the symbolic musical notes do not exceed the piano range of 88 keys, which is important for creating the music alignment model.
#
# The import of the dataset with the function `load_dataset()` results in a dictionary, where the keys correspond to the names of the directories in the "trainingset" folder and the values to a tuple with 3 indices. Index 0 corresponds to the performance-csv-file, index 1 to the score-csv-file and index 2 to the ground-truth-alignment. In the following code-cells the numpy-representations are inspected more carefully.

# %%
import challenge_utils as cu

# %%
dataset = cu.load_dataset("trainingset")

# %%
performance_note_array = dataset["Chopin_op10_no3_p01"][0]

# %%
performance_note_array
# Out:
# array([( 4.9925 , 0.8775 , 59, 44, 0, 1, '0'),
#        ( 5.7025 , 2.4375 , 40, 22, 0, 1, '1'),
#        ( 5.70375, 2.43625, 64, 54, 0, 1, '2'),
#        ( 5.77625, 2.36375, 56, 26, 0, 1, '3'),
#        ( 6.4325 , 1.7075 , 47, 20, 0, 1, '4'),
#        ( 6.44625, 1.69375, 59, 37, 0, 1, '5'),
#        ( 6.9725 , 1.1675 , 63, 52, 0, 1, '6'),
#        ( 7.0125 , 1.1275 , 56, 32, 0, 1, '7'),
#        ( 7.47625, 0.66375, 64, 59, 0, 1, '8'),
#        ( 7.5025 , 0.6375 , 59, 41, 0, 1, '9'),
#        ( 7.51875, 0.62125, 47, 26, 0, 1, '10'),
#        ( 8.03375, 4.20625, 66, 58, 0, 1, '11'),
#        ( 8.06875, 2.04125, 35, 30, 0, 1, '12'),
#        ( 8.06875, 4.17125, 63, 41, 0, 1, '13'),
#        ( 8.09   , 0.625  , 57, 32, 0, 1, '14'),
#        ( 8.70375, 1.40625, 47, 31, 0, 1, '15'),
#        ( 8.73125, 1.37875, 59, 36, 0, 1, '16'),
#        ( 9.2075 , 0.9025 , 57, 40, 0, 1, '17'),
#        ( 9.66625, 0.4825 , 47, 30, 0, 1, '18'),
#        ( 9.67   , 0.55375, 59, 44, 0, 1, '19'),
#        (10.1375 , 2.1025 , 57, 39, 0, 1, '20'),
#        (10.14   , 2.1    , 35, 30, 0, 1, '21'),
#        (10.63   , 1.61   , 68, 57, 0, 1, '22'),
#        (10.63375, 1.60625, 59, 44, 0, 1, '23'),
#        (10.6525 , 1.5875 , 47, 31, 0, 1, '24'),
#        (11.09625, 1.14375, 68, 63, 0, 1, '25'),
#        (11.11625, 1.12375, 63, 48, 0, 1, '26'),
#        (11.175  , 1.065  , 57, 11, 0, 1, '27'),
#        (11.56   , 0.68   , 66, 65, 0, 1, '28'),
#        (11.59125, 0.64875, 59, 45, 0, 1, '29'),
#        (11.5975 , 0.6425 , 47, 31, 0, 1, '30'),
#        (12.15875, 4.14125, 68, 61, 0, 1, '31'),
#        (12.18125, 1.98875, 40, 29, 0, 1, '32'),
#        (12.1875 , 2.0675 , 64, 48, 0, 1, '33'),
#        (12.1975 , 1.9725 , 56, 33, 0, 1, '34'),
#        (12.82   , 1.35   , 47, 27, 0, 1, '35'),
#        (12.82125, 1.34875, 59, 38, 0, 1, '36'),
#        (13.30625, 0.86375, 56, 36, 0, 1, '37'),
#        (13.7325 , 0.47125, 47, 25, 0, 1, '38'),
#        (13.73875, 0.48375, 59, 43, 0, 1, '39'),
#        (14.1975 , 2.1025 , 40, 27, 0, 1, '40'),
#        (14.2125 , 2.0875 , 56, 41, 0, 1, '41'),
#        (14.6675 , 1.6325 , 69, 57, 0, 1, '42'),
#        (14.68875, 1.61125, 47, 33, 0, 1, '43'),
#        (14.70875, 1.59125, 64, 42, 0, 1, '44'),
#        (15.125  , 1.175  , 69, 68, 0, 1, '45'),
#        (15.17625, 1.12375, 59, 44, 0, 1, '46'),
#        (15.58375, 0.71625, 68, 72, 0, 1, '47'),
#        (15.62   , 0.68   , 64, 45, 0, 1, '48'),
#        (15.62125, 0.67875, 47, 34, 0, 1, '49'),
#        (16.15625, 2.18375, 73, 71, 0, 1, '50'),
#        (16.18625, 2.15375, 63, 51, 0, 1, '51'),
#        (16.19375, 2.14625, 35, 36, 0, 1, '52'),
#        (16.73625, 1.60375, 47, 34, 0, 1, '53'),
#        (16.755  , 1.585  , 69, 56, 0, 1, '54'),
#        (17.2225 , 1.1175 , 59, 49, 0, 1, '55'),
#        (17.65375, 0.68625, 71, 60, 0, 1, '56'),
#        (17.68375, 0.65625, 63, 44, 0, 1, '57'),
#        (17.6925 , 0.6475 , 47, 34, 0, 1, '58'),
#        (18.18875, 0.61125, 69, 59, 0, 1, '59'),
#        (18.20125, 1.99875, 40, 30, 0, 1, '60'),
#        (18.2225 , 0.445  , 59, 42, 0, 1, '61'),
#        (18.6975 , 0.9125 , 68, 52, 0, 1, '62'),
#        (18.71625, 0.89375, 64, 36, 0, 1, '63'),
#        (18.73   , 0.88   , 47, 11, 0, 1, '64'),
#        (19.1375 , 0.4725 , 63, 53, 0, 1, '65'),
#        (19.18625, 0.42375, 56, 39, 0, 1, '66'),
#        (19.60125, 0.61125, 64, 55, 0, 1, '67'),
#        (19.61875, 0.58125, 59, 39, 0, 1, '68'),
#        (19.63   , 0.57   , 47, 29, 0, 1, '69'),
#        (20.1875 , 2.2675 , 66, 54, 0, 1, '70'),
#        (20.21625, 2.04375, 35, 25, 0, 1, '71'),
#        (20.245  , 0.665  , 61, 34, 0, 1, '72'),
#        (20.25125, 0.65875, 57, 27, 0, 1, '73'),
#        (20.8825 , 0.9375 , 63, 41, 0, 1, '74'),
#        (20.9    , 0.92   , 47, 29, 0, 1, '75'),
#        (20.95625, 0.18875, 59, 17, 0, 1, '76'),
#        (21.3725 , 0.47875, 61, 42, 0, 1, '77'),
#        (21.415  , 0.405  , 57, 30, 0, 1, '78'),
#        (21.8275 , 0.48   , 47, 34, 0, 1, '79'),
#        (21.83375, 0.43625, 63, 41, 0, 1, '80'),
#        (21.865  , 0.395  , 59, 26, 0, 1, '81'),
#        (22.2925 , 2.0575 , 35, 31, 0, 1, '82'),
#        (22.29375, 0.54625, 61, 38, 0, 1, '83'),
#        (22.31625, 0.12125, 57, 31, 0, 1, '84'),
#        (22.82   , 1.53   , 68, 55, 0, 1, '85'),
#        (22.8325 , 1.5175 , 63, 40, 0, 1, '86'),
#        (22.84625, 1.50375, 47, 31, 0, 1, '87'),
#        (22.85375, 0.185  , 59, 34, 0, 1, '88'),
#        (23.28875, 1.06125, 68, 60, 0, 1, '89'),
#        (23.2925 , 1.0575 , 61, 46, 0, 1, '90'),
#        (23.31125, 1.03875, 57, 38, 0, 1, '91'),
#        (23.7525 , 0.5975 , 66, 57, 0, 1, '92'),
#        (23.775  , 0.575  , 59, 42, 0, 1, '93'),
#        (23.78   , 0.57   , 63, 45, 0, 1, '94'),
#        (23.7875 , 0.5625 , 47, 37, 0, 1, '95'),
#        (24.29625, 2.34375, 64, 57, 0, 1, '96'),
#        (24.31875, 2.32125, 40, 28, 0, 1, '97'),
#        (24.36125, 0.50625, 56, 25, 0, 1, '98'),
#        (24.84125, 1.79875, 47, 23, 0, 1, '99'),
#        (24.84375, 1.79625, 59, 37, 0, 1, '100'),
#        (25.29125, 1.34875, 56, 36, 0, 1, '101'),
#        (25.815  , 0.825  , 59, 28, 0, 1, '102'),
#        (25.81625, 0.82375, 47, 26, 0, 1, '103'),
#        (26.4225 , 0.53125, 68, 46, 0, 1, '104'),
#        (26.42625, 1.85375, 40, 28, 0, 1, '105'),
#        (26.45125, 0.4775 , 62, 32, 0, 1, '106'),
#        (26.905  , 1.375  , 69, 50, 0, 1, '107'),
#        (26.9125 , 1.3675 , 52, 35, 0, 1, '108'),
#        (26.9425 , 1.3375 , 64, 40, 0, 1, '109'),
#        (27.31   , 0.97   , 66, 55, 0, 1, '110'),
#        (27.35   , 0.93   , 62, 40, 0, 1, '111'),
#        (27.7375 , 0.5425 , 68, 62, 0, 1, '112'),
#        (27.745  , 0.535  , 52, 39, 0, 1, '113'),
#        (27.78125, 0.49875, 64, 31, 0, 1, '114'),
#        (28.16625, 0.465  , 69, 68, 0, 1, '115'),
#        (28.2025 , 0.45125, 61, 46, 0, 1, '116'),
#        (28.205  , 1.745  , 45, 34, 0, 1, '117'),
#        (28.58125, 1.36875, 71, 70, 0, 1, '118'),
#        (28.59   , 1.36   , 52, 40, 0, 1, '119'),
#        (28.60625, 1.34375, 64, 57, 0, 1, '120'),
#        (28.9825 , 0.9675 , 68, 68, 0, 1, '121'),
#        (28.99375, 0.95625, 61, 61, 0, 1, '122'),
#        (29.395  , 0.555  , 69, 72, 0, 1, '123'),
#        (29.4125 , 0.5375 , 52, 40, 0, 1, '124'),
#        (29.4225 , 0.5275 , 64, 47, 0, 1, '125'),
#        (29.8725 , 1.8875 , 45, 38, 0, 1, '126'),
#        (29.88375, 1.87625, 73, 71, 0, 1, '127'),
#        (29.92125, 0.675  , 61, 45, 0, 1, '128'),
#        (30.42625, 1.33375, 54, 55, 0, 1, '129'),
#        (30.4525 , 1.3075 , 64, 48, 0, 1, '130'),
#        (30.87625, 2.53375, 66, 64, 0, 1, '131'),
#        (30.9425 , 0.8175 , 61, 34, 0, 1, '132'),
#        (31.3075 , 0.45375, 64, 53, 0, 1, '133'),
#        (31.32875, 0.43125, 54, 39, 0, 1, '134'),
#        (31.71125, 1.69875, 59, 55, 0, 1, '135'),
#        (31.72   , 1.73625, 47, 48, 0, 1, '136'),
#        (32.1075 , 1.3025 , 54, 40, 0, 1, '137'),
#        (32.12875, 1.28125, 64, 59, 0, 1, '138'),
#        (32.3875 , 1.0225 , 59, 45, 0, 1, '139'),
#        (32.46125, 0.94875, 70, 63, 0, 1, '140'),
#        (32.52375, 0.88625, 68, 60, 0, 1, '141'),
#        (32.92625, 2.40375, 66, 61, 0, 1, '142'),
#        (32.95375, 0.4825 , 54, 39, 0, 1, '143'),
#        (32.95875, 0.49875, 64, 53, 0, 1, '144'),
#        (33.3925 , 1.9375 , 49, 49, 0, 1, '145'),
#        (33.3975 , 1.9325 , 58, 56, 0, 1, '146'),
#        (33.81625, 1.51375, 64, 58, 0, 1, '147'),
#        (33.83125, 1.49875, 54, 37, 0, 1, '148'),
#        (34.0925 , 1.2375 , 58, 52, 0, 1, '149'),
#        (34.16875, 1.16125, 70, 61, 0, 1, '150'),
#        (34.24625, 1.08375, 68, 65, 0, 1, '151'),
#        (34.7175 , 0.6125 , 66, 55, 0, 1, '152'),
#        (34.735  , 0.595  , 64, 49, 0, 1, '153'),
#        (34.7475 , 0.5825 , 54, 42, 0, 1, '154'),
#        (35.32625, 2.63375, 71, 53, 0, 1, '155'),
#        (35.355  , 0.635  , 63, 38, 0, 1, '156'),
#        (35.36375, 2.59625, 47, 30, 0, 1, '157'),
#        (35.36875, 0.62125, 57, 32, 0, 1, '158'),
#        (35.99875, 1.96125, 59, 37, 0, 1, '159'),
#        (36.01875, 1.94125, 54, 30, 0, 1, '160'),
#        (36.47875, 1.48125, 57, 46, 0, 1, '161'),
#        (37.0475 , 0.9125 , 59, 44, 0, 1, '162'),
#        (37.09875, 0.86125, 54, 12, 0, 1, '163'),
#        (37.84375, 2.27625, 40, 25, 0, 1, '164'),
#        (37.84375, 2.27625, 68, 45, 0, 1, '165'),
#        (37.87875, 0.6675 , 56, 26, 0, 1, '166'),
#        (37.88875, 2.23125, 64, 38, 0, 1, '167'),
#        (38.52125, 1.59875, 47, 24, 0, 1, '168'),
#        (38.53375, 1.58625, 59, 35, 0, 1, '169'),
#        (39.     , 1.12   , 63, 48, 0, 1, '170'),
#        (39.045  , 1.075  , 56, 30, 0, 1, '171'),
#        (39.46125, 0.65875, 64, 53, 0, 1, '172'),
#        (39.46875, 0.65125, 47, 33, 0, 1, '173'),
#        (39.5025 , 0.6175 , 59, 33, 0, 1, '174'),
#        (39.9975 , 4.0525 , 66, 47, 0, 1, '175'),
#        (40.0025 , 1.9375 , 35, 30, 0, 1, '176'),
#        (40.0275 , 4.0225 , 63, 37, 0, 1, '177'),
#        (40.03375, 0.59   , 57, 33, 0, 1, '178'),
#        (40.60375, 1.33625, 47, 33, 0, 1, '179'),
#        (40.62125, 1.31875, 59, 37, 0, 1, '180'),
#        (41.05625, 0.88375, 57, 36, 0, 1, '181'),
#        (41.525  , 0.465  , 59, 40, 0, 1, '182'),
#        (41.53875, 0.42875, 47, 27, 0, 1, '183'),
#        (41.985  , 2.065  , 57, 38, 0, 1, '184'),
#        (42.00375, 2.04625, 35, 25, 0, 1, '185'),
#        (42.48125, 1.56875, 68, 51, 0, 1, '186'),
#        (42.4825 , 1.5675 , 59, 44, 0, 1, '187'),
#        (42.49625, 1.55375, 47, 36, 0, 1, '188'),
#        (42.9425 , 1.1075 , 68, 56, 0, 1, '189'),
#        (42.95375, 1.09625, 63, 45, 0, 1, '190'),
#        (42.98125, 1.06875, 57, 30, 0, 1, '191'),
#        (43.39625, 0.65375, 66, 55, 0, 1, '192'),
#        (43.42   , 0.63   , 47, 32, 0, 1, '193'),
#        (43.435  , 0.615  , 59, 37, 0, 1, '194'),
#        (43.97125, 4.02875, 68, 52, 0, 1, '195'),
#        (43.99375, 1.93625, 40, 24, 0, 1, '196'),
#        (44.00125, 2.06875, 64, 43, 0, 1, '197'),
#        (44.01875, 0.60375, 56, 24, 0, 1, '198'),
#        (44.6075 , 1.3225 , 47, 24, 0, 1, '199'),
#        (44.62   , 1.31   , 59, 35, 0, 1, '200'),
#        (45.06875, 0.86125, 56, 32, 0, 1, '201'),
#        (45.5125 , 0.45   , 47, 28, 0, 1, '202'),
#        (45.51625, 0.43875, 59, 39, 0, 1, '203'),
#        (45.98125, 2.01875, 56, 43, 0, 1, '204'),
#        (45.98375, 2.01625, 40, 28, 0, 1, '205'),
#        (46.435  , 1.565  , 69, 54, 0, 1, '206'),
#        (46.475  , 1.525  , 47, 31, 0, 1, '207'),
#        (46.4825 , 1.5175 , 64, 41, 0, 1, '208'),
#        (46.89625, 1.10375, 69, 65, 0, 1, '209'),
#        (46.95625, 1.04375, 59, 39, 0, 1, '210'),
#        (47.345  , 0.655  , 68, 67, 0, 1, '211'),
#        (47.38375, 0.61625, 47, 35, 0, 1, '212'),
#        (47.39375, 0.60625, 64, 35, 0, 1, '213'),
#        (47.90625, 2.12375, 73, 71, 0, 1, '214'),
#        (47.9375 , 2.0925 , 35, 34, 0, 1, '215'),
#        (47.9425 , 2.0875 , 63, 47, 0, 1, '216'),
#        (48.4825 , 1.5475 , 47, 33, 0, 1, '217'),
#        (48.49625, 1.53375, 69, 59, 0, 1, '218'),
#        (48.94625, 1.08375, 59, 55, 0, 1, '219'),
#        (49.3825 , 0.6475 , 71, 63, 0, 1, '220'),
#        (49.4    , 0.63   , 47, 37, 0, 1, '221'),
#        (49.415  , 0.615  , 63, 40, 0, 1, '222'),
#        (49.89125, 2.01875, 69, 56, 0, 1, '223'),
#        (49.8975 , 2.0125 , 40, 32, 0, 1, '224'),
#        (49.9375 , 0.38625, 59, 39, 0, 1, '225'),
#        (50.38375, 1.52625, 68, 50, 0, 1, '226'),
#        (50.3975 , 1.5125 , 47, 20, 0, 1, '227'),
#        (50.4025 , 1.5075 , 64, 38, 0, 1, '228'),
#        (50.8325 , 1.0775 , 63, 49, 0, 1, '229'),
#        (50.87625, 1.03375, 56, 37, 0, 1, '230'),
#        (51.30625, 0.60375, 47, 32, 0, 1, '231'),
#        (51.3075 , 0.6025 , 64, 58, 0, 1, '232'),
#        (51.32875, 0.58125, 59, 36, 0, 1, '233'),
#        (51.8925 , 2.4675 , 66, 55, 0, 1, '234'),
#        (51.93875, 1.87125, 35, 26, 0, 1, '235'),
#        (51.93875, 0.2625 , 57, 31, 0, 1, '236'),
#        (51.95125, 0.54875, 61, 32, 0, 1, '237'),
#        (52.4925 , 1.3175 , 63, 40, 0, 1, '238'),
#        (52.525  , 1.285  , 47, 27, 0, 1, '239'),
#        (52.5425 , 0.16625, 59, 29, 0, 1, '240'),
#        (52.95   , 0.86   , 61, 44, 0, 1, '241'),
#        (52.98625, 0.82375, 57, 34, 0, 1, '242'),
#        (53.42625, 0.51125, 63, 49, 0, 1, '243'),
#        (53.42875, 0.45375, 47, 34, 0, 1, '244'),
#        (53.4675 , 0.3425 , 59, 24, 0, 1, '245'),
#        (53.87875, 0.50625, 61, 49, 0, 1, '246'),
#        (53.88875, 2.03125, 35, 28, 0, 1, '247'),
#        (53.89375, 0.46625, 57, 40, 0, 1, '248'),
#        (54.3675 , 1.5525 , 68, 62, 0, 1, '249'),
#        (54.4025 , 1.5175 , 47, 31, 0, 1, '250'),
#        (54.40875, 0.1475 , 59, 34, 0, 1, '251'),
#        (54.41375, 1.50625, 63, 30, 0, 1, '252'),
#        (54.82   , 1.1    , 68, 63, 0, 1, '253'),
#        (54.85625, 1.06375, 61, 45, 0, 1, '254'),
#        (54.87125, 1.04875, 57, 22, 0, 1, '255'),
#        (55.28   , 0.64   , 66, 59, 0, 1, '256'),
#        (55.2975 , 0.6225 , 47, 39, 0, 1, '257'),
#        (55.3025 , 0.6175 , 59, 45, 0, 1, '258'),
#        (55.305  , 0.615  , 63, 44, 0, 1, '259'),
#        (55.8475 , 2.0625 , 64, 59, 0, 1, '260'),
#        (55.8925 , 2.0175 , 40, 26, 0, 1, '261'),
#        (55.91   , 0.49125, 56, 29, 0, 1, '262'),
#        (56.3575 , 1.5525 , 59, 40, 0, 1, '263'),
#        (56.35875, 1.55125, 47, 24, 0, 1, '264'),
#        (56.8025 , 1.1075 , 56, 38, 0, 1, '265'),
#        (57.315  , 0.595  , 59, 31, 0, 1, '266'),
#        (57.32375, 0.58625, 47, 27, 0, 1, '267'),
#        (57.89875, 1.90125, 71, 53, 0, 1, '268'),
#        (57.91875, 1.88125, 40, 31, 0, 1, '269'),
#        (57.92625, 1.87375, 66, 31, 0, 1, '270'),
#        (57.9475 , 1.8525 , 62, 31, 0, 1, '271'),
#        (58.46125, 1.33875, 73, 56, 0, 1, '272'),
#        (58.47625, 1.32375, 52, 34, 0, 1, '273'),
#        (58.49   , 1.31   , 68, 43, 0, 1, '274'),
#        (58.5125 , 1.2875 , 64, 38, 0, 1, '275'),
#        (58.885  , 0.915  , 73, 63, 0, 1, '276'),
#        (58.91375, 0.88625, 66, 47, 0, 1, '277'),
#        (58.9175 , 0.8825 , 62, 44, 0, 1, '278'),
#        (59.32875, 0.47125, 71, 64, 0, 1, '279'),
#        (59.33875, 0.46125, 52, 42, 0, 1, '280'),
#        (59.3525 , 0.4475 , 68, 46, 0, 1, '281'),
#        (59.35625, 0.44375, 64, 37, 0, 1, '282'),
#        (59.75375, 1.68625, 69, 62, 0, 1, '283'),
#        (59.76875, 1.67125, 45, 39, 0, 1, '284'),
#        (59.785  , 1.655  , 61, 44, 0, 1, '285'),
#        (60.18375, 1.25625, 52, 39, 0, 1, '286'),
#        (60.1925 , 1.2475 , 71, 67, 0, 1, '287'),
#        (60.21   , 1.23   , 64, 54, 0, 1, '288'),
#        (60.57625, 0.86375, 68, 65, 0, 1, '289'),
#        (60.60125, 0.83875, 61, 56, 0, 1, '290'),
#        (60.99625, 0.44375, 69, 69, 0, 1, '291'),
#        (60.99875, 0.44125, 52, 48, 0, 1, '292'),
#        (61.01125, 0.42875, 64, 56, 0, 1, '293'),
#        (61.42125, 1.79875, 75, 73, 0, 1, '294'),
#        (61.435  , 1.82   , 44, 55, 0, 1, '295'),
#        (61.4375 , 1.7825 , 72, 62, 0, 1, '296'),
#        (61.44375, 1.77625, 66, 55, 0, 1, '297'),
#        (61.93625, 1.28375, 76, 74, 0, 1, '298'),
#        (61.95   , 1.27   , 56, 44, 0, 1, '299'),
#        (61.9625 , 1.2575 , 68, 52, 0, 1, '300'),
#        (62.34375, 0.87625, 76, 71, 0, 1, '301'),
#        (62.3575 , 0.8625 , 70, 60, 0, 1, '302'),
#        (62.3725 , 0.8475 , 66, 52, 0, 1, '303'),
#        (62.745  , 0.475  , 75, 74, 0, 1, '304'),
#        (62.76   , 0.46   , 68, 59, 0, 1, '305'),
#        (62.76375, 0.45625, 56, 52, 0, 1, '306'),
#        (62.765  , 0.455  , 72, 51, 0, 1, '307'),
#        (63.17375, 1.80625, 49, 52, 0, 1, '308'),
#        (63.17625, 1.80375, 73, 75, 0, 1, '309'),
#        (63.1875 , 1.7925 , 64, 62, 0, 1, '310'),
#        (63.6025 , 1.3775 , 75, 76, 0, 1, '311'),
#        (63.605  , 1.375  , 56, 49, 0, 1, '312'),
#        (63.62375, 1.35625, 68, 56, 0, 1, '313'),
#        (64.00375, 0.97625, 72, 72, 0, 1, '314'),
#        (64.025  , 0.955  , 64, 60, 0, 1, '315'),
#        (64.44875, 0.53125, 73, 75, 0, 1, '316'),
#        (64.45125, 0.52875, 56, 57, 0, 1, '317'),
#        (64.45625, 0.52375, 68, 61, 0, 1, '318'),
#        (64.98375, 1.81625, 76, 80, 0, 1, '319'),
#        (64.9975 , 1.8025 , 58, 45, 0, 1, '320'),
#        (65.0025 , 1.7975 , 70, 58, 0, 1, '321'),
#        (65.00375, 1.79625, 64, 61, 0, 1, '322'),
#        (65.01   , 1.79   , 49, 43, 0, 1, '323'),
#        (65.01625, 1.78375, 52, 40, 0, 1, '324'),
#        (65.0175 , 1.7825 , 54, 39, 0, 1, '325'),
#        (65.52375, 1.27625, 78, 78, 0, 1, '326'),
#        (65.53   , 1.27   , 58, 58, 0, 1, '327'),
#        (65.53375, 1.26625, 66, 69, 0, 1, '328'),
#        (65.54625, 1.25375, 54, 45, 0, 1, '329'),
#        (65.55   , 1.25   , 52, 42, 0, 1, '330'),
#        (65.55125, 1.24875, 49, 44, 0, 1, '331'),
#        (65.55875, 1.24125, 70, 57, 0, 1, '332'),
#        (65.9525 , 0.8475 , 58, 68, 0, 1, '333'),
#        (65.95375, 0.84625, 75, 83, 0, 1, '334'),
#        (65.96375, 0.83625, 63, 80, 0, 1, '335'),
#        (65.965  , 0.835  , 49, 58, 0, 1, '336'),
#        (65.9725 , 0.8275 , 54, 51, 0, 1, '337'),
#        (65.98   , 0.82   , 52, 44, 0, 1, '338'),
#        (65.98625, 0.81375, 70, 50, 0, 1, '339'),
#        (66.36125, 0.43875, 58, 67, 0, 1, '340'),
#        (66.3675 , 0.4325 , 76, 87, 0, 1, '341'),
#        (66.37   , 0.43   , 49, 55, 0, 1, '342'),
#        (66.37   , 0.43   , 64, 77, 0, 1, '343'),
#        (66.37375, 0.42625, 70, 61, 0, 1, '344'),
#        (66.3825 , 0.4175 , 54, 53, 0, 1, '345'),
#        (66.3975 , 0.4025 , 52, 42, 0, 1, '346'),
#        (66.8175 , 0.8625 , 78, 85, 0, 1, '347'),
#        (66.81875, 0.86125, 58, 67, 0, 1, '348'),
#        (66.825  , 0.855  , 54, 57, 0, 1, '349'),
#        (66.825  , 0.855  , 66, 75, 0, 1, '350'),
#        (66.8275 , 0.8525 , 70, 73, 0, 1, '351'),
#        (66.83375, 0.84625, 48, 61, 0, 1, '352'),
#        (66.84   , 0.84   , 52, 57, 0, 1, '353'),
#        (67.2825 , 0.3975 , 80, 87, 0, 1, '354'),
#        (67.28375, 0.39625, 58, 68, 0, 1, '355'),
#        (67.29375, 0.38625, 48, 58, 0, 1, '356'),
#        (67.295  , 0.385  , 52, 56, 0, 1, '357'),
#        (67.2975 , 0.3825 , 68, 73, 0, 1, '358'),
#        (67.70875, 0.51125, 76, 87, 0, 1, '359'),
#        (67.71125, 0.50875, 58, 77, 0, 1, '360'),
#        (67.715  , 0.505  , 64, 82, 0, 1, '361'),
#        (67.725  , 0.495  , 48, 65, 0, 1, '362'),
#        (67.725  , 0.495  , 54, 65, 0, 1, '363'),
#        (67.72625, 0.49375, 70, 66, 0, 1, '364'),
#        (67.73625, 0.48375, 52, 57, 0, 1, '365'),
#        (68.2325 , 0.9275 , 58, 75, 0, 1, '366'),
#        (68.2325 , 0.9275 , 78, 87, 0, 1, '367'),
#        (68.23625, 0.92375, 66, 82, 0, 1, '368'),
#        (68.2375 , 0.9225 , 70, 78, 0, 1, '369'),
#        (68.24   , 0.92   , 54, 66, 0, 1, '370'),
#        (68.24375, 0.91625, 48, 66, 0, 1, '371'),
#        (68.26625, 0.89375, 52, 50, 0, 1, '372'),
#        (69.02375, 3.20625, 80, 87, 0, 1, '373'),
#        (69.035  , 0.7725 , 68, 71, 0, 1, '374'),
#        (69.0375 , 4.4825 , 59, 63, 0, 1, '375'),
#        (69.04125, 4.47875, 47, 59, 0, 1, '376'),
#        (69.04125, 4.47875, 56, 56, 0, 1, '377'),
#        (69.04125, 3.18875, 76, 69, 0, 1, '378'),
#        (69.0525 , 4.4675 , 52, 50, 0, 1, '379'),
#        (69.79   , 2.44   , 71, 62, 0, 1, '380'),
#        (70.33625, 1.89375, 68, 56, 0, 1, '381'),
#        (70.80125, 1.42875, 71, 60, 0, 1, '382'),
#        (71.23625, 0.99375, 68, 56, 0, 1, '383'),
#        (71.70375, 0.52625, 78, 67, 0, 1, '384'),
#        (71.735  , 0.495  , 71, 48, 0, 1, '385'),
#        (72.2    , 0.52375, 76, 66, 0, 1, '386'),
#        (72.24125, 0.46875, 68, 40, 0, 1, '387'),
#        (72.7375 , 0.7825 , 73, 53, 0, 1, '388'),
#        (72.74625, 0.77375, 71, 48, 0, 1, '389'),
#        (73.42   , 2.13   , 75, 59, 0, 1, '390'),
#        (73.45875, 0.615  , 63, 45, 0, 1, '391'),
#        (73.47375, 2.07625, 54, 25, 0, 1, '392'),
#        (74.08875, 1.46125, 66, 39, 0, 1, '393'),
#        (74.11   , 1.44   , 59, 28, 0, 1, '394'),
#        (74.58875, 0.96125, 63, 36, 0, 1, '395'),
#        (74.59375, 0.95625, 47, 13, 0, 1, '396'),
#        (75.00125, 0.54875, 66, 46, 0, 1, '397'),
#        (75.03875, 0.51125, 59, 38, 0, 1, '398'),
#        (75.45875, 0.59625, 76, 62, 0, 1, '399'),
#        (75.48375, 0.5    , 64, 46, 0, 1, '400'),
#        (75.48625, 0.5825 , 49, 35, 0, 1, '401'),
#        (75.90625, 0.5475 , 75, 66, 0, 1, '402'),
#        (75.9225 , 0.48375, 68, 50, 0, 1, '403'),
#        (75.95125, 0.4425 , 56, 32, 0, 1, '404'),
#        (76.355  , 1.195  , 73, 62, 0, 1, '405'),
#        (76.37   , 0.45   , 64, 44, 0, 1, '406'),
#        (76.375  , 1.175  , 44, 35, 0, 1, '407'),
#        (76.86375, 0.68625, 68, 52, 0, 1, '408'),
#        (76.865  , 0.685  , 56, 33, 0, 1, '409'),
#        (77.49875, 2.02125, 71, 54, 0, 1, '410'),
#        (77.5    , 2.02   , 51, 31, 0, 1, '411'),
#        (77.545  , 0.925  , 59, 36, 0, 1, '412'),
#        (78.02625, 0.52625, 63, 40, 0, 1, '413'),
#        (78.0425 , 0.4275 , 56, 29, 0, 1, '414'),
#        (78.475  , 1.045  , 44, 30, 0, 1, '415'),
#        (78.49   , 1.03   , 59, 36, 0, 1, '416'),
#        (78.97   , 0.55   , 63, 43, 0, 1, '417'),
#        (78.98375, 0.53625, 56,  7, 0, 1, '418'),
#        (79.51875, 0.54125, 73, 54, 0, 1, '419'),
#        (79.55375, 0.51625, 45, 30, 0, 1, '420'),
#        (79.56375, 0.5125 , 61, 35, 0, 1, '421'),
#        (80.05875, 0.495  , 52, 37, 0, 1, '422'),
#        (80.0625 , 0.49   , 71, 48, 0, 1, '423'),
#        (80.10125, 0.39875, 64, 31, 0, 1, '424'),
#        (80.5125 , 1.1275 , 69, 48, 0, 1, '425'),
#        (80.53125, 1.10875, 40, 32, 0, 1, '426'),
#        (80.54625, 0.41375, 61, 23, 0, 1, '427'),
#        (80.9875 , 0.6525 , 64, 49, 0, 1, '428'),
#        (80.99125, 0.64875, 52, 32, 0, 1, '429'),
#        (81.585  , 4.995  , 68, 46, 0, 1, '430'),
#        (81.61375, 1.28625, 47, 23, 0, 1, '431'),
#        (81.645  , 0.56375, 56, 26, 0, 1, '432'),
#        (82.21375, 0.53625, 52, 19, 0, 1, '433'),
#        (82.235  , 0.5325 , 59, 30, 0, 1, '434'),
#        (82.71375, 1.07375, 40, 23, 0, 1, '435'),
#        (82.745  , 0.985  , 56, 15, 0, 1, '436'),
#        (83.19   , 0.58875, 52, 31, 0, 1, '437'),
#        (83.215  , 0.55125, 59, 34, 0, 1, '438'),
#        (83.70125, 1.1975 , 47, 28, 0, 1, '439'),
#        (83.72   , 1.06   , 56, 25, 0, 1, '440'),
#        (84.2025 , 0.65625, 59, 27, 0, 1, '441'),
#        (84.2475 , 0.5325 , 52, 19, 0, 1, '442'),
#        (84.7675 , 1.8125 , 56, 23, 0, 1, '443'),
#        (84.77125, 4.00875, 40, 22, 0, 1, '444'),
#        (85.44375, 1.13625, 59, 30, 0, 1, '445'),
#        (85.44875, 3.33125, 47, 18, 0, 1, '446'),
#        (86.41625, 0.35625, 68, 38, 0, 1, '447'),
#        (86.475  , 2.305  , 56, 28, 0, 1, '449'),
#        (86.6425 , 0.32   , 66, 44, 0, 1, '450'),
#        (86.88125, 1.89875, 64, 40, 0, 1, '451')],
#       dtype=[('onset_sec', '<f4'), ('duration_sec', '<f4'), ('pitch', '<i4'), ('velocity', '<i4'), ('track', '<i4'), ('channel', '<i4'), ('id', '<U256')])

# %%
score_note_array = dataset["Chopin_op10_no3_p01"][1]

# %%
score_note_array
# Out:
# array([(-0.5 , 0.5 , -0.5 , 0.5 ,   0,  8, 59, 1, 'n1', '16'),
#        ( 0.  , 1.  ,  0.  , 1.  ,   8, 16, 40, 7, 'n4', '16'),
#        ( 0.  , 0.25,  0.  , 0.25,   8,  4, 56, 3, 'n3', '16'),
#        ( 0.  , 0.5 ,  0.  , 0.5 ,   8,  8, 64, 1, 'n2', '16'),
#        ( 0.25, 0.5 ,  0.25, 0.5 ,  12,  8, 47, 4, 'n6', '16'),
#        ( 0.25, 0.25,  0.25, 0.25,  12,  4, 59, 3, 'n5', '16'),
#        ( 0.5 , 0.25,  0.5 , 0.25,  16,  4, 56, 3, 'n8', '16'),
#        ( 0.5 , 0.25,  0.5 , 0.25,  16,  4, 63, 1, 'n7', '16'),
#        ( 0.75, 0.25,  0.75, 0.25,  20,  4, 47, 4, 'n11', '16'),
#        ( 0.75, 0.25,  0.75, 0.25,  20,  4, 59, 3, 'n10', '16'),
#        ( 0.75, 0.25,  0.75, 0.25,  20,  4, 64, 1, 'n9', '16'),
#        ( 1.  , 1.  ,  1.  , 1.  ,  24, 16, 35, 7, 'n15', '16'),
#        ( 1.  , 0.25,  1.  , 0.25,  24,  4, 57, 3, 'n14', '16'),
#        ( 1.  , 1.5 ,  1.  , 1.5 ,  24, 24, 63, 2, 'n13', '16'),
#        ( 1.  , 1.25,  1.  , 1.25,  24, 20, 66, 1, 'n12', '16'),
#        ( 1.25, 0.5 ,  1.25, 0.5 ,  28,  8, 47, 4, 'n17', '16'),
#        ( 1.25, 0.25,  1.25, 0.25,  28,  4, 59, 3, 'n16', '16'),
#        ( 1.5 , 0.25,  1.5 , 0.25,  32,  4, 57, 3, 'n18', '16'),
#        ( 1.75, 0.25,  1.75, 0.25,  36,  4, 47, 4, 'n20', '16'),
#        ( 1.75, 0.25,  1.75, 0.25,  36,  4, 59, 3, 'n19', '16'),
#        ( 2.  , 1.  ,  2.  , 1.  ,  40, 16, 35, 7, 'n22', '16'),
#        ( 2.  , 0.25,  2.  , 0.25,  40,  4, 57, 3, 'n21', '16'),
#        ( 2.25, 0.5 ,  2.25, 0.5 ,  44,  8, 47, 4, 'n25', '16'),
#        ( 2.25, 0.25,  2.25, 0.25,  44,  4, 59, 3, 'n24', '16'),
#        ( 2.25, 0.25,  2.25, 0.25,  44,  4, 68, 1, 'n23', '16'),
#        ( 2.5 , 0.25,  2.5 , 0.25,  48,  4, 57, 3, 'n28', '16'),
#        ( 2.5 , 0.5 ,  2.5 , 0.5 ,  48,  8, 63, 2, 'n27', '16'),
#        ( 2.5 , 0.25,  2.5 , 0.25,  48,  4, 68, 1, 'n26', '16'),
#        ( 2.75, 0.25,  2.75, 0.25,  52,  4, 47, 4, 'n31', '16'),
#        ( 2.75, 0.25,  2.75, 0.25,  52,  4, 59, 3, 'n30', '16'),
#        ( 2.75, 0.25,  2.75, 0.25,  52,  4, 66, 1, 'n29', '16'),
#        ( 3.  , 1.  ,  3.  , 1.  ,  56, 16, 40, 7, 'n35', '16'),
#        ( 3.  , 0.25,  3.  , 0.25,  56,  4, 56, 3, 'n34', '16'),
#        ( 3.  , 1.  ,  3.  , 1.  ,  56, 16, 64, 2, 'n33', '16'),
#        ( 3.  , 1.25,  3.  , 1.25,  56, 20, 68, 1, 'n32', '16'),
#        ( 3.25, 0.5 ,  3.25, 0.5 ,  60,  8, 47, 4, 'n37', '16'),
#        ( 3.25, 0.25,  3.25, 0.25,  60,  4, 59, 3, 'n36', '16'),
#        ( 3.5 , 0.25,  3.5 , 0.25,  64,  4, 56, 3, 'n38', '16'),
#        ( 3.75, 0.25,  3.75, 0.25,  68,  4, 47, 4, 'n40', '16'),
#        ( 3.75, 0.25,  3.75, 0.25,  68,  4, 59, 3, 'n39', '16'),
#        ( 4.  , 1.  ,  4.  , 1.  ,  72, 16, 40, 7, 'n42', '16'),
#        ( 4.  , 0.25,  4.  , 0.25,  72,  4, 56, 3, 'n41', '16'),
#        ( 4.25, 0.5 ,  4.25, 0.5 ,  76,  8, 47, 4, 'n45', '16'),
#        ( 4.25, 0.25,  4.25, 0.25,  76,  4, 64, 3, 'n44', '16'),
#        ( 4.25, 0.25,  4.25, 0.25,  76,  4, 69, 1, 'n43', '16'),
#        ( 4.5 , 0.25,  4.5 , 0.25,  80,  4, 59, 3, 'n47', '16'),
#        ( 4.5 , 0.25,  4.5 , 0.25,  80,  4, 69, 1, 'n46', '16'),
#        ( 4.75, 0.25,  4.75, 0.25,  84,  4, 47, 4, 'n50', '16'),
#        ( 4.75, 0.25,  4.75, 0.25,  84,  4, 64, 3, 'n49', '16'),
#        ( 4.75, 0.25,  4.75, 0.25,  84,  4, 68, 1, 'n48', '16'),
#        ( 5.  , 1.  ,  5.  , 1.  ,  88, 16, 35, 7, 'n53', '16'),
#        ( 5.  , 0.25,  5.  , 0.25,  88,  4, 63, 3, 'n52', '16'),
#        ( 5.  , 0.75,  5.  , 0.75,  88, 12, 73, 1, 'n51', '16'),
#        ( 5.25, 0.5 ,  5.25, 0.5 ,  92,  8, 47, 4, 'n55', '16'),
#        ( 5.25, 0.25,  5.25, 0.25,  92,  4, 69, 3, 'n54', '16'),
#        ( 5.5 , 0.25,  5.5 , 0.25,  96,  4, 59, 3, 'n56', '16'),
#        ( 5.75, 0.25,  5.75, 0.25, 100,  4, 47, 4, 'n59', '16'),
#        ( 5.75, 0.25,  5.75, 0.25, 100,  4, 63, 3, 'n58', '16'),
#        ( 5.75, 0.25,  5.75, 0.25, 100,  4, 71, 1, 'n57', '16'),
#        ( 6.  , 1.  ,  6.  , 1.  , 104, 16, 40, 7, 'n62', '16'),
#        ( 6.  , 0.25,  6.  , 0.25, 104,  4, 59, 3, 'n61', '16'),
#        ( 6.  , 0.25,  6.  , 0.25, 104,  4, 69, 1, 'n60', '16'),
#        ( 6.25, 0.5 ,  6.25, 0.5 , 108,  8, 47, 4, 'n65', '16'),
#        ( 6.25, 0.25,  6.25, 0.25, 108,  4, 64, 3, 'n64', '16'),
#        ( 6.25, 0.25,  6.25, 0.25, 108,  4, 68, 1, 'n63', '16'),
#        ( 6.5 , 0.25,  6.5 , 0.25, 112,  4, 56, 3, 'n67', '16'),
#        ( 6.5 , 0.25,  6.5 , 0.25, 112,  4, 63, 1, 'n66', '16'),
#        ( 6.75, 0.25,  6.75, 0.25, 116,  4, 47, 4, 'n70', '16'),
#        ( 6.75, 0.25,  6.75, 0.25, 116,  4, 59, 3, 'n69', '16'),
#        ( 6.75, 0.25,  6.75, 0.25, 116,  4, 64, 1, 'n68', '16'),
#        ( 7.  , 1.  ,  7.  , 1.  , 120, 16, 35, 7, 'n74', '16'),
#        ( 7.  , 0.25,  7.  , 0.25, 120,  4, 57, 3, 'n73', '16'),
#        ( 7.  , 0.25,  7.  , 0.25, 120,  4, 61, 2, 'n72', '16'),
#        ( 7.  , 1.25,  7.  , 1.25, 120, 20, 66, 1, 'n71', '16'),
#        ( 7.25, 0.5 ,  7.25, 0.5 , 124,  8, 47, 4, 'n77', '16'),
#        ( 7.25, 0.25,  7.25, 0.25, 124,  4, 59, 3, 'n76', '16'),
#        ( 7.25, 0.25,  7.25, 0.25, 124,  4, 63, 2, 'n75', '16'),
#        ( 7.5 , 0.25,  7.5 , 0.25, 128,  4, 57, 3, 'n79', '16'),
#        ( 7.5 , 0.25,  7.5 , 0.25, 128,  4, 61, 2, 'n78', '16'),
#        ( 7.75, 0.25,  7.75, 0.25, 132,  4, 47, 4, 'n82', '16'),
#        ( 7.75, 0.25,  7.75, 0.25, 132,  4, 59, 3, 'n81', '16'),
#        ( 7.75, 0.25,  7.75, 0.25, 132,  4, 63, 2, 'n80', '16'),
#        ( 8.  , 1.  ,  8.  , 1.  , 136, 16, 35, 7, 'n85', '16'),
#        ( 8.  , 0.25,  8.  , 0.25, 136,  4, 57, 3, 'n84', '16'),
#        ( 8.  , 0.25,  8.  , 0.25, 136,  4, 61, 2, 'n83', '16'),
#        ( 8.25, 0.5 ,  8.25, 0.5 , 140,  8, 47, 4, 'n89', '16'),
#        ( 8.25, 0.25,  8.25, 0.25, 140,  4, 59, 3, 'n88', '16'),
#        ( 8.25, 0.25,  8.25, 0.25, 140,  4, 63, 2, 'n87', '16'),
#        ( 8.25, 0.25,  8.25, 0.25, 140,  4, 68, 1, 'n86', '16'),
#        ( 8.5 , 0.25,  8.5 , 0.25, 144,  4, 57, 3, 'n92', '16'),
#        ( 8.5 , 0.25,  8.5 , 0.25, 144,  4, 61, 2, 'n91', '16'),
#        ( 8.5 , 0.25,  8.5 , 0.25, 144,  4, 68, 1, 'n90', '16'),
#        ( 8.75, 0.25,  8.75, 0.25, 148,  4, 47, 4, 'n96', '16'),
#        ( 8.75, 0.25,  8.75, 0.25, 148,  4, 59, 3, 'n95', '16'),
#        ( 8.75, 0.25,  8.75, 0.25, 148,  4, 63, 2, 'n94', '16'),
#        ( 8.75, 0.25,  8.75, 0.25, 148,  4, 66, 1, 'n93', '16'),
#        ( 9.  , 1.  ,  9.  , 1.  , 152, 16, 40, 7, 'n99', '16'),
#        ( 9.  , 0.25,  9.  , 0.25, 152,  4, 56, 3, 'n98', '16'),
#        ( 9.  , 1.  ,  9.  , 1.  , 152, 16, 64, 1, 'n97', '16'),
#        ( 9.25, 0.5 ,  9.25, 0.5 , 156,  8, 47, 4, 'n101', '16'),
#        ( 9.25, 0.25,  9.25, 0.25, 156,  4, 59, 3, 'n100', '16'),
#        ( 9.5 , 0.25,  9.5 , 0.25, 160,  4, 56, 3, 'n102', '16'),
#        ( 9.75, 0.25,  9.75, 0.25, 164,  4, 47, 4, 'n104', '16'),
#        ( 9.75, 0.25,  9.75, 0.25, 164,  4, 59, 3, 'n103', '16'),
#        (10.  , 1.  , 10.  , 1.  , 168, 16, 40, 7, 'n107', '16'),
#        (10.  , 0.25, 10.  , 0.25, 168,  4, 62, 3, 'n106', '16'),
#        (10.  , 0.25, 10.  , 0.25, 168,  4, 68, 1, 'n105', '16'),
#        (10.25, 0.5 , 10.25, 0.5 , 172,  8, 52, 4, 'n110', '16'),
#        (10.25, 0.25, 10.25, 0.25, 172,  4, 64, 3, 'n109', '16'),
#        (10.25, 0.25, 10.25, 0.25, 172,  4, 69, 1, 'n108', '16'),
#        (10.5 , 0.25, 10.5 , 0.25, 176,  4, 62, 3, 'n112', '16'),
#        (10.5 , 0.25, 10.5 , 0.25, 176,  4, 66, 1, 'n111', '16'),
#        (10.75, 0.25, 10.75, 0.25, 180,  4, 52, 4, 'n115', '16'),
#        (10.75, 0.25, 10.75, 0.25, 180,  4, 64, 3, 'n114', '16'),
#        (10.75, 0.25, 10.75, 0.25, 180,  4, 68, 1, 'n113', '16'),
#        (11.  , 1.  , 11.  , 1.  , 184, 16, 45, 7, 'n118', '16'),
#        (11.  , 0.25, 11.  , 0.25, 184,  4, 61, 3, 'n117', '16'),
#        (11.  , 0.25, 11.  , 0.25, 184,  4, 69, 1, 'n116', '16'),
#        (11.25, 0.5 , 11.25, 0.5 , 188,  8, 52, 4, 'n121', '16'),
#        (11.25, 0.25, 11.25, 0.25, 188,  4, 64, 3, 'n120', '16'),
#        (11.25, 0.25, 11.25, 0.25, 188,  4, 71, 1, 'n119', '16'),
#        (11.5 , 0.25, 11.5 , 0.25, 192,  4, 61, 3, 'n123', '16'),
#        (11.5 , 0.25, 11.5 , 0.25, 192,  4, 68, 1, 'n122', '16'),
#        (11.75, 0.25, 11.75, 0.25, 196,  4, 52, 4, 'n126', '16'),
#        (11.75, 0.25, 11.75, 0.25, 196,  4, 64, 3, 'n125', '16'),
#        (11.75, 0.25, 11.75, 0.25, 196,  4, 69, 1, 'n124', '16'),
#        (12.  , 1.  , 12.  , 1.  , 200, 16, 45, 7, 'n129', '16'),
#        (12.  , 0.25, 12.  , 0.25, 200,  4, 61, 3, 'n128', '16'),
#        (12.  , 0.5 , 12.  , 0.5 , 200,  8, 73, 1, 'n127', '16'),
#        (12.25, 0.5 , 12.25, 0.5 , 204,  8, 54, 4, 'n131', '16'),
#        (12.25, 0.25, 12.25, 0.25, 204,  4, 64, 3, 'n130', '16'),
#        (12.5 , 0.25, 12.5 , 0.25, 208,  4, 61, 3, 'n133', '16'),
#        (12.5 , 1.  , 12.5 , 1.  , 208, 16, 66, 1, 'n132', '16'),
#        (12.75, 0.25, 12.75, 0.25, 212,  4, 54, 4, 'n135', '16'),
#        (12.75, 0.25, 12.75, 0.25, 212,  4, 64, 3, 'n134', '16'),
#        (13.  , 1.  , 13.  , 1.  , 216, 16, 47, 7, 'n137', '16'),
#        (13.  , 0.25, 13.  , 0.25, 216,  4, 59, 3, 'n136', '16'),
#        (13.25, 0.5 , 13.25, 0.5 , 220,  8, 54, 4, 'n139', '16'),
#        (13.25, 0.25, 13.25, 0.25, 220,  4, 64, 3, 'n138', '16'),
#        (13.5 , 0.25, 13.5 , 0.25, 224,  4, 59, 3, 'n142', '16'),
#        (13.5 , 0.25, 13.5 , 0.25, 224,  4, 68, 1, 'n141', '16'),
#        (13.5 , 0.  , 13.5 , 0.  , 224,  0, 70, 1, 'n140', '16'),
#        (13.75, 0.25, 13.75, 0.25, 228,  4, 54, 4, 'n145', '16'),
#        (13.75, 0.25, 13.75, 0.25, 228,  4, 64, 3, 'n144', '16'),
#        (13.75, 0.75, 13.75, 0.75, 228, 12, 66, 1, 'n143', '16'),
#        (14.  , 1.  , 14.  , 1.  , 232, 16, 49, 7, 'n147', '16'),
#        (14.  , 0.25, 14.  , 0.25, 232,  4, 58, 3, 'n146', '16'),
#        (14.25, 0.5 , 14.25, 0.5 , 236,  8, 54, 4, 'n149', '16'),
#        (14.25, 0.25, 14.25, 0.25, 236,  4, 64, 3, 'n148', '16'),
#        (14.5 , 0.25, 14.5 , 0.25, 240,  4, 58, 3, 'n152', '16'),
#        (14.5 , 0.25, 14.5 , 0.25, 240,  4, 68, 1, 'n151', '16'),
#        (14.5 , 0.  , 14.5 , 0.  , 240,  0, 70, 1, 'n150', '16'),
#        (14.75, 0.25, 14.75, 0.25, 244,  4, 54, 4, 'n155', '16'),
#        (14.75, 0.25, 14.75, 0.25, 244,  4, 64, 3, 'n154', '16'),
#        (14.75, 0.25, 14.75, 0.25, 244,  4, 66, 1, 'n153', '16'),
#        (15.  , 1.  , 15.  , 1.  , 248, 16, 47, 7, 'n159', '16'),
#        (15.  , 0.25, 15.  , 0.25, 248,  4, 57, 3, 'n158', '16'),
#        (15.  , 1.  , 15.  , 1.  , 248, 16, 63, 2, 'n157', '16'),
#        (15.  , 1.  , 15.  , 1.  , 248, 16, 71, 1, 'n156', '16'),
#        (15.25, 0.5 , 15.25, 0.5 , 252,  8, 54, 4, 'n161', '16'),
#        (15.25, 0.25, 15.25, 0.25, 252,  4, 59, 3, 'n160', '16'),
#        (15.5 , 0.25, 15.5 , 0.25, 256,  4, 57, 3, 'n162', '16'),
#        (15.75, 0.25, 15.75, 0.25, 260,  4, 54, 4, 'n164', '16'),
#        (15.75, 0.25, 15.75, 0.25, 260,  4, 59, 3, 'n163', '16'),
#        (16.  , 1.  , 16.  , 1.  , 264, 16, 40, 7, 'n168', '16'),
#        (16.  , 0.25, 16.  , 0.25, 264,  4, 56, 3, 'n167', '16'),
#        (16.  , 0.5 , 16.  , 0.5 , 264,  8, 64, 2, 'n166', '16'),
#        (16.  , 0.5 , 16.  , 0.5 , 264,  8, 68, 1, 'n165', '16'),
#        (16.25, 0.5 , 16.25, 0.5 , 268,  8, 47, 4, 'n170', '16'),
#        (16.25, 0.25, 16.25, 0.25, 268,  4, 59, 3, 'n169', '16'),
#        (16.5 , 0.25, 16.5 , 0.25, 272,  4, 56, 3, 'n172', '16'),
#        (16.5 , 0.25, 16.5 , 0.25, 272,  4, 63, 1, 'n171', '16'),
#        (16.75, 0.25, 16.75, 0.25, 276,  4, 47, 4, 'n175', '16'),
#        (16.75, 0.25, 16.75, 0.25, 276,  4, 59, 3, 'n174', '16'),
#        (16.75, 0.25, 16.75, 0.25, 276,  4, 64, 1, 'n173', '16'),
#        (17.  , 1.  , 17.  , 1.  , 280, 16, 35, 7, 'n179', '16'),
#        (17.  , 0.25, 17.  , 0.25, 280,  4, 57, 3, 'n178', '16'),
#        (17.  , 1.5 , 17.  , 1.5 , 280, 24, 63, 2, 'n177', '16'),
#        (17.  , 1.25, 17.  , 1.25, 280, 20, 66, 1, 'n176', '16'),
#        (17.25, 0.5 , 17.25, 0.5 , 284,  8, 47, 4, 'n181', '16'),
#        (17.25, 0.25, 17.25, 0.25, 284,  4, 59, 3, 'n180', '16'),
#        (17.5 , 0.25, 17.5 , 0.25, 288,  4, 57, 3, 'n182', '16'),
#        (17.75, 0.25, 17.75, 0.25, 292,  4, 47, 4, 'n184', '16'),
#        (17.75, 0.25, 17.75, 0.25, 292,  4, 59, 3, 'n183', '16'),
#        (18.  , 1.  , 18.  , 1.  , 296, 16, 35, 7, 'n186', '16'),
#        (18.  , 0.25, 18.  , 0.25, 296,  4, 57, 3, 'n185', '16'),
#        (18.25, 0.5 , 18.25, 0.5 , 300,  8, 47, 4, 'n189', '16'),
#        (18.25, 0.25, 18.25, 0.25, 300,  4, 59, 3, 'n188', '16'),
#        (18.25, 0.25, 18.25, 0.25, 300,  4, 68, 1, 'n187', '16'),
#        (18.5 , 0.25, 18.5 , 0.25, 304,  4, 57, 3, 'n192', '16'),
#        (18.5 , 0.5 , 18.5 , 0.5 , 304,  8, 63, 2, 'n191', '16'),
#        (18.5 , 0.25, 18.5 , 0.25, 304,  4, 68, 1, 'n190', '16'),
#        (18.75, 0.25, 18.75, 0.25, 308,  4, 47, 4, 'n195', '16'),
#        (18.75, 0.25, 18.75, 0.25, 308,  4, 59, 3, 'n194', '16'),
#        (18.75, 0.25, 18.75, 0.25, 308,  4, 66, 1, 'n193', '16'),
#        (19.  , 1.  , 19.  , 1.  , 312, 16, 40, 7, 'n199', '16'),
#        (19.  , 0.25, 19.  , 0.25, 312,  4, 56, 3, 'n198', '16'),
#        (19.  , 1.  , 19.  , 1.  , 312, 16, 64, 2, 'n197', '16'),
#        (19.  , 1.25, 19.  , 1.25, 312, 20, 68, 1, 'n196', '16'),
#        (19.25, 0.5 , 19.25, 0.5 , 316,  8, 47, 4, 'n201', '16'),
#        (19.25, 0.25, 19.25, 0.25, 316,  4, 59, 3, 'n200', '16'),
#        (19.5 , 0.25, 19.5 , 0.25, 320,  4, 56, 3, 'n202', '16'),
#        (19.75, 0.25, 19.75, 0.25, 324,  4, 47, 4, 'n204', '16'),
#        (19.75, 0.25, 19.75, 0.25, 324,  4, 59, 3, 'n203', '16'),
#        (20.  , 1.  , 20.  , 1.  , 328, 16, 40, 7, 'n206', '16'),
#        (20.  , 0.25, 20.  , 0.25, 328,  4, 56, 3, 'n205', '16'),
#        (20.25, 0.5 , 20.25, 0.5 , 332,  8, 47, 4, 'n209', '16'),
#        (20.25, 0.25, 20.25, 0.25, 332,  4, 64, 3, 'n208', '16'),
#        (20.25, 0.25, 20.25, 0.25, 332,  4, 69, 1, 'n207', '16'),
#        (20.5 , 0.25, 20.5 , 0.25, 336,  4, 59, 3, 'n211', '16'),
#        (20.5 , 0.25, 20.5 , 0.25, 336,  4, 69, 1, 'n210', '16'),
#        (20.75, 0.25, 20.75, 0.25, 340,  4, 47, 4, 'n214', '16'),
#        (20.75, 0.25, 20.75, 0.25, 340,  4, 64, 3, 'n213', '16'),
#        (20.75, 0.25, 20.75, 0.25, 340,  4, 68, 1, 'n212', '16'),
#        (21.  , 1.  , 21.  , 1.  , 344, 16, 35, 7, 'n217', '16'),
#        (21.  , 0.25, 21.  , 0.25, 344,  4, 63, 3, 'n216', '16'),
#        (21.  , 0.75, 21.  , 0.75, 344, 12, 73, 1, 'n215', '16'),
#        (21.25, 0.5 , 21.25, 0.5 , 348,  8, 47, 4, 'n219', '16'),
#        (21.25, 0.25, 21.25, 0.25, 348,  4, 69, 3, 'n218', '16'),
#        (21.5 , 0.25, 21.5 , 0.25, 352,  4, 59, 3, 'n220', '16'),
#        (21.75, 0.25, 21.75, 0.25, 356,  4, 47, 4, 'n223', '16'),
#        (21.75, 0.25, 21.75, 0.25, 356,  4, 63, 3, 'n222', '16'),
#        (21.75, 0.25, 21.75, 0.25, 356,  4, 71, 1, 'n221', '16'),
#        (22.  , 1.  , 22.  , 1.  , 360, 16, 40, 7, 'n226', '16'),
#        (22.  , 0.25, 22.  , 0.25, 360,  4, 59, 3, 'n225', '16'),
#        (22.  , 0.25, 22.  , 0.25, 360,  4, 69, 1, 'n224', '16'),
#        (22.25, 0.5 , 22.25, 0.5 , 364,  8, 47, 4, 'n229', '16'),
#        (22.25, 0.25, 22.25, 0.25, 364,  4, 64, 3, 'n228', '16'),
#        (22.25, 0.25, 22.25, 0.25, 364,  4, 68, 1, 'n227', '16'),
#        (22.5 , 0.25, 22.5 , 0.25, 368,  4, 56, 3, 'n231', '16'),
#        (22.5 , 0.25, 22.5 , 0.25, 368,  4, 63, 1, 'n230', '16'),
#        (22.75, 0.25, 22.75, 0.25, 372,  4, 47, 4, 'n234', '16'),
#        (22.75, 0.25, 22.75, 0.25, 372,  4, 59, 3, 'n233', '16'),
#        (22.75, 0.25, 22.75, 0.25, 372,  4, 64, 1, 'n232', '16'),
#        (23.  , 1.  , 23.  , 1.  , 376, 16, 35, 7, 'n238', '16'),
#        (23.  , 0.25, 23.  , 0.25, 376,  4, 57, 3, 'n237', '16'),
#        (23.  , 0.25, 23.  , 0.25, 376,  4, 61, 2, 'n236', '16'),
#        (23.  , 1.25, 23.  , 1.25, 376, 20, 66, 1, 'n235', '16'),
#        (23.25, 0.5 , 23.25, 0.5 , 380,  8, 47, 4, 'n241', '16'),
#        (23.25, 0.25, 23.25, 0.25, 380,  4, 59, 3, 'n240', '16'),
#        (23.25, 0.25, 23.25, 0.25, 380,  4, 63, 2, 'n239', '16'),
#        (23.5 , 0.25, 23.5 , 0.25, 384,  4, 57, 3, 'n243', '16'),
#        (23.5 , 0.25, 23.5 , 0.25, 384,  4, 61, 2, 'n242', '16'),
#        (23.75, 0.25, 23.75, 0.25, 388,  4, 47, 4, 'n246', '16'),
#        (23.75, 0.25, 23.75, 0.25, 388,  4, 59, 3, 'n245', '16'),
#        (23.75, 0.25, 23.75, 0.25, 388,  4, 63, 2, 'n244', '16'),
#        (24.  , 1.  , 24.  , 1.  , 392, 16, 35, 7, 'n249', '16'),
#        (24.  , 0.25, 24.  , 0.25, 392,  4, 57, 3, 'n248', '16'),
#        (24.  , 0.25, 24.  , 0.25, 392,  4, 61, 2, 'n247', '16'),
#        (24.25, 0.5 , 24.25, 0.5 , 396,  8, 47, 4, 'n253', '16'),
#        (24.25, 0.25, 24.25, 0.25, 396,  4, 59, 3, 'n252', '16'),
#        (24.25, 0.25, 24.25, 0.25, 396,  4, 63, 2, 'n251', '16'),
#        (24.25, 0.25, 24.25, 0.25, 396,  4, 68, 1, 'n250', '16'),
#        (24.5 , 0.25, 24.5 , 0.25, 400,  4, 57, 3, 'n256', '16'),
#        (24.5 , 0.25, 24.5 , 0.25, 400,  4, 61, 2, 'n255', '16'),
#        (24.5 , 0.25, 24.5 , 0.25, 400,  4, 68, 1, 'n254', '16'),
#        (24.75, 0.25, 24.75, 0.25, 404,  4, 47, 4, 'n260', '16'),
#        (24.75, 0.25, 24.75, 0.25, 404,  4, 59, 3, 'n259', '16'),
#        (24.75, 0.25, 24.75, 0.25, 404,  4, 63, 2, 'n258', '16'),
#        (24.75, 0.25, 24.75, 0.25, 404,  4, 66, 1, 'n257', '16'),
#        (25.  , 1.  , 25.  , 1.  , 408, 16, 40, 7, 'n263', '16'),
#        (25.  , 0.25, 25.  , 0.25, 408,  4, 56, 3, 'n262', '16'),
#        (25.  , 1.  , 25.  , 1.  , 408, 16, 64, 1, 'n261', '16'),
#        (25.25, 0.5 , 25.25, 0.5 , 412,  8, 47, 4, 'n265', '16'),
#        (25.25, 0.25, 25.25, 0.25, 412,  4, 59, 3, 'n264', '16'),
#        (25.5 , 0.25, 25.5 , 0.25, 416,  4, 56, 3, 'n266', '16'),
#        (25.75, 0.25, 25.75, 0.25, 420,  4, 47, 4, 'n268', '16'),
#        (25.75, 0.25, 25.75, 0.25, 420,  4, 59, 3, 'n267', '16'),
#        (26.  , 1.  , 26.  , 1.  , 424, 16, 40, 7, 'n272', '16'),
#        (26.  , 0.25, 26.  , 0.25, 424,  4, 62, 3, 'n271', '16'),
#        (26.  , 0.25, 26.  , 0.25, 424,  4, 66, 2, 'n270', '16'),
#        (26.  , 0.25, 26.  , 0.25, 424,  4, 71, 1, 'n269', '16'),
#        (26.25, 0.5 , 26.25, 0.5 , 428,  8, 52, 4, 'n276', '16'),
#        (26.25, 0.25, 26.25, 0.25, 428,  4, 64, 3, 'n275', '16'),
#        (26.25, 0.25, 26.25, 0.25, 428,  4, 68, 2, 'n274', '16'),
#        (26.25, 0.25, 26.25, 0.25, 428,  4, 73, 1, 'n273', '16'),
#        (26.5 , 0.25, 26.5 , 0.25, 432,  4, 62, 3, 'n279', '16'),
#        (26.5 , 0.25, 26.5 , 0.25, 432,  4, 66, 2, 'n278', '16'),
#        (26.5 , 0.25, 26.5 , 0.25, 432,  4, 73, 1, 'n277', '16'),
#        (26.75, 0.25, 26.75, 0.25, 436,  4, 52, 4, 'n283', '16'),
#        (26.75, 0.25, 26.75, 0.25, 436,  4, 64, 3, 'n282', '16'),
#        (26.75, 0.25, 26.75, 0.25, 436,  4, 68, 2, 'n281', '16'),
#        (26.75, 0.25, 26.75, 0.25, 436,  4, 71, 1, 'n280', '16'),
#        (27.  , 1.  , 27.  , 1.  , 440, 16, 45, 7, 'n286', '16'),
#        (27.  , 0.25, 27.  , 0.25, 440,  4, 61, 3, 'n285', '16'),
#        (27.  , 0.25, 27.  , 0.25, 440,  4, 69, 1, 'n284', '16'),
#        (27.25, 0.5 , 27.25, 0.5 , 444,  8, 52, 4, 'n289', '16'),
#        (27.25, 0.25, 27.25, 0.25, 444,  4, 64, 3, 'n288', '16'),
#        (27.25, 0.25, 27.25, 0.25, 444,  4, 71, 1, 'n287', '16'),
#        (27.5 , 0.25, 27.5 , 0.25, 448,  4, 61, 3, 'n291', '16'),
#        (27.5 , 0.25, 27.5 , 0.25, 448,  4, 68, 1, 'n290', '16'),
#        (27.75, 0.25, 27.75, 0.25, 452,  4, 52, 4, 'n294', '16'),
#        (27.75, 0.25, 27.75, 0.25, 452,  4, 64, 3, 'n293', '16'),
#        (27.75, 0.25, 27.75, 0.25, 452,  4, 69, 1, 'n292', '16'),
#        (28.  , 1.  , 28.  , 1.  , 456, 16, 44, 7, 'n298', '16'),
#        (28.  , 0.25, 28.  , 0.25, 456,  4, 66, 3, 'n297', '16'),
#        (28.  , 0.25, 28.  , 0.25, 456,  4, 72, 2, 'n296', '16'),
#        (28.  , 0.25, 28.  , 0.25, 456,  4, 75, 1, 'n295', '16'),
#        (28.25, 0.5 , 28.25, 0.5 , 460,  8, 56, 4, 'n301', '16'),
#        (28.25, 0.25, 28.25, 0.25, 460,  4, 68, 3, 'n300', '16'),
#        (28.25, 0.25, 28.25, 0.25, 460,  4, 76, 1, 'n299', '16'),
#        (28.5 , 0.25, 28.5 , 0.25, 464,  4, 66, 3, 'n304', '16'),
#        (28.5 , 0.25, 28.5 , 0.25, 464,  4, 70, 2, 'n303', '16'),
#        (28.5 , 0.25, 28.5 , 0.25, 464,  4, 76, 1, 'n302', '16'),
#        (28.75, 0.25, 28.75, 0.25, 468,  4, 56, 4, 'n308', '16'),
#        (28.75, 0.25, 28.75, 0.25, 468,  4, 68, 3, 'n307', '16'),
#        (28.75, 0.25, 28.75, 0.25, 468,  4, 72, 2, 'n306', '16'),
#        (28.75, 0.25, 28.75, 0.25, 468,  4, 75, 1, 'n305', '16'),
#        (29.  , 1.  , 29.  , 1.  , 472, 16, 49, 7, 'n311', '16'),
#        (29.  , 0.25, 29.  , 0.25, 472,  4, 64, 3, 'n310', '16'),
#        (29.  , 0.25, 29.  , 0.25, 472,  4, 73, 1, 'n309', '16'),
#        (29.25, 0.5 , 29.25, 0.5 , 476,  8, 56, 4, 'n314', '16'),
#        (29.25, 0.25, 29.25, 0.25, 476,  4, 68, 3, 'n313', '16'),
#        (29.25, 0.25, 29.25, 0.25, 476,  4, 75, 1, 'n312', '16'),
#        (29.5 , 0.25, 29.5 , 0.25, 480,  4, 64, 3, 'n316', '16'),
#        (29.5 , 0.25, 29.5 , 0.25, 480,  4, 72, 1, 'n315', '16'),
#        (29.75, 0.25, 29.75, 0.25, 484,  4, 56, 4, 'n319', '16'),
#        (29.75, 0.25, 29.75, 0.25, 484,  4, 68, 3, 'n318', '16'),
#        (29.75, 0.25, 29.75, 0.25, 484,  4, 73, 1, 'n317', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 49, 7, 'n326', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 52, 6, 'n325', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 54, 5, 'n324', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 58, 4, 'n323', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 64, 2, 'n321', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 70, 3, 'n322', '16'),
#        (30.  , 0.25, 30.  , 0.25, 488,  4, 76, 1, 'n320', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 49, 7, 'n333', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 52, 6, 'n332', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 54, 5, 'n331', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 58, 4, 'n330', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 66, 3, 'n329', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 70, 2, 'n328', '16'),
#        (30.25, 0.25, 30.25, 0.25, 492,  4, 78, 1, 'n327', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 49, 7, 'n340', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 52, 6, 'n339', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 54, 5, 'n338', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 58, 4, 'n337', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 63, 3, 'n336', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 70, 2, 'n335', '16'),
#        (30.5 , 0.25, 30.5 , 0.25, 496,  4, 75, 1, 'n334', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 49, 7, 'n347', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 52, 6, 'n346', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 54, 5, 'n345', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 58, 4, 'n344', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 64, 3, 'n343', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 70, 2, 'n342', '16'),
#        (30.75, 0.25, 30.75, 0.25, 500,  4, 76, 1, 'n341', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 48, 7, 'n354', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 52, 6, 'n353', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 54, 5, 'n352', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 58, 4, 'n351', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 66, 2, 'n349', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 70, 3, 'n350', '16'),
#        (31.  , 0.25, 31.  , 0.25, 504,  4, 78, 1, 'n348', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 48, 7, 'n361', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 52, 6, 'n360', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 54, 5, 'n359', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 58, 4, 'n358', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 68, 3, 'n357', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 70, 2, 'n356', '16'),
#        (31.25, 0.25, 31.25, 0.25, 508,  4, 80, 1, 'n355', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 48, 5, 'n366', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 52, 7, 'n368', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 54, 6, 'n367', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 58, 4, 'n365', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 64, 3, 'n364', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 70, 2, 'n363', '16'),
#        (31.5 , 0.25, 31.5 , 0.25, 512,  4, 76, 1, 'n362', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 48, 7, 'n375', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 52, 6, 'n374', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 54, 5, 'n373', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 58, 4, 'n372', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 66, 3, 'n371', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 70, 2, 'n370', '16'),
#        (31.75, 0.25, 31.75, 0.25, 516,  4, 78, 1, 'n369', '16'),
#        (32.  , 2.  , 32.  , 2.  , 520, 32, 47, 7, 'n382', '16'),
#        (32.  , 2.  , 32.  , 2.  , 520, 32, 52, 6, 'n381', '16'),
#        (32.  , 2.  , 32.  , 2.  , 520, 32, 56, 5, 'n380', '16'),
#        (32.  , 2.  , 32.  , 2.  , 520, 32, 59, 4, 'n379', '16'),
#        (32.  , 0.25, 32.  , 0.25, 520,  4, 68, 3, 'n378', '16'),
#        (32.  , 1.  , 32.  , 1.  , 520, 16, 76, 2, 'n377', '16'),
#        (32.  , 1.25, 32.  , 1.25, 520, 20, 80, 1, 'n376', '16'),
#        (32.25, 0.25, 32.25, 0.25, 524,  4, 71, 3, 'n383', '16'),
#        (32.5 , 0.25, 32.5 , 0.25, 528,  4, 68, 3, 'n384', '16'),
#        (32.75, 0.25, 32.75, 0.25, 532,  4, 71, 3, 'n385', '16'),
#        (33.  , 0.25, 33.  , 0.25, 536,  4, 68, 3, 'n386', '16'),
#        (33.25, 0.25, 33.25, 0.25, 540,  4, 71, 3, 'n388', '16'),
#        (33.25, 0.25, 33.25, 0.25, 540,  4, 78, 1, 'n387', '16'),
#        (33.5 , 0.25, 33.5 , 0.25, 544,  4, 68, 3, 'n390', '16'),
#        (33.5 , 0.25, 33.5 , 0.25, 544,  4, 76, 1, 'n389', '16'),
#        (33.75, 0.25, 33.75, 0.25, 548,  4, 71, 3, 'n392', '16'),
#        (33.75, 0.25, 33.75, 0.25, 548,  4, 73, 1, 'n391', '16'),
#        (34.  , 0.25, 34.  , 0.25, 552,  4, 54, 7, 'n395', '16'),
#        (34.  , 0.25, 34.  , 0.25, 552,  4, 63, 3, 'n394', '16'),
#        (34.  , 1.  , 34.  , 1.  , 552, 16, 75, 1, 'n393', '16'),
#        (34.25, 0.25, 34.25, 0.25, 556,  4, 59, 4, 'n397', '16'),
#        (34.25, 0.25, 34.25, 0.25, 556,  4, 66, 3, 'n396', '16'),
#        (34.5 , 0.25, 34.5 , 0.25, 560,  4, 47, 7, 'n399', '16'),
#        (34.5 , 0.25, 34.5 , 0.25, 560,  4, 63, 3, 'n398', '16'),
#        (34.75, 0.25, 34.75, 0.25, 564,  4, 59, 4, 'n401', '16'),
#        (34.75, 0.25, 34.75, 0.25, 564,  4, 66, 3, 'n400', '16'),
#        (35.  , 0.25, 35.  , 0.25, 568,  4, 49, 7, 'n404', '16'),
#        (35.  , 0.25, 35.  , 0.25, 568,  4, 64, 3, 'n403', '16'),
#        (35.  , 0.25, 35.  , 0.25, 568,  4, 76, 1, 'n402', '16'),
#        (35.25, 0.25, 35.25, 0.25, 572,  4, 56, 4, 'n407', '16'),
#        (35.25, 0.25, 35.25, 0.25, 572,  4, 68, 3, 'n406', '16'),
#        (35.25, 0.25, 35.25, 0.25, 572,  4, 75, 1, 'n405', '16'),
#        (35.5 , 1.  , 35.5 , 1.  , 576, 16, 44, 7, 'n410', '16'),
#        (35.5 , 0.25, 35.5 , 0.25, 576,  4, 64, 3, 'n409', '16'),
#        (35.5 , 0.25, 35.5 , 0.25, 576,  4, 73, 1, 'n408', '16'),
#        (35.75, 0.25, 35.75, 0.25, 580,  4, 56, 4, 'n412', '16'),
#        (35.75, 0.25, 35.75, 0.25, 580,  4, 68, 1, 'n411', '16'),
#        (36.  , 0.25, 36.  , 0.25, 584,  4, 51, 7, 'n415', '16'),
#        (36.  , 0.25, 36.  , 0.25, 584,  4, 59, 3, 'n414', '16'),
#        (36.  , 1.  , 36.  , 1.  , 584, 16, 71, 1, 'n413', '16'),
#        (36.25, 0.25, 36.25, 0.25, 588,  4, 56, 4, 'n417', '16'),
#        (36.25, 0.25, 36.25, 0.25, 588,  4, 63, 3, 'n416', '16'),
#        (36.5 , 0.25, 36.5 , 0.25, 592,  4, 44, 7, 'n419', '16'),
#        (36.5 , 0.25, 36.5 , 0.25, 592,  4, 59, 3, 'n418', '16'),
#        (36.75, 0.25, 36.75, 0.25, 596,  4, 56, 4, 'n421', '16'),
#        (36.75, 0.25, 36.75, 0.25, 596,  4, 63, 3, 'n420', '16'),
#        (37.  , 0.25, 37.  , 0.25, 600,  4, 45, 7, 'n424', '16'),
#        (37.  , 0.25, 37.  , 0.25, 600,  4, 61, 3, 'n423', '16'),
#        (37.  , 0.25, 37.  , 0.25, 600,  4, 73, 1, 'n422', '16'),
#        (37.25, 0.25, 37.25, 0.25, 604,  4, 52, 4, 'n427', '16'),
#        (37.25, 0.25, 37.25, 0.25, 604,  4, 64, 3, 'n426', '16'),
#        (37.25, 0.25, 37.25, 0.25, 604,  4, 71, 1, 'n425', '16'),
#        (37.5 , 1.  , 37.5 , 1.  , 608, 16, 40, 7, 'n430', '16'),
#        (37.5 , 0.25, 37.5 , 0.25, 608,  4, 61, 3, 'n429', '16'),
#        (37.5 , 0.25, 37.5 , 0.25, 608,  4, 69, 1, 'n428', '16'),
#        (37.75, 0.25, 37.75, 0.25, 612,  4, 52, 4, 'n432', '16'),
#        (37.75, 0.25, 37.75, 0.25, 612,  4, 64, 1, 'n431', '16'),
#        (38.  , 0.25, 38.  , 0.25, 616,  4, 47, 7, 'n435', '16'),
#        (38.  , 0.25, 38.  , 0.25, 616,  4, 56, 3, 'n434', '16'),
#        (38.  , 2.  , 38.  , 2.  , 616, 32, 68, 1, 'n433', '16'),
#        (38.25, 0.25, 38.25, 0.25, 620,  4, 52, 4, 'n437', '16'),
#        (38.25, 0.25, 38.25, 0.25, 620,  4, 59, 3, 'n436', '16'),
#        (38.5 , 1.  , 38.5 , 1.  , 624, 16, 40, 7, 'n439', '16'),
#        (38.5 , 0.25, 38.5 , 0.25, 624,  4, 56, 3, 'n438', '16'),
#        (38.75, 0.25, 38.75, 0.25, 628,  4, 52, 4, 'n441', '16'),
#        (38.75, 0.25, 38.75, 0.25, 628,  4, 59, 3, 'n440', '16'),
#        (39.  , 0.25, 39.  , 0.25, 632,  4, 47, 7, 'n443', '16'),
#        (39.  , 0.25, 39.  , 0.25, 632,  4, 56, 3, 'n442', '16'),
#        (39.25, 0.25, 39.25, 0.25, 636,  4, 52, 4, 'n445', '16'),
#        (39.25, 0.25, 39.25, 0.25, 636,  4, 59, 3, 'n444', '16'),
#        (39.5 , 1.5 , 39.5 , 1.5 , 640, 24, 40, 7, 'n447', '16'),
#        (39.5 , 0.25, 39.5 , 0.25, 640,  4, 56, 3, 'n446', '16'),
#        (39.75, 1.25, 39.75, 1.25, 644, 20, 47, 6, 'n449', '16'),
#        (39.75, 0.25, 39.75, 0.25, 644,  4, 59, 3, 'n448', '16'),
#        (40.  , 1.  , 40.  , 1.  , 648, 16, 52, 4, 'n454', '16'),
#        (40.  , 1.  , 40.  , 1.  , 648, 16, 56, 3, 'n453', '16'),
#        (40.  , 1.  , 40.  , 1.  , 648, 16, 64, 1, 'n452', '16'),
#        (40.  , 0.  , 40.  , 0.  , 648,  0, 66, 1, 'n451', '16'),
#        (40.  , 0.  , 40.  , 0.  , 648,  0, 68, 1, 'n450', '16')],
#       dtype=[('onset_beat', '<f4'), ('duration_beat', '<f4'), ('onset_quarter', '<f4'), ('duration_quarter', '<f4'), ('onset_div', '<i4'), ('duration_div', '<i4'), ('pitch', '<i4'), ('voice', '<i4'), ('id', '<U256'), ('divs_pq', '<U256')])

# %%
gt_alignment = dataset["Chopin_op10_no3_p01"][2]

# %%
gt_alignment
# Out:
# [{'label': 'match', 'score_id': 'n1', 'performance_id': '0'},
#  {'label': 'match', 'score_id': 'n2', 'performance_id': '2'},
#  {'label': 'match', 'score_id': 'n3', 'performance_id': '3'},
#  {'label': 'match', 'score_id': 'n4', 'performance_id': '1'},
#  {'label': 'match', 'score_id': 'n5', 'performance_id': '5'},
#  {'label': 'match', 'score_id': 'n6', 'performance_id': '4'},
#  {'label': 'match', 'score_id': 'n7', 'performance_id': '6'},
#  {'label': 'match', 'score_id': 'n8', 'performance_id': '7'},
#  {'label': 'match', 'score_id': 'n9', 'performance_id': '8'},
#  {'label': 'match', 'score_id': 'n10', 'performance_id': '9'},
#  {'label': 'match', 'score_id': 'n11', 'performance_id': '10'},
#  {'label': 'match', 'score_id': 'n12', 'performance_id': '11'},
#  {'label': 'match', 'score_id': 'n13', 'performance_id': '13'},
#  {'label': 'match', 'score_id': 'n14', 'performance_id': '14'},
#  {'label': 'match', 'score_id': 'n15', 'performance_id': '12'},
#  {'label': 'match', 'score_id': 'n16', 'performance_id': '16'},
#  {'label': 'match', 'score_id': 'n17', 'performance_id': '15'},
#  {'label': 'match', 'score_id': 'n18', 'performance_id': '17'},
#  {'label': 'match', 'score_id': 'n19', 'performance_id': '19'},
#  {'label': 'match', 'score_id': 'n20', 'performance_id': '18'},
#  {'label': 'match', 'score_id': 'n21', 'performance_id': '20'},
#  {'label': 'match', 'score_id': 'n22', 'performance_id': '21'},
#  {'label': 'match', 'score_id': 'n23', 'performance_id': '22'},
#  {'label': 'match', 'score_id': 'n24', 'performance_id': '23'},
#  {'label': 'match', 'score_id': 'n25', 'performance_id': '24'},
#  {'label': 'match', 'score_id': 'n26', 'performance_id': '25'},
#  {'label': 'match', 'score_id': 'n27', 'performance_id': '26'},
#  {'label': 'match', 'score_id': 'n28', 'performance_id': '27'},
#  {'label': 'match', 'score_id': 'n29', 'performance_id': '28'},
#  {'label': 'match', 'score_id': 'n30', 'performance_id': '29'},
#  {'label': 'match', 'score_id': 'n31', 'performance_id': '30'},
#  {'label': 'match', 'score_id': 'n32', 'performance_id': '31'},
#  {'label': 'match', 'score_id': 'n33', 'performance_id': '33'},
#  {'label': 'match', 'score_id': 'n34', 'performance_id': '34'},
#  {'label': 'match', 'score_id': 'n35', 'performance_id': '32'},
#  {'label': 'match', 'score_id': 'n36', 'performance_id': '36'},
#  {'label': 'match', 'score_id': 'n37', 'performance_id': '35'},
#  {'label': 'match', 'score_id': 'n38', 'performance_id': '37'},
#  {'label': 'match', 'score_id': 'n39', 'performance_id': '39'},
#  {'label': 'match', 'score_id': 'n40', 'performance_id': '38'},
#  {'label': 'match', 'score_id': 'n41', 'performance_id': '41'},
#  {'label': 'match', 'score_id': 'n42', 'performance_id': '40'},
#  {'label': 'match', 'score_id': 'n43', 'performance_id': '42'},
#  {'label': 'match', 'score_id': 'n44', 'performance_id': '44'},
#  {'label': 'match', 'score_id': 'n45', 'performance_id': '43'},
#  {'label': 'match', 'score_id': 'n46', 'performance_id': '45'},
#  {'label': 'match', 'score_id': 'n47', 'performance_id': '46'},
#  {'label': 'match', 'score_id': 'n48', 'performance_id': '47'},
#  {'label': 'match', 'score_id': 'n49', 'performance_id': '48'},
#  {'label': 'match', 'score_id': 'n50', 'performance_id': '49'},
#  {'label': 'match', 'score_id': 'n51', 'performance_id': '50'},
#  {'label': 'match', 'score_id': 'n52', 'performance_id': '51'},
#  {'label': 'match', 'score_id': 'n53', 'performance_id': '52'},
#  {'label': 'match', 'score_id': 'n54', 'performance_id': '54'},
#  {'label': 'match', 'score_id': 'n55', 'performance_id': '53'},
#  {'label': 'match', 'score_id': 'n56', 'performance_id': '55'},
#  {'label': 'match', 'score_id': 'n57', 'performance_id': '56'},
#  {'label': 'match', 'score_id': 'n58', 'performance_id': '57'},
#  {'label': 'match', 'score_id': 'n59', 'performance_id': '58'},
#  {'label': 'match', 'score_id': 'n60', 'performance_id': '59'},
#  {'label': 'match', 'score_id': 'n61', 'performance_id': '61'},
#  {'label': 'match', 'score_id': 'n62', 'performance_id': '60'},
#  {'label': 'match', 'score_id': 'n63', 'performance_id': '62'},
#  {'label': 'match', 'score_id': 'n64', 'performance_id': '63'},
#  {'label': 'match', 'score_id': 'n65', 'performance_id': '64'},
#  {'label': 'match', 'score_id': 'n66', 'performance_id': '65'},
#  {'label': 'match', 'score_id': 'n67', 'performance_id': '66'},
#  {'label': 'match', 'score_id': 'n68', 'performance_id': '67'},
#  {'label': 'match', 'score_id': 'n69', 'performance_id': '68'},
#  {'label': 'match', 'score_id': 'n70', 'performance_id': '69'},
#  {'label': 'match', 'score_id': 'n71', 'performance_id': '70'},
#  {'label': 'match', 'score_id': 'n72', 'performance_id': '72'},
#  {'label': 'match', 'score_id': 'n73', 'performance_id': '73'},
#  {'label': 'match', 'score_id': 'n74', 'performance_id': '71'},
#  {'label': 'match', 'score_id': 'n75', 'performance_id': '74'},
#  {'label': 'match', 'score_id': 'n76', 'performance_id': '76'},
#  {'label': 'match', 'score_id': 'n77', 'performance_id': '75'},
#  {'label': 'match', 'score_id': 'n78', 'performance_id': '77'},
#  {'label': 'match', 'score_id': 'n79', 'performance_id': '78'},
#  {'label': 'match', 'score_id': 'n80', 'performance_id': '80'},
#  {'label': 'match', 'score_id': 'n81', 'performance_id': '81'},
#  {'label': 'match', 'score_id': 'n82', 'performance_id': '79'},
#  {'label': 'match', 'score_id': 'n83', 'performance_id': '83'},
#  {'label': 'match', 'score_id': 'n84', 'performance_id': '84'},
#  {'label': 'match', 'score_id': 'n85', 'performance_id': '82'},
#  {'label': 'match', 'score_id': 'n86', 'performance_id': '85'},
#  {'label': 'match', 'score_id': 'n87', 'performance_id': '86'},
#  {'label': 'match', 'score_id': 'n88', 'performance_id': '88'},
#  {'label': 'match', 'score_id': 'n89', 'performance_id': '87'},
#  {'label': 'match', 'score_id': 'n90', 'performance_id': '89'},
#  {'label': 'match', 'score_id': 'n91', 'performance_id': '90'},
#  {'label': 'match', 'score_id': 'n92', 'performance_id': '91'},
#  {'label': 'match', 'score_id': 'n93', 'performance_id': '92'},
#  {'label': 'match', 'score_id': 'n94', 'performance_id': '94'},
#  {'label': 'match', 'score_id': 'n95', 'performance_id': '93'},
#  {'label': 'match', 'score_id': 'n96', 'performance_id': '95'},
#  {'label': 'match', 'score_id': 'n97', 'performance_id': '96'},
#  {'label': 'match', 'score_id': 'n98', 'performance_id': '98'},
#  {'label': 'match', 'score_id': 'n99', 'performance_id': '97'},
#  {'label': 'match', 'score_id': 'n100', 'performance_id': '100'},
#  {'label': 'match', 'score_id': 'n101', 'performance_id': '99'},
#  {'label': 'match', 'score_id': 'n102', 'performance_id': '101'},
#  {'label': 'match', 'score_id': 'n103', 'performance_id': '102'},
#  {'label': 'match', 'score_id': 'n104', 'performance_id': '103'},
#  {'label': 'match', 'score_id': 'n105', 'performance_id': '104'},
#  {'label': 'match', 'score_id': 'n106', 'performance_id': '106'},
#  {'label': 'match', 'score_id': 'n107', 'performance_id': '105'},
#  {'label': 'match', 'score_id': 'n108', 'performance_id': '107'},
#  {'label': 'match', 'score_id': 'n109', 'performance_id': '109'},
#  {'label': 'match', 'score_id': 'n110', 'performance_id': '108'},
#  {'label': 'match', 'score_id': 'n111', 'performance_id': '110'},
#  {'label': 'match', 'score_id': 'n112', 'performance_id': '111'},
#  {'label': 'match', 'score_id': 'n113', 'performance_id': '112'},
#  {'label': 'match', 'score_id': 'n114', 'performance_id': '114'},
#  {'label': 'match', 'score_id': 'n115', 'performance_id': '113'},
#  {'label': 'match', 'score_id': 'n116', 'performance_id': '115'},
#  {'label': 'match', 'score_id': 'n117', 'performance_id': '116'},
#  {'label': 'match', 'score_id': 'n118', 'performance_id': '117'},
#  {'label': 'match', 'score_id': 'n119', 'performance_id': '118'},
#  {'label': 'match', 'score_id': 'n120', 'performance_id': '120'},
#  {'label': 'match', 'score_id': 'n121', 'performance_id': '119'},
#  {'label': 'match', 'score_id': 'n122', 'performance_id': '121'},
#  {'label': 'match', 'score_id': 'n123', 'performance_id': '122'},
#  {'label': 'match', 'score_id': 'n124', 'performance_id': '123'},
#  {'label': 'match', 'score_id': 'n125', 'performance_id': '125'},
#  {'label': 'match', 'score_id': 'n126', 'performance_id': '124'},
#  {'label': 'match', 'score_id': 'n127', 'performance_id': '127'},
#  {'label': 'match', 'score_id': 'n128', 'performance_id': '128'},
#  {'label': 'match', 'score_id': 'n129', 'performance_id': '126'},
#  {'label': 'match', 'score_id': 'n130', 'performance_id': '130'},
#  {'label': 'match', 'score_id': 'n131', 'performance_id': '129'},
#  {'label': 'match', 'score_id': 'n132', 'performance_id': '131'},
#  {'label': 'match', 'score_id': 'n133', 'performance_id': '132'},
#  {'label': 'match', 'score_id': 'n134', 'performance_id': '133'},
#  {'label': 'match', 'score_id': 'n135', 'performance_id': '134'},
#  {'label': 'match', 'score_id': 'n136', 'performance_id': '135'},
#  {'label': 'match', 'score_id': 'n137', 'performance_id': '136'},
#  {'label': 'match', 'score_id': 'n138', 'performance_id': '138'},
#  {'label': 'match', 'score_id': 'n139', 'performance_id': '137'},
#  {'label': 'match', 'score_id': 'n140', 'performance_id': '140'},
#  {'label': 'match', 'score_id': 'n141', 'performance_id': '141'},
#  {'label': 'match', 'score_id': 'n142', 'performance_id': '139'},
#  {'label': 'match', 'score_id': 'n143', 'performance_id': '142'},
#  {'label': 'match', 'score_id': 'n144', 'performance_id': '144'},
#  {'label': 'match', 'score_id': 'n145', 'performance_id': '143'},
#  {'label': 'match', 'score_id': 'n146', 'performance_id': '146'},
#  {'label': 'match', 'score_id': 'n147', 'performance_id': '145'},
#  {'label': 'match', 'score_id': 'n148', 'performance_id': '147'},
#  {'label': 'match', 'score_id': 'n149', 'performance_id': '148'},
#  {'label': 'match', 'score_id': 'n150', 'performance_id': '150'},
#  {'label': 'match', 'score_id': 'n151', 'performance_id': '151'},
#  {'label': 'match', 'score_id': 'n152', 'performance_id': '149'},
#  {'label': 'match', 'score_id': 'n153', 'performance_id': '152'},
#  {'label': 'match', 'score_id': 'n154', 'performance_id': '153'},
#  {'label': 'match', 'score_id': 'n155', 'performance_id': '154'},
#  {'label': 'match', 'score_id': 'n156', 'performance_id': '155'},
#  {'label': 'match', 'score_id': 'n157', 'performance_id': '156'},
#  {'label': 'match', 'score_id': 'n158', 'performance_id': '158'},
#  {'label': 'match', 'score_id': 'n159', 'performance_id': '157'},
#  {'label': 'match', 'score_id': 'n160', 'performance_id': '159'},
#  {'label': 'match', 'score_id': 'n161', 'performance_id': '160'},
#  {'label': 'match', 'score_id': 'n162', 'performance_id': '161'},
#  {'label': 'match', 'score_id': 'n163', 'performance_id': '162'},
#  {'label': 'match', 'score_id': 'n164', 'performance_id': '163'},
#  {'label': 'match', 'score_id': 'n165', 'performance_id': '165'},
#  {'label': 'match', 'score_id': 'n166', 'performance_id': '167'},
#  {'label': 'match', 'score_id': 'n167', 'performance_id': '166'},
#  {'label': 'match', 'score_id': 'n168', 'performance_id': '164'},
#  {'label': 'match', 'score_id': 'n169', 'performance_id': '169'},
#  {'label': 'match', 'score_id': 'n170', 'performance_id': '168'},
#  {'label': 'match', 'score_id': 'n171', 'performance_id': '170'},
#  {'label': 'match', 'score_id': 'n172', 'performance_id': '171'},
#  {'label': 'match', 'score_id': 'n173', 'performance_id': '172'},
#  {'label': 'match', 'score_id': 'n174', 'performance_id': '174'},
#  {'label': 'match', 'score_id': 'n175', 'performance_id': '173'},
#  {'label': 'match', 'score_id': 'n176', 'performance_id': '175'},
#  {'label': 'match', 'score_id': 'n177', 'performance_id': '177'},
#  {'label': 'match', 'score_id': 'n178', 'performance_id': '178'},
#  {'label': 'match', 'score_id': 'n179', 'performance_id': '176'},
#  {'label': 'match', 'score_id': 'n180', 'performance_id': '180'},
#  {'label': 'match', 'score_id': 'n181', 'performance_id': '179'},
#  {'label': 'match', 'score_id': 'n182', 'performance_id': '181'},
#  {'label': 'match', 'score_id': 'n183', 'performance_id': '182'},
#  {'label': 'match', 'score_id': 'n184', 'performance_id': '183'},
#  {'label': 'match', 'score_id': 'n185', 'performance_id': '184'},
#  {'label': 'match', 'score_id': 'n186', 'performance_id': '185'},
#  {'label': 'match', 'score_id': 'n187', 'performance_id': '186'},
#  {'label': 'match', 'score_id': 'n188', 'performance_id': '187'},
#  {'label': 'match', 'score_id': 'n189', 'performance_id': '188'},
#  {'label': 'match', 'score_id': 'n190', 'performance_id': '189'},
#  {'label': 'match', 'score_id': 'n191', 'performance_id': '190'},
#  {'label': 'match', 'score_id': 'n192', 'performance_id': '191'},
#  {'label': 'match', 'score_id': 'n193', 'performance_id': '192'},
#  {'label': 'match', 'score_id': 'n194', 'performance_id': '194'},
#  {'label': 'match', 'score_id': 'n195', 'performance_id': '193'},
#  {'label': 'match', 'score_id': 'n196', 'performance_id': '195'},
#  {'label': 'match', 'score_id': 'n197', 'performance_id': '197'},
#  {'label': 'match', 'score_id': 'n198', 'performance_id': '198'},
#  {'label': 'match', 'score_id': 'n199', 'performance_id': '196'},
#  {'label': 'match', 'score_id': 'n200', 'performance_id': '200'},
#  {'label': 'match', 'score_id': 'n201', 'performance_id': '199'},
#  {'label': 'match', 'score_id': 'n202', 'performance_id': '201'},
#  {'label': 'match', 'score_id': 'n203', 'performance_id': '203'},
#  {'label': 'match', 'score_id': 'n204', 'performance_id': '202'},
#  {'label': 'match', 'score_id': 'n205', 'performance_id': '204'},
#  {'label': 'match', 'score_id': 'n206', 'performance_id': '205'},
#  {'label': 'match', 'score_id': 'n207', 'performance_id': '206'},
#  {'label': 'match', 'score_id': 'n208', 'performance_id': '208'},
#  {'label': 'match', 'score_id': 'n209', 'performance_id': '207'},
#  {'label': 'match', 'score_id': 'n210', 'performance_id': '209'},
#  {'label': 'match', 'score_id': 'n211', 'performance_id': '210'},
#  {'label': 'match', 'score_id': 'n212', 'performance_id': '211'},
#  {'label': 'match', 'score_id': 'n213', 'performance_id': '213'},
#  {'label': 'match', 'score_id': 'n214', 'performance_id': '212'},
#  {'label': 'match', 'score_id': 'n215', 'performance_id': '214'},
#  {'label': 'match', 'score_id': 'n216', 'performance_id': '216'},
#  {'label': 'match', 'score_id': 'n217', 'performance_id': '215'},
#  {'label': 'match', 'score_id': 'n218', 'performance_id': '218'},
#  {'label': 'match', 'score_id': 'n219', 'performance_id': '217'},
#  {'label': 'match', 'score_id': 'n220', 'performance_id': '219'},
#  {'label': 'match', 'score_id': 'n221', 'performance_id': '220'},
#  {'label': 'match', 'score_id': 'n222', 'performance_id': '222'},
#  {'label': 'match', 'score_id': 'n223', 'performance_id': '221'},
#  {'label': 'match', 'score_id': 'n224', 'performance_id': '223'},
#  {'label': 'match', 'score_id': 'n225', 'performance_id': '225'},
#  {'label': 'match', 'score_id': 'n226', 'performance_id': '224'},
#  {'label': 'match', 'score_id': 'n227', 'performance_id': '226'},
#  {'label': 'match', 'score_id': 'n228', 'performance_id': '228'},
#  {'label': 'match', 'score_id': 'n229', 'performance_id': '227'},
#  {'label': 'match', 'score_id': 'n230', 'performance_id': '229'},
#  {'label': 'match', 'score_id': 'n231', 'performance_id': '230'},
#  {'label': 'match', 'score_id': 'n232', 'performance_id': '232'},
#  {'label': 'match', 'score_id': 'n233', 'performance_id': '233'},
#  {'label': 'match', 'score_id': 'n234', 'performance_id': '231'},
#  {'label': 'match', 'score_id': 'n235', 'performance_id': '234'},
#  {'label': 'match', 'score_id': 'n236', 'performance_id': '237'},
#  {'label': 'match', 'score_id': 'n237', 'performance_id': '236'},
#  {'label': 'match', 'score_id': 'n238', 'performance_id': '235'},
#  {'label': 'match', 'score_id': 'n239', 'performance_id': '238'},
#  {'label': 'match', 'score_id': 'n240', 'performance_id': '240'},
#  {'label': 'match', 'score_id': 'n241', 'performance_id': '239'},
#  {'label': 'match', 'score_id': 'n242', 'performance_id': '241'},
#  {'label': 'match', 'score_id': 'n243', 'performance_id': '242'},
#  {'label': 'match', 'score_id': 'n244', 'performance_id': '243'},
#  {'label': 'match', 'score_id': 'n245', 'performance_id': '245'},
#  {'label': 'match', 'score_id': 'n246', 'performance_id': '244'},
#  {'label': 'match', 'score_id': 'n247', 'performance_id': '246'},
#  {'label': 'match', 'score_id': 'n248', 'performance_id': '248'},
#  {'label': 'match', 'score_id': 'n249', 'performance_id': '247'},
#  {'label': 'match', 'score_id': 'n250', 'performance_id': '249'},
#  {'label': 'match', 'score_id': 'n251', 'performance_id': '252'},
#  {'label': 'match', 'score_id': 'n252', 'performance_id': '251'},
#  {'label': 'match', 'score_id': 'n253', 'performance_id': '250'},
#  {'label': 'match', 'score_id': 'n254', 'performance_id': '253'},
#  {'label': 'match', 'score_id': 'n255', 'performance_id': '254'},
#  {'label': 'match', 'score_id': 'n256', 'performance_id': '255'},
#  {'label': 'match', 'score_id': 'n257', 'performance_id': '256'},
#  {'label': 'match', 'score_id': 'n258', 'performance_id': '259'},
#  {'label': 'match', 'score_id': 'n259', 'performance_id': '258'},
#  {'label': 'match', 'score_id': 'n260', 'performance_id': '257'},
#  {'label': 'match', 'score_id': 'n261', 'performance_id': '260'},
#  {'label': 'match', 'score_id': 'n262', 'performance_id': '262'},
#  {'label': 'match', 'score_id': 'n263', 'performance_id': '261'},
#  {'label': 'match', 'score_id': 'n264', 'performance_id': '263'},
#  {'label': 'match', 'score_id': 'n265', 'performance_id': '264'},
#  {'label': 'match', 'score_id': 'n266', 'performance_id': '265'},
#  {'label': 'match', 'score_id': 'n267', 'performance_id': '266'},
#  {'label': 'match', 'score_id': 'n268', 'performance_id': '267'},
#  {'label': 'match', 'score_id': 'n269', 'performance_id': '268'},
#  {'label': 'match', 'score_id': 'n270', 'performance_id': '270'},
#  {'label': 'match', 'score_id': 'n271', 'performance_id': '271'},
#  {'label': 'match', 'score_id': 'n272', 'performance_id': '269'},
#  {'label': 'match', 'score_id': 'n273', 'performance_id': '272'},
#  {'label': 'match', 'score_id': 'n274', 'performance_id': '274'},
#  {'label': 'match', 'score_id': 'n275', 'performance_id': '275'},
#  {'label': 'match', 'score_id': 'n276', 'performance_id': '273'},
#  {'label': 'match', 'score_id': 'n277', 'performance_id': '276'},
#  {'label': 'match', 'score_id': 'n278', 'performance_id': '277'},
#  {'label': 'match', 'score_id': 'n279', 'performance_id': '278'},
#  {'label': 'match', 'score_id': 'n280', 'performance_id': '279'},
#  {'label': 'match', 'score_id': 'n281', 'performance_id': '281'},
#  {'label': 'match', 'score_id': 'n282', 'performance_id': '282'},
#  {'label': 'match', 'score_id': 'n283', 'performance_id': '280'},
#  {'label': 'match', 'score_id': 'n284', 'performance_id': '283'},
#  {'label': 'match', 'score_id': 'n285', 'performance_id': '285'},
#  {'label': 'match', 'score_id': 'n286', 'performance_id': '284'},
#  {'label': 'match', 'score_id': 'n287', 'performance_id': '287'},
#  {'label': 'match', 'score_id': 'n288', 'performance_id': '288'},
#  {'label': 'match', 'score_id': 'n289', 'performance_id': '286'},
#  {'label': 'match', 'score_id': 'n290', 'performance_id': '289'},
#  {'label': 'match', 'score_id': 'n291', 'performance_id': '290'},
#  {'label': 'match', 'score_id': 'n292', 'performance_id': '291'},
#  {'label': 'match', 'score_id': 'n293', 'performance_id': '293'},
#  {'label': 'match', 'score_id': 'n294', 'performance_id': '292'},
#  {'label': 'match', 'score_id': 'n295', 'performance_id': '294'},
#  {'label': 'match', 'score_id': 'n296', 'performance_id': '296'},
#  {'label': 'match', 'score_id': 'n297', 'performance_id': '297'},
#  {'label': 'match', 'score_id': 'n298', 'performance_id': '295'},
#  {'label': 'match', 'score_id': 'n299', 'performance_id': '298'},
#  {'label': 'match', 'score_id': 'n300', 'performance_id': '300'},
#  {'label': 'match', 'score_id': 'n301', 'performance_id': '299'},
#  {'label': 'match', 'score_id': 'n302', 'performance_id': '301'},
#  {'label': 'match', 'score_id': 'n303', 'performance_id': '302'},
#  {'label': 'match', 'score_id': 'n304', 'performance_id': '303'},
#  {'label': 'match', 'score_id': 'n305', 'performance_id': '304'},
#  {'label': 'match', 'score_id': 'n306', 'performance_id': '307'},
#  {'label': 'match', 'score_id': 'n307', 'performance_id': '305'},
#  {'label': 'match', 'score_id': 'n308', 'performance_id': '306'},
#  {'label': 'match', 'score_id': 'n309', 'performance_id': '309'},
#  {'label': 'match', 'score_id': 'n310', 'performance_id': '310'},
#  {'label': 'match', 'score_id': 'n311', 'performance_id': '308'},
#  {'label': 'match', 'score_id': 'n312', 'performance_id': '311'},
#  {'label': 'match', 'score_id': 'n313', 'performance_id': '313'},
#  {'label': 'match', 'score_id': 'n314', 'performance_id': '312'},
#  {'label': 'match', 'score_id': 'n315', 'performance_id': '314'},
#  {'label': 'match', 'score_id': 'n316', 'performance_id': '315'},
#  {'label': 'match', 'score_id': 'n317', 'performance_id': '316'},
#  {'label': 'match', 'score_id': 'n318', 'performance_id': '318'},
#  {'label': 'match', 'score_id': 'n319', 'performance_id': '317'},
#  {'label': 'match', 'score_id': 'n320', 'performance_id': '319'},
#  {'label': 'match', 'score_id': 'n321', 'performance_id': '322'},
#  {'label': 'match', 'score_id': 'n322', 'performance_id': '321'},
#  {'label': 'match', 'score_id': 'n323', 'performance_id': '320'},
#  {'label': 'match', 'score_id': 'n324', 'performance_id': '325'},
#  {'label': 'match', 'score_id': 'n325', 'performance_id': '324'},
#  {'label': 'match', 'score_id': 'n326', 'performance_id': '323'},
#  {'label': 'match', 'score_id': 'n327', 'performance_id': '326'},
#  {'label': 'match', 'score_id': 'n328', 'performance_id': '332'},
#  {'label': 'match', 'score_id': 'n329', 'performance_id': '328'},
#  {'label': 'match', 'score_id': 'n330', 'performance_id': '327'},
#  {'label': 'match', 'score_id': 'n331', 'performance_id': '329'},
#  {'label': 'match', 'score_id': 'n332', 'performance_id': '330'},
#  {'label': 'match', 'score_id': 'n333', 'performance_id': '331'},
#  {'label': 'match', 'score_id': 'n334', 'performance_id': '334'},
#  {'label': 'match', 'score_id': 'n335', 'performance_id': '339'},
#  {'label': 'match', 'score_id': 'n336', 'performance_id': '335'},
#  {'label': 'match', 'score_id': 'n337', 'performance_id': '333'},
#  {'label': 'match', 'score_id': 'n338', 'performance_id': '337'},
#  {'label': 'match', 'score_id': 'n339', 'performance_id': '338'},
#  {'label': 'match', 'score_id': 'n340', 'performance_id': '336'},
#  {'label': 'match', 'score_id': 'n341', 'performance_id': '341'},
#  {'label': 'match', 'score_id': 'n342', 'performance_id': '344'},
#  {'label': 'match', 'score_id': 'n343', 'performance_id': '343'},
#  {'label': 'match', 'score_id': 'n344', 'performance_id': '340'},
#  {'label': 'match', 'score_id': 'n345', 'performance_id': '345'},
#  {'label': 'match', 'score_id': 'n346', 'performance_id': '346'},
#  {'label': 'match', 'score_id': 'n347', 'performance_id': '342'},
#  {'label': 'match', 'score_id': 'n348', 'performance_id': '347'},
#  {'label': 'match', 'score_id': 'n349', 'performance_id': '350'},
#  {'label': 'match', 'score_id': 'n350', 'performance_id': '351'},
#  {'label': 'match', 'score_id': 'n351', 'performance_id': '348'},
#  {'label': 'match', 'score_id': 'n352', 'performance_id': '349'},
#  {'label': 'match', 'score_id': 'n353', 'performance_id': '353'},
#  {'label': 'match', 'score_id': 'n354', 'performance_id': '352'},
#  {'label': 'match', 'score_id': 'n355', 'performance_id': '354'},
#  {'label': 'deletion', 'score_id': 'n356'},
#  {'label': 'match', 'score_id': 'n357', 'performance_id': '358'},
#  {'label': 'match', 'score_id': 'n358', 'performance_id': '355'},
#  {'label': 'deletion', 'score_id': 'n359'},
#  {'label': 'match', 'score_id': 'n360', 'performance_id': '357'},
#  {'label': 'match', 'score_id': 'n361', 'performance_id': '356'},
#  {'label': 'match', 'score_id': 'n362', 'performance_id': '359'},
#  {'label': 'match', 'score_id': 'n363', 'performance_id': '364'},
#  {'label': 'match', 'score_id': 'n364', 'performance_id': '361'},
#  {'label': 'match', 'score_id': 'n365', 'performance_id': '360'},
#  {'label': 'match', 'score_id': 'n366', 'performance_id': '362'},
#  {'label': 'match', 'score_id': 'n367', 'performance_id': '363'},
#  {'label': 'match', 'score_id': 'n368', 'performance_id': '365'},
#  {'label': 'match', 'score_id': 'n369', 'performance_id': '367'},
#  {'label': 'match', 'score_id': 'n370', 'performance_id': '369'},
#  {'label': 'match', 'score_id': 'n371', 'performance_id': '368'},
#  {'label': 'match', 'score_id': 'n372', 'performance_id': '366'},
#  {'label': 'match', 'score_id': 'n373', 'performance_id': '370'},
#  {'label': 'match', 'score_id': 'n374', 'performance_id': '372'},
#  {'label': 'match', 'score_id': 'n375', 'performance_id': '371'},
#  {'label': 'match', 'score_id': 'n376', 'performance_id': '373'},
#  {'label': 'match', 'score_id': 'n377', 'performance_id': '378'},
#  {'label': 'match', 'score_id': 'n378', 'performance_id': '374'},
#  {'label': 'match', 'score_id': 'n379', 'performance_id': '375'},
#  {'label': 'match', 'score_id': 'n380', 'performance_id': '377'},
#  {'label': 'match', 'score_id': 'n381', 'performance_id': '379'},
#  {'label': 'match', 'score_id': 'n382', 'performance_id': '376'},
#  {'label': 'match', 'score_id': 'n383', 'performance_id': '380'},
#  {'label': 'match', 'score_id': 'n384', 'performance_id': '381'},
#  {'label': 'match', 'score_id': 'n385', 'performance_id': '382'},
#  {'label': 'match', 'score_id': 'n386', 'performance_id': '383'},
#  {'label': 'match', 'score_id': 'n387', 'performance_id': '384'},
#  {'label': 'match', 'score_id': 'n388', 'performance_id': '385'},
#  {'label': 'match', 'score_id': 'n389', 'performance_id': '386'},
#  {'label': 'match', 'score_id': 'n390', 'performance_id': '387'},
#  {'label': 'match', 'score_id': 'n391', 'performance_id': '388'},
#  {'label': 'match', 'score_id': 'n392', 'performance_id': '389'},
#  {'label': 'match', 'score_id': 'n393', 'performance_id': '390'},
#  {'label': 'match', 'score_id': 'n394', 'performance_id': '391'},
#  {'label': 'match', 'score_id': 'n395', 'performance_id': '392'},
#  {'label': 'match', 'score_id': 'n396', 'performance_id': '393'},
#  {'label': 'match', 'score_id': 'n397', 'performance_id': '394'},
#  {'label': 'match', 'score_id': 'n398', 'performance_id': '395'},
#  {'label': 'match', 'score_id': 'n399', 'performance_id': '396'},
#  {'label': 'match', 'score_id': 'n400', 'performance_id': '397'},
#  {'label': 'match', 'score_id': 'n401', 'performance_id': '398'},
#  {'label': 'match', 'score_id': 'n402', 'performance_id': '399'},
#  {'label': 'match', 'score_id': 'n403', 'performance_id': '400'},
#  {'label': 'match', 'score_id': 'n404', 'performance_id': '401'},
#  {'label': 'match', 'score_id': 'n405', 'performance_id': '402'},
#  {'label': 'match', 'score_id': 'n406', 'performance_id': '403'},
#  {'label': 'match', 'score_id': 'n407', 'performance_id': '404'},
#  {'label': 'match', 'score_id': 'n408', 'performance_id': '405'},
#  {'label': 'match', 'score_id': 'n409', 'performance_id': '406'},
#  {'label': 'match', 'score_id': 'n410', 'performance_id': '407'},
#  {'label': 'match', 'score_id': 'n411', 'performance_id': '408'},
#  {'label': 'match', 'score_id': 'n412', 'performance_id': '409'},
#  {'label': 'match', 'score_id': 'n413', 'performance_id': '410'},
#  {'label': 'match', 'score_id': 'n414', 'performance_id': '412'},
#  {'label': 'match', 'score_id': 'n415', 'performance_id': '411'},
#  {'label': 'match', 'score_id': 'n416', 'performance_id': '413'},
#  {'label': 'match', 'score_id': 'n417', 'performance_id': '414'},
#  {'label': 'match', 'score_id': 'n418', 'performance_id': '416'},
#  {'label': 'match', 'score_id': 'n419', 'performance_id': '415'},
#  {'label': 'match', 'score_id': 'n420', 'performance_id': '417'},
#  {'label': 'match', 'score_id': 'n421', 'performance_id': '418'},
#  {'label': 'match', 'score_id': 'n422', 'performance_id': '419'},
#  {'label': 'match', 'score_id': 'n423', 'performance_id': '421'},
#  {'label': 'match', 'score_id': 'n424', 'performance_id': '420'},
#  {'label': 'match', 'score_id': 'n425', 'performance_id': '423'},
#  {'label': 'match', 'score_id': 'n426', 'performance_id': '424'},
#  {'label': 'match', 'score_id': 'n427', 'performance_id': '422'},
#  {'label': 'match', 'score_id': 'n428', 'performance_id': '425'},
#  {'label': 'match', 'score_id': 'n429', 'performance_id': '427'},
#  {'label': 'match', 'score_id': 'n430', 'performance_id': '426'},
#  {'label': 'match', 'score_id': 'n431', 'performance_id': '428'},
#  {'label': 'match', 'score_id': 'n432', 'performance_id': '429'},
#  {'label': 'match', 'score_id': 'n433', 'performance_id': '430'},
#  {'label': 'match', 'score_id': 'n434', 'performance_id': '432'},
#  {'label': 'match', 'score_id': 'n435', 'performance_id': '431'},
#  {'label': 'match', 'score_id': 'n436', 'performance_id': '434'},
#  {'label': 'match', 'score_id': 'n437', 'performance_id': '433'},
#  {'label': 'match', 'score_id': 'n438', 'performance_id': '436'},
#  {'label': 'match', 'score_id': 'n439', 'performance_id': '435'},
#  {'label': 'match', 'score_id': 'n440', 'performance_id': '438'},
#  {'label': 'match', 'score_id': 'n441', 'performance_id': '437'},
#  {'label': 'match', 'score_id': 'n442', 'performance_id': '440'},
#  {'label': 'match', 'score_id': 'n443', 'performance_id': '439'},
#  {'label': 'match', 'score_id': 'n444', 'performance_id': '441'},
#  {'label': 'match', 'score_id': 'n445', 'performance_id': '442'},
#  {'label': 'match', 'score_id': 'n446', 'performance_id': '443'},
#  {'label': 'match', 'score_id': 'n447', 'performance_id': '444'},
#  {'label': 'match', 'score_id': 'n448', 'performance_id': '445'},
#  {'label': 'match', 'score_id': 'n449', 'performance_id': '446'},
#  {'label': 'match', 'score_id': 'n450', 'performance_id': '447'},
#  {'label': 'match', 'score_id': 'n451', 'performance_id': '450'},
#  {'label': 'match', 'score_id': 'n452', 'performance_id': '451'},
#  {'label': 'match', 'score_id': 'n453', 'performance_id': '449'},
#  {'label': 'deletion', 'score_id': 'n454'}]

# %% [markdown]
# ## Inspecting the data
#
# When inspecting the score and the performance matrix, one can observe, that each note has a separate entry in form of a row inside the numpy-matrix. Basically the score and the performance are represented as an array of notes.
#
# ### Performance
# The performance-numpy array consists of information about onset_sec, duration_sec, pitch, velocity, track, channel and id. "Onset" means the beginning of a note, e.g. if the pianist presses a key, the beginning of the note when its played is called "onset". After that the key is most likely hold for sometime on the piano, which is referred to as the duration.
#
# In the performance-numpy array onset and duration is defined in seconds. The pitch is an integer-number which corresponds to the pitch in the MIDI-convention. Velocity refers to another integer-number following the MIDI-convention representing how strong the key is pressed on the piano. The range is from 0 to 127 for both values, where 0 is the lowest pitch and strength-value and 127 the highest one.
#
# Track and Channel are just meta-information about the MIDI-File, because MIDI-Files can be composed of multiple MIDI-Layers where each consists of different MIDI-notes played. E.g. you could divide the information of the upper and the lower hand into two different tracks. A channel corresponds to the output-instrument, e.g. if you have two instruments, they are divided into two channels.
#
# The last element, the ID, is a unique identifier for each note played in a piece.
#
# As you can see, the most important information are the onset-time and the duration, as well as the pitch and velocity. This is used for music alignment.
#
# ### Score
#
# The score also has onset- and duration-times, but in the score-representation the format are in "beats", "quarters" and "divs" (divisions). "onset_beat", "onset_quarter" and "onset_div" represents the same information just in different formats.
#
# "beats" refer to the individual beats in a musical score, where also negative values are allowed in the beginning of a piece to represent the upbeat before the piece starts with its measure, e.g. an upbeat could be 1/4 and then the piece continues in 4/4. A value of -1 would represent one beat before the actual start of the piece.
#
# "quarters" are quarter-notes, as the name suggests. So a note with an onset of 1 would represent, that this note starts one quarter after the beginning. A duration of 0.5 in quarters would correspond to half a quarter, which is an eighth note.
#
# "div" is a unit for division which is a metric also implemented in MusicXML and adapted for partitura. For notes to be specified in divisions, a second value has to be established, which is "div_pq". "div_pq" specifies how much a quarter note is further divided in, e.g. div_pq = 16 means, that the value 16 represents the duration of a quarter note. If now a note has duration 8, it is an eighth-note since 16 would correspond to a quarter note and half of it (16/2 = 8) is an eighth-note. Normally, div_pq can change in every bar and with this value every note has to be represented, such that the precision can vary for each bar.
#
# Pitch is the same as in the performance, but now, there is a voice-column established. The voice is a tag of MusicXML representing a bunch of notes, rests, etc. which belongs together. You could e.g. divide the piano-clefs for melody and accompaniment into different voices, but in the base clef, there could be different elements belonging to different melodies itself, which can be further divided into voices. This feature is not strictly necessary but can provide useful musical information which cannot be explicitly encoded.
#
# The ID serves the same purpose as in the performance-part and is an unique identifier.
#
# ### Ground-Truth-Alignment
#
# The ground-truth-alignment is a list consisting of dictionaries always following the same structure. The first entry is called "label" and can take one out of three important values, namely "insertion", "deletion" and "match". "Insertion" refers to the fact, that in the performance there is a note inserted, which is not in the score and deletion is a note, which would be written in the score but was not played by the pianist. "Matches" are notes, which have been successfully matched between score and performance array.

# %% [markdown]
# ## Computing Features for Music Alignment
#
# From these different data-representations of score and performance, we can conclude, that in order to match notes of the score to the performance, we have to match representations first.
#
# There are multiple ways to do that, e.g. training an auto-encoder to encode these features in the same format, but we decided against doing that, since neural networks do not know musical structure per se and would be uninformed function approximators. The most natural way to represent music is a visualization used in Digital Audio Workstations when editing MIDI-notes. It is called the "Piano Roll" and represents the musical piece on two axis in a cartesian coordinate system, where x is the time and y the midi-pitch. Internally, it is stored in a sparse matrix, since there are many zeros inside the array. This representation can be constructed with the score and the performance.
#
# Piano Rolls can occur in different forms, e.g. they can represent only pitches, such that each pitch is represented within the same pitch-class (e.g. C1 and C2 would be treated the same) or they can distinguish between the actual ranges of the notes. They can also represent velocity-values or completely neglect them only considering binary values, where 0 represents a note not being played and 1 represents a note being played.
#
# For generating Piano-Rolls out of note arrays, such those, which are given as training-data, the class "Partitura" is used.

# %% [markdown]
# ### Partitura
#
# `Partitura` is a package for Music Information Retrieval (MIR) of Symbolic Music. In general, in MIR tasks you want to automatically process symbolic music and therefore, you need to convert it into a format, algorithms can automatically understand. Importing symbolic music files in the original MIDI or MusicXML formats is not a good idea, since they contain much redundant information and in the end you want a representation in matrix form, which is not given by the original formats.
#
# The goal of `Partitura` is to preprocess different symbolic music files and store them in a structured and similar way for all of these different sources within structured python objects. Furthermore, it provides many additional functions for preprocessing the data into different formats, e.g. to transform MIDI data into Piano Rolls. `Partitura` is divided into different modules, the `utils.music`-package contains a function for computing a piano-roll out of a note-array which is needed for our case.
#
# Further tasks `Partitura` can handle are related to loading different symbolic music formats and computing different representations of it, e.g. extending the feature-columns to different properties of the loaded score-file in MusicXML, etc.
#
# see paper: Cancino-Chacón, C. E., Peter, S. D., Karystinaios, E., Foscarin, F., Grachten, M., & Widmer, G. (2022). Partitura: A Python Package for Symbolic Music Processing. In Proceedings of the Music Encoding Conference (MEC2022). Halifax, Canada. (https://arxiv.org/abs/2206.01071)

# %% [markdown]
# The method `pt.utils.music.compute_pianoroll()` computes a piano-roll out of a note-array, where different parameters can be chosen.
#
# Parameters:
# 1. `return_idxs`: represents a boolean-value. If this value is true, an additional array is returned containing the coordinates of each note in the computed piano-roll.
# 2. `remove_drums`: represents also a boolean-value and does not take drums into consideration. Since we only use classical piano pieces, this value is always set to True.
# 3. `end_time`: with this value, you could restrict the maximum length of the piece and truncate everything else. In our scenario this is not used due to a loss of information.
# 4. `time_unit` corresponds to a value for measuring duration and onset of notes when computing the piano roll. If "auto" is chosen score-note-arrays are using the "beat"-measure and performance-note-array the "sec"-measure. Out of this information of the notes, the piano roll is computed.
# 5. `binary`: represents a boolean-value. If this is true, the velocity of notes is neglected and only 0 and 1 is used for velocity when computing the piano-roll, where 0 means that the note is not present and 1 means, that the note is present.
# 6. `time_div` is the accuracy of the piano-roll and the count of divisions within a time-unit (by default this is beat for scores and seconds for performances; see: `time_unit` = "auto")
# 7. `onset_only` = True means that the duration of a note is completely neglected and only the beginning of the note is used for computing the piano-roll.
# 8. `pitch_margin` and `time_margin` are two parameters which impose some contraints about the maximum time and range used. If a time-margin is established, for example, after a certain time, the piano-roll is not computed anymore, e.g. a few bars of the piece will not be present in the piano-roll. The same holds for the time_margin.
# 9. If `remove_silence` is true, the piece will not have any pauses before the start/onset of the first note.

# %%
import partitura as pt

# %%
score_pr, score_idx = pt.utils.music.compute_pianoroll(
    note_info=score_note_array,
    piano_range=True,
    return_idxs=True,
    remove_drums=True,
    end_time=None,              # piece will not be truncated
    time_unit="auto",           # must be set to auto, since the note_array-format depends on the performance/score
                    
    # parameters to change
    # binary = False,           # ensure a binary piano roll (either the node is pressed or not)
    # time_div = 24,            # sets the time division per time-unit
    # onset_only = False,  
    # pitch_margin = 0,
    # time_margin = 0,
    # remove_silence = False
)

# %%
performance_pr, performance_idx = pt.utils.music.compute_pianoroll(
    note_info=performance_note_array,
    piano_range=True,
    return_idxs=True,
    remove_drums=True,
    end_time=None,              # piece will not be truncated
    time_unit="auto",           # must be set to auto, since the note_array-format depends on the performance/score
                    
    # parameters to change
    # binary = False,           # ensure a binary piano roll (either the node is pressed or not)
    # time_div = 24,            # sets the time division per time-unit
    # onset_only = False,  
    # pitch_margin = 0,
    # time_margin = 0,
    # remove_silence = False
)
# Out:
# C:\Users\chfei\anaconda3\envs\miws23\lib\site-packages\partitura\utils\music.py:1296: UserWarning: Do not consider drum track for computing piano roll
#   warnings.warn("Do not consider drum track for computing piano roll")

# %%
# is represented as a sparse matrix with many zeros in it
score_pr
# Out:
# <88x332 sparse matrix of type '<class 'numpy.intc'>'
# 	with 1430 stored elements in Compressed Sparse Column format>

# %%
# is represented as a sparse matrix with many zeros in it
performance_pr
# Out:
# <88x671 sparse matrix of type '<class 'numpy.intc'>'
# 	with 3634 stored elements in Compressed Sparse Column format>

# %% [markdown]
# This code-cell visualizes the computed piano-roll in `Matplotlib`.

# %%
# code is part of the "Symbolic_Music_Alignment"-file

import matplotlib.pyplot as plt

fig, axes = plt.subplots(2, figsize=(10, 7))
axes[0].imshow(
    score_pr.todense(),
    aspect = "auto",
    origin="lower",
    cmap="gray",
    interpolation="nearest",
)
axes[1].imshow(
    performance_pr.todense(),
    aspect = "auto",
    origin="lower",
    cmap="gray",
    interpolation="nearest",
)
y_label = "Piano key"
axes[0].set_ylabel(y_label)
axes[1].set_ylabel(y_label)
axes[0].set_title("Score")
axes[1].set_title("Performance")
axes[1].set_xlabel("Time")
plt.show()

# %% [markdown]
# ## Computing Alignments
#
# After having computed two representations of score and performance that match in their quality, the next step is to match the individual notes, since this is the goal of Music Alignment.
#
# This can be done in two steps without any Machine Learning Methods. The first one is to see the individual time-steps of both piano-rolls as two sequences. Mathematically, we want to match those two sequences in order to minimize a cost-function which represents the "error" of these two alignments. This can be done with Dynamic Time Warping, a dynamic programming technique, or similar algorithms, e.g. the Needleman-Wunsch Algorithm which can be modified for time warping also. Since Dynamic Time Warping minimizes the total cost-function, we have chosen also Dynamic Time Warping, which as an algorithm which takes two sequences following the same structure, which can be arbitrary. Therefore, there is only the cost-function to be chosen as a parameter, which can be any sort of distance (e.g. euclidian-distance, manhattan-distance, minkowski-distance (in the general case))
#
# see paper: Peter, S. D., Cancino-Chacón, C. E., Foscarin, F., McLeod, A. P., Henkel, F., Karystinaios, E., & Widmer, G. (2023). Automatic Note-Level Scoreto-Performance Alignments in the ASAP Dataset. Transactions of the International Society for Music Information Retrieval, 6(1), 27–42. DOI: https://doi.org/10.5334/tismir.149

# %% [markdown]
# ### Dynamic Time Warping
#
# The package `fastdtw` implements a computationally faster version of dynamic time warping (DTW) which is more efficient for longer pieces to be aligned.
#
# It takes two parameters:
# 1. `dist` represents the cost-measure of two musical entities of a the two sequences $X, Y$, we want to align, where these parameters p define the order of the corresponding minkowski-distance. If p=1, this corresponds to the manhattan-distance and if p=2, this corresponds to the euclidean-distance. $D\left(X,Y\right) = \biggl(\sum_{i=1}^n |x_i-y_i|^p\biggr)^{\frac{1}{p}}.$
# (see https://en.wikipedia.org/wiki/Minkowski_distance)
# 2. `radius` specifies how many neighbors of the sequence (how many adjacent entities) are taken into account when calculating the optimal path between the two musical sequences after determining the distance-matrix. When this value is higher, the accuracy increases, but also the computational power needs to be higher.

# %%
# transformations on the piano-roll, such that it can be used by the fastdtw() function
score_features = score_pr.toarray().T
performance_features = performance_pr.toarray().T

# %%
from fastdtw import fastdtw
import numpy as np

dtwd, warping_path = fastdtw(score_features, performance_features, dist=2, radius=2)

# Make path a numpy array
warping_path = np.array(warping_path, dtype=int)

# %%
warping_path
# Out:
# array([[  0,   0],
#        [  1,   1],
#        [  2,   2],
#        ...,
#        [331, 668],
#        [331, 669],
#        [331, 670]])

# %% [markdown]
# ### Greedy Note Alignment
#
# The matching of time-step of the piano-rolls of score and performance is only the first part of Music Alignment, because, now we matched time-slices on the piano-roll where multiple notes can occur at once.
#
# Therefore, individual notes have to be matched as well, which can be done, e.g. by using a greedy algorithm which can work with a sliding window. If you have onset notes of the score, which are started to be played on timestep t, and you want to match them with the corresponding note of the performance, you look from timestep t-k to t+k to find it, where k is the window-size. The best matching note will be taken as the correct one, why it is called greedy note alignment. This is the most straight-forward-way to implement that, but can also lead to some accuracy-issues. You can also simplify this process by taking some additional assumptions, such that a note, which is matched to another one must have the same pitch.

# %%
from typing import List

def greedy_note_alignment(
    warping_path: np.ndarray,
    idx1: np.ndarray,
    note_array1: np.ndarray,
    idx2: np.ndarray,
    note_array2: np.ndarray,
) -> List[dict]:
    """
    Greedily find and store possible note alignments

    Parameters
    ----------
    warping_path : numpy ndarray
        alignment sequence idx in stacked columns
    idx1: numpy ndarray
        pitch, start, and end coordinates of all notes in note_array1
    note_array1: numpy structured array
        note_array of sequence 1 (the score)
    idx2: numpy ndarray
        pitch, start, and end coordinates of all notes in note_array2
    note_array2: numpy structured array
        note_array of sequence 2 (the performance)

    Returns
    ----------
    note_alignment : list
        list of note alignment dictionaries

    """
    note_alignment = []
    used_notes1 = []
    used_notes2 = []

    coord_info1 = idx1
    if idx1.shape[1] == 3:
        # Assume that the first column contains the correct MIDI pitch
        coord_info1 = np.column_stack((idx1, idx1[:, 0]))

    coord_info2 = idx2

    if idx2.shape[1] == 3:
        # Assume that the first column contains the correct MIDI pitch
        coord_info2 = np.column_stack((idx2, idx2[:, 0]))

    # loop over all notes in sequence 1
    for note1, coord1 in zip(note_array1, coord_info1):
        note1_id = note1["id"]
        pc1, s1, e1, pitch1 = coord1

        # find the coordinates of the note in the warping_path

        idx_in_warping_path = np.all(
            [warping_path[:, 0] >= s1, warping_path[:, 0] <= e1], axis=0
        )
        # print(idx_in_warping_path, idx_in_warping_path.shape)
        range_in_sequence2 = warping_path[idx_in_warping_path, 1]
        max2 = np.max(range_in_sequence2)
        min2 = np.min(range_in_sequence2)

        # loop over all notes in sequence 2 and pick the notes with same pitch
        # and position
        for note2, coord2 in zip(note_array2, coord_info2):
            note2_id = note2["id"]
            pc2, s2, e2, pitch2 = coord2
            if note2_id not in used_notes2:
                if pitch2 == pitch1 and s2 <= max2 and e2 >= min2:
                    note_alignment.append(
                        {
                            "label": "match",
                            "score_id": note1_id,
                            "performance_id": str(note2_id),
                        }
                    )
                    used_notes2.append(str(note2_id))
                    used_notes1.append(note1_id)

        # check if a note has been found for the sequence 1 note,
        # otherwise add it as deletion
        if note1_id not in used_notes1:
            note_alignment.append({"label": "deletion", "score_id": note1_id})
            used_notes1.append(note1_id)

    # check again for all notes in sequence 2, if not used,
    # add them as insertions
    for note2 in note_array2:
        note2_id = note2["id"]
        if note2_id not in used_notes2:
            note_alignment.append(
                {
                    "label": "insertion",
                    "performance_id": str(note2_id),
                }
            )
            used_notes2.append(str(note2_id))

    return note_alignment

# %%
predicted_alignment = greedy_note_alignment(
                    warping_path=warping_path,
                    idx1=score_idx,
                    note_array1=score_note_array,
                    idx2=performance_idx,
                    note_array2=performance_note_array,
)

# %%
predicted_alignment
# Out:
# [{'label': 'match', 'score_id': 'n1', 'performance_id': '0'},
#  {'label': 'match', 'score_id': 'n4', 'performance_id': '1'},
#  {'label': 'match', 'score_id': 'n3', 'performance_id': '3'},
#  {'label': 'match', 'score_id': 'n2', 'performance_id': '2'},
#  {'label': 'match', 'score_id': 'n6', 'performance_id': '4'},
#  {'label': 'match', 'score_id': 'n5', 'performance_id': '5'},
#  {'label': 'match', 'score_id': 'n8', 'performance_id': '7'},
#  {'label': 'match', 'score_id': 'n7', 'performance_id': '6'},
#  {'label': 'match', 'score_id': 'n11', 'performance_id': '10'},
#  {'label': 'match', 'score_id': 'n10', 'performance_id': '9'},
#  {'label': 'match', 'score_id': 'n9', 'performance_id': '8'},
#  {'label': 'match', 'score_id': 'n15', 'performance_id': '12'},
#  {'label': 'match', 'score_id': 'n15', 'performance_id': '21'},
#  {'label': 'match', 'score_id': 'n14', 'performance_id': '14'},
#  {'label': 'match', 'score_id': 'n13', 'performance_id': '13'},
#  {'label': 'match', 'score_id': 'n13', 'performance_id': '26'},
#  {'label': 'match', 'score_id': 'n12', 'performance_id': '11'},
#  {'label': 'match', 'score_id': 'n17', 'performance_id': '15'},
#  {'label': 'match', 'score_id': 'n17', 'performance_id': '18'},
#  {'label': 'match', 'score_id': 'n16', 'performance_id': '16'},
#  {'label': 'match', 'score_id': 'n18', 'performance_id': '17'},
#  {'label': 'deletion', 'score_id': 'n20'},
#  {'label': 'match', 'score_id': 'n19', 'performance_id': '19'},
#  {'label': 'deletion', 'score_id': 'n22'},
#  {'label': 'match', 'score_id': 'n21', 'performance_id': '20'},
#  {'label': 'match', 'score_id': 'n25', 'performance_id': '24'},
#  {'label': 'match', 'score_id': 'n25', 'performance_id': '30'},
#  {'label': 'match', 'score_id': 'n24', 'performance_id': '23'},
#  {'label': 'match', 'score_id': 'n23', 'performance_id': '22'},
#  {'label': 'match', 'score_id': 'n23', 'performance_id': '25'},
#  {'label': 'match', 'score_id': 'n28', 'performance_id': '27'},
#  {'label': 'deletion', 'score_id': 'n27'},
#  {'label': 'deletion', 'score_id': 'n26'},
#  {'label': 'deletion', 'score_id': 'n31'},
#  {'label': 'match', 'score_id': 'n30', 'performance_id': '29'},
#  {'label': 'match', 'score_id': 'n29', 'performance_id': '28'},
#  {'label': 'match', 'score_id': 'n35', 'performance_id': '32'},
#  {'label': 'match', 'score_id': 'n35', 'performance_id': '40'},
#  {'label': 'match', 'score_id': 'n34', 'performance_id': '34'},
#  {'label': 'match', 'score_id': 'n33', 'performance_id': '33'},
#  {'label': 'match', 'score_id': 'n33', 'performance_id': '44'},
#  {'label': 'match', 'score_id': 'n32', 'performance_id': '31'},
#  {'label': 'match', 'score_id': 'n32', 'performance_id': '47'},
#  {'label': 'match', 'score_id': 'n37', 'performance_id': '35'},
#  {'label': 'match', 'score_id': 'n37', 'performance_id': '38'},
#  {'label': 'match', 'score_id': 'n37', 'performance_id': '43'},
#  {'label': 'match', 'score_id': 'n36', 'performance_id': '36'},
#  {'label': 'match', 'score_id': 'n36', 'performance_id': '39'},
#  {'label': 'match', 'score_id': 'n38', 'performance_id': '37'},
#  {'label': 'match', 'score_id': 'n38', 'performance_id': '41'},
#  {'label': 'deletion', 'score_id': 'n40'},
#  {'label': 'match', 'score_id': 'n39', 'performance_id': '46'},
#  {'label': 'deletion', 'score_id': 'n42'},
#  {'label': 'deletion', 'score_id': 'n41'},
#  {'label': 'match', 'score_id': 'n45', 'performance_id': '49'},
#  {'label': 'match', 'score_id': 'n44', 'performance_id': '48'},
#  {'label': 'match', 'score_id': 'n43', 'performance_id': '42'},
#  {'label': 'match', 'score_id': 'n43', 'performance_id': '45'},
#  {'label': 'deletion', 'score_id': 'n47'},
#  {'label': 'deletion', 'score_id': 'n46'},
#  {'label': 'deletion', 'score_id': 'n50'},
#  {'label': 'deletion', 'score_id': 'n49'},
#  {'label': 'deletion', 'score_id': 'n48'},
#  {'label': 'match', 'score_id': 'n53', 'performance_id': '52'},
#  {'label': 'match', 'score_id': 'n52', 'performance_id': '51'},
#  {'label': 'match', 'score_id': 'n51', 'performance_id': '50'},
#  {'label': 'match', 'score_id': 'n55', 'performance_id': '53'},
#  {'label': 'match', 'score_id': 'n55', 'performance_id': '58'},
#  {'label': 'match', 'score_id': 'n54', 'performance_id': '54'},
#  {'label': 'match', 'score_id': 'n56', 'performance_id': '55'},
#  {'label': 'deletion', 'score_id': 'n59'},
#  {'label': 'match', 'score_id': 'n58', 'performance_id': '57'},
#  {'label': 'match', 'score_id': 'n57', 'performance_id': '56'},
#  {'label': 'match', 'score_id': 'n62', 'performance_id': '60'},
#  {'label': 'match', 'score_id': 'n61', 'performance_id': '61'},
#  {'label': 'match', 'score_id': 'n60', 'performance_id': '59'},
#  {'label': 'match', 'score_id': 'n65', 'performance_id': '64'},
#  {'label': 'match', 'score_id': 'n65', 'performance_id': '69'},
#  {'label': 'match', 'score_id': 'n64', 'performance_id': '63'},
#  {'label': 'match', 'score_id': 'n63', 'performance_id': '62'},
#  {'label': 'match', 'score_id': 'n67', 'performance_id': '66'},
#  {'label': 'match', 'score_id': 'n66', 'performance_id': '65'},
#  {'label': 'deletion', 'score_id': 'n70'},
#  {'label': 'match', 'score_id': 'n69', 'performance_id': '68'},
#  {'label': 'match', 'score_id': 'n68', 'performance_id': '67'},
#  {'label': 'match', 'score_id': 'n74', 'performance_id': '71'},
#  {'label': 'match', 'score_id': 'n74', 'performance_id': '82'},
#  {'label': 'match', 'score_id': 'n73', 'performance_id': '73'},
#  {'label': 'match', 'score_id': 'n72', 'performance_id': '72'},
#  {'label': 'match', 'score_id': 'n71', 'performance_id': '70'},
#  {'label': 'match', 'score_id': 'n77', 'performance_id': '75'},
#  {'label': 'match', 'score_id': 'n77', 'performance_id': '79'},
#  {'label': 'match', 'score_id': 'n76', 'performance_id': '76'},
#  {'label': 'match', 'score_id': 'n75', 'performance_id': '74'},
#  {'label': 'match', 'score_id': 'n79', 'performance_id': '78'},
#  {'label': 'match', 'score_id': 'n78', 'performance_id': '77'},
#  {'label': 'deletion', 'score_id': 'n82'},
#  {'label': 'match', 'score_id': 'n81', 'performance_id': '81'},
#  {'label': 'match', 'score_id': 'n80', 'performance_id': '80'},
#  {'label': 'deletion', 'score_id': 'n85'},
#  {'label': 'match', 'score_id': 'n84', 'performance_id': '84'},
#  {'label': 'match', 'score_id': 'n83', 'performance_id': '83'},
#  {'label': 'match', 'score_id': 'n89', 'performance_id': '87'},
#  {'label': 'match', 'score_id': 'n89', 'performance_id': '95'},
#  {'label': 'match', 'score_id': 'n88', 'performance_id': '88'},
#  {'label': 'match', 'score_id': 'n87', 'performance_id': '86'},
#  {'label': 'match', 'score_id': 'n86', 'performance_id': '85'},
#  {'label': 'match', 'score_id': 'n86', 'performance_id': '89'},
#  {'label': 'match', 'score_id': 'n92', 'performance_id': '91'},
#  {'label': 'match', 'score_id': 'n91', 'performance_id': '90'},
#  {'label': 'deletion', 'score_id': 'n90'},
#  {'label': 'deletion', 'score_id': 'n96'},
#  {'label': 'match', 'score_id': 'n95', 'performance_id': '93'},
#  {'label': 'match', 'score_id': 'n94', 'performance_id': '94'},
#  {'label': 'match', 'score_id': 'n93', 'performance_id': '92'},
#  {'label': 'match', 'score_id': 'n99', 'performance_id': '97'},
#  {'label': 'match', 'score_id': 'n99', 'performance_id': '105'},
#  {'label': 'match', 'score_id': 'n98', 'performance_id': '98'},
#  {'label': 'match', 'score_id': 'n97', 'performance_id': '96'},
#  {'label': 'match', 'score_id': 'n101', 'performance_id': '99'},
#  {'label': 'match', 'score_id': 'n101', 'performance_id': '103'},
#  {'label': 'match', 'score_id': 'n100', 'performance_id': '100'},
#  {'label': 'match', 'score_id': 'n100', 'performance_id': '102'},
#  {'label': 'match', 'score_id': 'n102', 'performance_id': '101'},
#  {'label': 'deletion', 'score_id': 'n104'},
#  {'label': 'deletion', 'score_id': 'n103'},
#  {'label': 'deletion', 'score_id': 'n107'},
#  {'label': 'match', 'score_id': 'n106', 'performance_id': '106'},
#  {'label': 'match', 'score_id': 'n105', 'performance_id': '104'},
#  {'label': 'match', 'score_id': 'n110', 'performance_id': '108'},
#  {'label': 'match', 'score_id': 'n110', 'performance_id': '113'},
#  {'label': 'match', 'score_id': 'n109', 'performance_id': '109'},
#  {'label': 'match', 'score_id': 'n108', 'performance_id': '107'},
#  {'label': 'match', 'score_id': 'n112', 'performance_id': '111'},
#  {'label': 'match', 'score_id': 'n111', 'performance_id': '110'},
#  {'label': 'deletion', 'score_id': 'n115'},
#  {'label': 'match', 'score_id': 'n114', 'performance_id': '114'},
#  {'label': 'match', 'score_id': 'n113', 'performance_id': '112'},
#  {'label': 'match', 'score_id': 'n118', 'performance_id': '117'},
#  {'label': 'match', 'score_id': 'n118', 'performance_id': '126'},
#  {'label': 'match', 'score_id': 'n117', 'performance_id': '116'},
#  {'label': 'match', 'score_id': 'n116', 'performance_id': '115'},
#  {'label': 'match', 'score_id': 'n121', 'performance_id': '119'},
#  {'label': 'match', 'score_id': 'n121', 'performance_id': '124'},
#  {'label': 'match', 'score_id': 'n120', 'performance_id': '120'},
#  {'label': 'match', 'score_id': 'n119', 'performance_id': '118'},
#  {'label': 'match', 'score_id': 'n123', 'performance_id': '122'},
#  {'label': 'match', 'score_id': 'n122', 'performance_id': '121'},
#  {'label': 'deletion', 'score_id': 'n126'},
#  {'label': 'match', 'score_id': 'n125', 'performance_id': '125'},
#  {'label': 'match', 'score_id': 'n124', 'performance_id': '123'},
#  {'label': 'deletion', 'score_id': 'n129'},
#  {'label': 'match', 'score_id': 'n128', 'performance_id': '128'},
#  {'label': 'match', 'score_id': 'n127', 'performance_id': '127'},
#  {'label': 'match', 'score_id': 'n131', 'performance_id': '129'},
#  {'label': 'match', 'score_id': 'n131', 'performance_id': '134'},
#  {'label': 'match', 'score_id': 'n130', 'performance_id': '130'},
#  {'label': 'match', 'score_id': 'n133', 'performance_id': '132'},
#  {'label': 'match', 'score_id': 'n132', 'performance_id': '131'},
#  {'label': 'match', 'score_id': 'n132', 'performance_id': '142'},
#  {'label': 'deletion', 'score_id': 'n135'},
#  {'label': 'match', 'score_id': 'n134', 'performance_id': '133'},
#  {'label': 'match', 'score_id': 'n137', 'performance_id': '136'},
#  {'label': 'match', 'score_id': 'n136', 'performance_id': '135'},
#  {'label': 'match', 'score_id': 'n139', 'performance_id': '137'},
#  {'label': 'match', 'score_id': 'n139', 'performance_id': '143'},
#  {'label': 'match', 'score_id': 'n138', 'performance_id': '138'},
#  {'label': 'match', 'score_id': 'n138', 'performance_id': '144'},
#  {'label': 'match', 'score_id': 'n142', 'performance_id': '139'},
#  {'label': 'match', 'score_id': 'n141', 'performance_id': '141'},
#  {'label': 'match', 'score_id': 'n140', 'performance_id': '140'},
#  {'label': 'deletion', 'score_id': 'n145'},
#  {'label': 'deletion', 'score_id': 'n144'},
#  {'label': 'match', 'score_id': 'n143', 'performance_id': '152'},
#  {'label': 'match', 'score_id': 'n147', 'performance_id': '145'},
#  {'label': 'match', 'score_id': 'n146', 'performance_id': '146'},
#  {'label': 'match', 'score_id': 'n149', 'performance_id': '148'},
#  {'label': 'match', 'score_id': 'n149', 'performance_id': '154'},
#  {'label': 'match', 'score_id': 'n148', 'performance_id': '147'},
#  {'label': 'match', 'score_id': 'n148', 'performance_id': '153'},
#  {'label': 'match', 'score_id': 'n152', 'performance_id': '149'},
#  {'label': 'match', 'score_id': 'n151', 'performance_id': '151'},
#  {'label': 'match', 'score_id': 'n150', 'performance_id': '150'},
#  {'label': 'deletion', 'score_id': 'n155'},
#  {'label': 'deletion', 'score_id': 'n154'},
#  {'label': 'deletion', 'score_id': 'n153'},
#  {'label': 'match', 'score_id': 'n159', 'performance_id': '157'},
#  {'label': 'match', 'score_id': 'n158', 'performance_id': '158'},
#  {'label': 'match', 'score_id': 'n157', 'performance_id': '156'},
#  {'label': 'match', 'score_id': 'n156', 'performance_id': '155'},
#  {'label': 'match', 'score_id': 'n161', 'performance_id': '160'},
#  {'label': 'match', 'score_id': 'n161', 'performance_id': '163'},
#  {'label': 'match', 'score_id': 'n160', 'performance_id': '159'},
#  {'label': 'match', 'score_id': 'n162', 'performance_id': '161'},
#  {'label': 'deletion', 'score_id': 'n164'},
#  {'label': 'match', 'score_id': 'n163', 'performance_id': '162'},
#  {'label': 'match', 'score_id': 'n168', 'performance_id': '164'},
#  {'label': 'match', 'score_id': 'n167', 'performance_id': '166'},
#  {'label': 'match', 'score_id': 'n166', 'performance_id': '167'},
#  {'label': 'match', 'score_id': 'n166', 'performance_id': '172'},
#  {'label': 'match', 'score_id': 'n165', 'performance_id': '165'},
#  {'label': 'match', 'score_id': 'n170', 'performance_id': '168'},
#  {'label': 'match', 'score_id': 'n170', 'performance_id': '173'},
#  {'label': 'match', 'score_id': 'n169', 'performance_id': '169'},
#  {'label': 'match', 'score_id': 'n169', 'performance_id': '174'},
#  {'label': 'match', 'score_id': 'n172', 'performance_id': '171'},
#  {'label': 'match', 'score_id': 'n171', 'performance_id': '170'},
#  {'label': 'deletion', 'score_id': 'n175'},
#  {'label': 'deletion', 'score_id': 'n174'},
#  {'label': 'deletion', 'score_id': 'n173'},
#  {'label': 'match', 'score_id': 'n179', 'performance_id': '176'},
#  {'label': 'match', 'score_id': 'n179', 'performance_id': '185'},
#  {'label': 'match', 'score_id': 'n178', 'performance_id': '178'},
#  {'label': 'match', 'score_id': 'n177', 'performance_id': '177'},
#  {'label': 'match', 'score_id': 'n177', 'performance_id': '190'},
#  {'label': 'match', 'score_id': 'n176', 'performance_id': '175'},
#  {'label': 'match', 'score_id': 'n181', 'performance_id': '179'},
#  {'label': 'match', 'score_id': 'n180', 'performance_id': '180'},
#  {'label': 'match', 'score_id': 'n182', 'performance_id': '181'},
#  {'label': 'match', 'score_id': 'n184', 'performance_id': '183'},
#  {'label': 'match', 'score_id': 'n183', 'performance_id': '182'},
#  {'label': 'deletion', 'score_id': 'n186'},
#  {'label': 'match', 'score_id': 'n185', 'performance_id': '184'},
#  {'label': 'match', 'score_id': 'n189', 'performance_id': '188'},
#  {'label': 'match', 'score_id': 'n189', 'performance_id': '193'},
#  {'label': 'match', 'score_id': 'n188', 'performance_id': '187'},
#  {'label': 'match', 'score_id': 'n188', 'performance_id': '194'},
#  {'label': 'match', 'score_id': 'n187', 'performance_id': '186'},
#  {'label': 'match', 'score_id': 'n187', 'performance_id': '189'},
#  {'label': 'match', 'score_id': 'n192', 'performance_id': '191'},
#  {'label': 'deletion', 'score_id': 'n191'},
#  {'label': 'deletion', 'score_id': 'n190'},
#  {'label': 'deletion', 'score_id': 'n195'},
#  {'label': 'deletion', 'score_id': 'n194'},
#  {'label': 'match', 'score_id': 'n193', 'performance_id': '192'},
#  {'label': 'match', 'score_id': 'n199', 'performance_id': '196'},
#  {'label': 'match', 'score_id': 'n199', 'performance_id': '205'},
#  {'label': 'match', 'score_id': 'n198', 'performance_id': '198'},
#  {'label': 'match', 'score_id': 'n197', 'performance_id': '197'},
#  {'label': 'match', 'score_id': 'n197', 'performance_id': '208'},
#  {'label': 'match', 'score_id': 'n196', 'performance_id': '195'},
#  {'label': 'match', 'score_id': 'n201', 'performance_id': '199'},
#  {'label': 'match', 'score_id': 'n201', 'performance_id': '202'},
#  {'label': 'match', 'score_id': 'n201', 'performance_id': '207'},
#  {'label': 'match', 'score_id': 'n200', 'performance_id': '200'},
#  {'label': 'match', 'score_id': 'n200', 'performance_id': '203'},
#  {'label': 'match', 'score_id': 'n202', 'performance_id': '201'},
#  {'label': 'match', 'score_id': 'n202', 'performance_id': '204'},
#  {'label': 'deletion', 'score_id': 'n204'},
#  {'label': 'match', 'score_id': 'n203', 'performance_id': '210'},
#  {'label': 'deletion', 'score_id': 'n206'},
#  {'label': 'deletion', 'score_id': 'n205'},
#  {'label': 'match', 'score_id': 'n209', 'performance_id': '212'},
#  {'label': 'match', 'score_id': 'n208', 'performance_id': '213'},
#  {'label': 'match', 'score_id': 'n207', 'performance_id': '206'},
#  {'label': 'match', 'score_id': 'n207', 'performance_id': '209'},
#  {'label': 'deletion', 'score_id': 'n211'},
#  {'label': 'deletion', 'score_id': 'n210'},
#  {'label': 'deletion', 'score_id': 'n214'},
#  {'label': 'deletion', 'score_id': 'n213'},
#  {'label': 'match', 'score_id': 'n212', 'performance_id': '211'},
#  {'label': 'match', 'score_id': 'n217', 'performance_id': '215'},
#  {'label': 'match', 'score_id': 'n216', 'performance_id': '216'},
#  {'label': 'match', 'score_id': 'n215', 'performance_id': '214'},
#  {'label': 'match', 'score_id': 'n219', 'performance_id': '217'},
#  {'label': 'match', 'score_id': 'n219', 'performance_id': '221'},
#  {'label': 'match', 'score_id': 'n218', 'performance_id': '218'},
#  {'label': 'match', 'score_id': 'n220', 'performance_id': '219'},
#  {'label': 'deletion', 'score_id': 'n223'},
#  {'label': 'match', 'score_id': 'n222', 'performance_id': '222'},
#  {'label': 'match', 'score_id': 'n221', 'performance_id': '220'},
#  {'label': 'match', 'score_id': 'n226', 'performance_id': '224'},
#  {'label': 'match', 'score_id': 'n225', 'performance_id': '225'},
#  {'label': 'match', 'score_id': 'n224', 'performance_id': '223'},
#  {'label': 'match', 'score_id': 'n229', 'performance_id': '227'},
#  {'label': 'match', 'score_id': 'n229', 'performance_id': '231'},
#  {'label': 'match', 'score_id': 'n228', 'performance_id': '228'},
#  {'label': 'match', 'score_id': 'n228', 'performance_id': '232'},
#  {'label': 'match', 'score_id': 'n227', 'performance_id': '226'},
#  {'label': 'match', 'score_id': 'n231', 'performance_id': '230'},
#  {'label': 'match', 'score_id': 'n230', 'performance_id': '229'},
#  {'label': 'deletion', 'score_id': 'n234'},
#  {'label': 'match', 'score_id': 'n233', 'performance_id': '233'},
#  {'label': 'deletion', 'score_id': 'n232'},
#  {'label': 'match', 'score_id': 'n238', 'performance_id': '235'},
#  {'label': 'match', 'score_id': 'n238', 'performance_id': '247'},
#  {'label': 'match', 'score_id': 'n237', 'performance_id': '236'},
#  {'label': 'match', 'score_id': 'n236', 'performance_id': '237'},
#  {'label': 'match', 'score_id': 'n235', 'performance_id': '234'},
#  {'label': 'match', 'score_id': 'n241', 'performance_id': '239'},
#  {'label': 'match', 'score_id': 'n241', 'performance_id': '244'},
#  {'label': 'match', 'score_id': 'n240', 'performance_id': '240'},
#  {'label': 'match', 'score_id': 'n239', 'performance_id': '238'},
#  {'label': 'match', 'score_id': 'n243', 'performance_id': '242'},
#  {'label': 'match', 'score_id': 'n242', 'performance_id': '241'},
#  {'label': 'deletion', 'score_id': 'n246'},
#  {'label': 'match', 'score_id': 'n245', 'performance_id': '245'},
#  {'label': 'match', 'score_id': 'n244', 'performance_id': '243'},
#  {'label': 'deletion', 'score_id': 'n249'},
#  {'label': 'match', 'score_id': 'n248', 'performance_id': '248'},
#  {'label': 'match', 'score_id': 'n247', 'performance_id': '246'},
#  {'label': 'match', 'score_id': 'n253', 'performance_id': '250'},
#  {'label': 'match', 'score_id': 'n253', 'performance_id': '257'},
#  {'label': 'match', 'score_id': 'n252', 'performance_id': '251'},
#  {'label': 'match', 'score_id': 'n251', 'performance_id': '252'},
#  {'label': 'match', 'score_id': 'n250', 'performance_id': '249'},
#  {'label': 'match', 'score_id': 'n250', 'performance_id': '253'},
#  {'label': 'match', 'score_id': 'n256', 'performance_id': '255'},
#  {'label': 'match', 'score_id': 'n255', 'performance_id': '254'},
#  {'label': 'deletion', 'score_id': 'n254'},
#  {'label': 'deletion', 'score_id': 'n260'},
#  {'label': 'match', 'score_id': 'n259', 'performance_id': '258'},
#  {'label': 'match', 'score_id': 'n258', 'performance_id': '259'},
#  {'label': 'match', 'score_id': 'n257', 'performance_id': '256'},
#  {'label': 'match', 'score_id': 'n263', 'performance_id': '261'},
#  {'label': 'match', 'score_id': 'n263', 'performance_id': '269'},
#  {'label': 'match', 'score_id': 'n262', 'performance_id': '262'},
#  {'label': 'match', 'score_id': 'n261', 'performance_id': '260'},
#  {'label': 'match', 'score_id': 'n265', 'performance_id': '264'},
#  {'label': 'match', 'score_id': 'n265', 'performance_id': '267'},
#  {'label': 'match', 'score_id': 'n264', 'performance_id': '263'},
#  {'label': 'match', 'score_id': 'n264', 'performance_id': '266'},
#  {'label': 'match', 'score_id': 'n266', 'performance_id': '265'},
#  {'label': 'deletion', 'score_id': 'n268'},
#  {'label': 'deletion', 'score_id': 'n267'},
#  {'label': 'deletion', 'score_id': 'n272'},
#  {'label': 'match', 'score_id': 'n271', 'performance_id': '271'},
#  {'label': 'match', 'score_id': 'n270', 'performance_id': '270'},
#  {'label': 'match', 'score_id': 'n269', 'performance_id': '268'},
#  {'label': 'match', 'score_id': 'n276', 'performance_id': '273'},
#  {'label': 'match', 'score_id': 'n276', 'performance_id': '280'},
#  {'label': 'match', 'score_id': 'n275', 'performance_id': '275'},
#  {'label': 'match', 'score_id': 'n274', 'performance_id': '274'},
#  {'label': 'match', 'score_id': 'n273', 'performance_id': '272'},
#  {'label': 'match', 'score_id': 'n273', 'performance_id': '276'},
#  {'label': 'match', 'score_id': 'n279', 'performance_id': '278'},
#  {'label': 'match', 'score_id': 'n278', 'performance_id': '277'},
#  {'label': 'deletion', 'score_id': 'n277'},
#  {'label': 'deletion', 'score_id': 'n283'},
#  {'label': 'match', 'score_id': 'n282', 'performance_id': '282'},
#  {'label': 'match', 'score_id': 'n281', 'performance_id': '281'},
#  {'label': 'match', 'score_id': 'n280', 'performance_id': '279'},
#  {'label': 'match', 'score_id': 'n286', 'performance_id': '284'},
#  {'label': 'match', 'score_id': 'n285', 'performance_id': '285'},
#  {'label': 'match', 'score_id': 'n284', 'performance_id': '283'},
#  {'label': 'match', 'score_id': 'n289', 'performance_id': '286'},
#  {'label': 'match', 'score_id': 'n289', 'performance_id': '292'},
#  {'label': 'match', 'score_id': 'n288', 'performance_id': '288'},
#  {'label': 'match', 'score_id': 'n287', 'performance_id': '287'},
#  {'label': 'match', 'score_id': 'n291', 'performance_id': '290'},
#  {'label': 'match', 'score_id': 'n290', 'performance_id': '289'},
#  {'label': 'deletion', 'score_id': 'n294'},
#  {'label': 'match', 'score_id': 'n293', 'performance_id': '293'},
#  {'label': 'match', 'score_id': 'n292', 'performance_id': '291'},
#  {'label': 'match', 'score_id': 'n298', 'performance_id': '295'},
#  {'label': 'match', 'score_id': 'n297', 'performance_id': '297'},
#  {'label': 'match', 'score_id': 'n296', 'performance_id': '296'},
#  {'label': 'match', 'score_id': 'n295', 'performance_id': '294'},
#  {'label': 'match', 'score_id': 'n301', 'performance_id': '299'},
#  {'label': 'match', 'score_id': 'n301', 'performance_id': '306'},
#  {'label': 'match', 'score_id': 'n300', 'performance_id': '300'},
#  {'label': 'match', 'score_id': 'n299', 'performance_id': '298'},
#  {'label': 'match', 'score_id': 'n299', 'performance_id': '301'},
#  {'label': 'match', 'score_id': 'n304', 'performance_id': '303'},
#  {'label': 'match', 'score_id': 'n303', 'performance_id': '302'},
#  {'label': 'deletion', 'score_id': 'n302'},
#  {'label': 'deletion', 'score_id': 'n308'},
#  {'label': 'match', 'score_id': 'n307', 'performance_id': '305'},
#  {'label': 'match', 'score_id': 'n306', 'performance_id': '307'},
#  {'label': 'match', 'score_id': 'n305', 'performance_id': '304'},
#  {'label': 'match', 'score_id': 'n311', 'performance_id': '308'},
#  {'label': 'match', 'score_id': 'n311', 'performance_id': '323'},
#  {'label': 'match', 'score_id': 'n310', 'performance_id': '310'},
#  {'label': 'match', 'score_id': 'n309', 'performance_id': '309'},
#  {'label': 'match', 'score_id': 'n314', 'performance_id': '312'},
#  {'label': 'match', 'score_id': 'n314', 'performance_id': '317'},
#  {'label': 'match', 'score_id': 'n313', 'performance_id': '313'},
#  {'label': 'match', 'score_id': 'n312', 'performance_id': '311'},
#  {'label': 'match', 'score_id': 'n316', 'performance_id': '315'},
#  {'label': 'match', 'score_id': 'n315', 'performance_id': '314'},
#  {'label': 'deletion', 'score_id': 'n319'},
#  {'label': 'match', 'score_id': 'n318', 'performance_id': '318'},
#  {'label': 'match', 'score_id': 'n317', 'performance_id': '316'},
#  {'label': 'match', 'score_id': 'n326', 'performance_id': '331'},
#  {'label': 'match', 'score_id': 'n325', 'performance_id': '324'},
#  {'label': 'match', 'score_id': 'n325', 'performance_id': '330'},
#  {'label': 'match', 'score_id': 'n324', 'performance_id': '325'},
#  {'label': 'match', 'score_id': 'n324', 'performance_id': '329'},
#  {'label': 'match', 'score_id': 'n323', 'performance_id': '320'},
#  {'label': 'match', 'score_id': 'n323', 'performance_id': '327'},
#  {'label': 'match', 'score_id': 'n321', 'performance_id': '322'},
#  {'label': 'match', 'score_id': 'n322', 'performance_id': '321'},
#  {'label': 'match', 'score_id': 'n320', 'performance_id': '319'},
#  {'label': 'match', 'score_id': 'n333', 'performance_id': '336'},
#  {'label': 'match', 'score_id': 'n332', 'performance_id': '338'},
#  {'label': 'match', 'score_id': 'n331', 'performance_id': '337'},
#  {'label': 'match', 'score_id': 'n330', 'performance_id': '333'},
#  {'label': 'match', 'score_id': 'n329', 'performance_id': '328'},
#  {'label': 'match', 'score_id': 'n328', 'performance_id': '332'},
#  {'label': 'match', 'score_id': 'n328', 'performance_id': '339'},
#  {'label': 'match', 'score_id': 'n327', 'performance_id': '326'},
#  {'label': 'match', 'score_id': 'n340', 'performance_id': '342'},
#  {'label': 'match', 'score_id': 'n339', 'performance_id': '346'},
#  {'label': 'match', 'score_id': 'n338', 'performance_id': '345'},
#  {'label': 'match', 'score_id': 'n337', 'performance_id': '340'},
#  {'label': 'match', 'score_id': 'n336', 'performance_id': '335'},
#  {'label': 'match', 'score_id': 'n335', 'performance_id': '344'},
#  {'label': 'match', 'score_id': 'n334', 'performance_id': '334'},
#  {'label': 'deletion', 'score_id': 'n347'},
#  {'label': 'match', 'score_id': 'n346', 'performance_id': '353'},
#  {'label': 'match', 'score_id': 'n345', 'performance_id': '349'},
#  {'label': 'match', 'score_id': 'n344', 'performance_id': '348'},
#  {'label': 'match', 'score_id': 'n343', 'performance_id': '343'},
#  {'label': 'match', 'score_id': 'n342', 'performance_id': '351'},
#  {'label': 'match', 'score_id': 'n341', 'performance_id': '341'},
#  {'label': 'match', 'score_id': 'n354', 'performance_id': '352'},
#  {'label': 'match', 'score_id': 'n354', 'performance_id': '356'},
#  {'label': 'match', 'score_id': 'n353', 'performance_id': '357'},
#  {'label': 'deletion', 'score_id': 'n352'},
#  {'label': 'match', 'score_id': 'n351', 'performance_id': '355'},
#  {'label': 'match', 'score_id': 'n349', 'performance_id': '350'},
#  {'label': 'deletion', 'score_id': 'n350'},
#  {'label': 'match', 'score_id': 'n348', 'performance_id': '347'},
#  {'label': 'deletion', 'score_id': 'n361'},
#  {'label': 'deletion', 'score_id': 'n360'},
#  {'label': 'deletion', 'score_id': 'n359'},
#  {'label': 'deletion', 'score_id': 'n358'},
#  {'label': 'match', 'score_id': 'n357', 'performance_id': '358'},
#  {'label': 'deletion', 'score_id': 'n356'},
#  {'label': 'match', 'score_id': 'n355', 'performance_id': '354'},
#  {'label': 'match', 'score_id': 'n366', 'performance_id': '362'},
#  {'label': 'match', 'score_id': 'n366', 'performance_id': '371'},
#  {'label': 'match', 'score_id': 'n368', 'performance_id': '365'},
#  {'label': 'match', 'score_id': 'n368', 'performance_id': '372'},
#  {'label': 'match', 'score_id': 'n367', 'performance_id': '363'},
#  {'label': 'match', 'score_id': 'n367', 'performance_id': '370'},
#  {'label': 'match', 'score_id': 'n365', 'performance_id': '360'},
#  {'label': 'match', 'score_id': 'n365', 'performance_id': '366'},
#  {'label': 'match', 'score_id': 'n364', 'performance_id': '361'},
#  {'label': 'match', 'score_id': 'n363', 'performance_id': '364'},
#  {'label': 'match', 'score_id': 'n363', 'performance_id': '369'},
#  {'label': 'match', 'score_id': 'n362', 'performance_id': '359'},
#  {'label': 'deletion', 'score_id': 'n375'},
#  {'label': 'match', 'score_id': 'n374', 'performance_id': '379'},
#  {'label': 'deletion', 'score_id': 'n373'},
#  {'label': 'deletion', 'score_id': 'n372'},
#  {'label': 'match', 'score_id': 'n371', 'performance_id': '368'},
#  {'label': 'deletion', 'score_id': 'n370'},
#  {'label': 'match', 'score_id': 'n369', 'performance_id': '367'},
#  {'label': 'match', 'score_id': 'n382', 'performance_id': '376'},
#  {'label': 'deletion', 'score_id': 'n381'},
#  {'label': 'match', 'score_id': 'n380', 'performance_id': '377'},
#  {'label': 'match', 'score_id': 'n379', 'performance_id': '375'},
#  {'label': 'match', 'score_id': 'n378', 'performance_id': '374'},
#  {'label': 'match', 'score_id': 'n377', 'performance_id': '378'},
#  {'label': 'match', 'score_id': 'n376', 'performance_id': '373'},
#  {'label': 'match', 'score_id': 'n383', 'performance_id': '380'},
#  {'label': 'match', 'score_id': 'n384', 'performance_id': '381'},
#  {'label': 'match', 'score_id': 'n385', 'performance_id': '382'},
#  {'label': 'match', 'score_id': 'n385', 'performance_id': '385'},
#  {'label': 'match', 'score_id': 'n386', 'performance_id': '383'},
#  {'label': 'deletion', 'score_id': 'n388'},
#  {'label': 'match', 'score_id': 'n387', 'performance_id': '384'},
#  {'label': 'match', 'score_id': 'n390', 'performance_id': '387'},
#  {'label': 'match', 'score_id': 'n389', 'performance_id': '386'},
#  {'label': 'match', 'score_id': 'n392', 'performance_id': '389'},
#  {'label': 'match', 'score_id': 'n391', 'performance_id': '388'},
#  {'label': 'match', 'score_id': 'n395', 'performance_id': '392'},
#  {'label': 'match', 'score_id': 'n394', 'performance_id': '391'},
#  {'label': 'match', 'score_id': 'n393', 'performance_id': '390'},
#  {'label': 'match', 'score_id': 'n397', 'performance_id': '394'},
#  {'label': 'match', 'score_id': 'n396', 'performance_id': '393'},
#  {'label': 'match', 'score_id': 'n399', 'performance_id': '396'},
#  {'label': 'match', 'score_id': 'n398', 'performance_id': '395'},
#  {'label': 'match', 'score_id': 'n401', 'performance_id': '398'},
#  {'label': 'match', 'score_id': 'n400', 'performance_id': '397'},
#  {'label': 'match', 'score_id': 'n404', 'performance_id': '401'},
#  {'label': 'match', 'score_id': 'n403', 'performance_id': '400'},
#  {'label': 'match', 'score_id': 'n402', 'performance_id': '399'},
#  {'label': 'match', 'score_id': 'n407', 'performance_id': '404'},
#  {'label': 'match', 'score_id': 'n406', 'performance_id': '403'},
#  {'label': 'match', 'score_id': 'n405', 'performance_id': '402'},
#  {'label': 'match', 'score_id': 'n410', 'performance_id': '407'},
#  {'label': 'match', 'score_id': 'n410', 'performance_id': '415'},
#  {'label': 'match', 'score_id': 'n409', 'performance_id': '406'},
#  {'label': 'match', 'score_id': 'n408', 'performance_id': '405'},
#  {'label': 'match', 'score_id': 'n412', 'performance_id': '409'},
#  {'label': 'match', 'score_id': 'n411', 'performance_id': '408'},
#  {'label': 'match', 'score_id': 'n415', 'performance_id': '411'},
#  {'label': 'match', 'score_id': 'n414', 'performance_id': '412'},
#  {'label': 'match', 'score_id': 'n413', 'performance_id': '410'},
#  {'label': 'match', 'score_id': 'n417', 'performance_id': '414'},
#  {'label': 'match', 'score_id': 'n416', 'performance_id': '413'},
#  {'label': 'deletion', 'score_id': 'n419'},
#  {'label': 'match', 'score_id': 'n418', 'performance_id': '416'},
#  {'label': 'match', 'score_id': 'n421', 'performance_id': '418'},
#  {'label': 'match', 'score_id': 'n420', 'performance_id': '417'},
#  {'label': 'match', 'score_id': 'n424', 'performance_id': '420'},
#  {'label': 'match', 'score_id': 'n423', 'performance_id': '421'},
#  {'label': 'match', 'score_id': 'n422', 'performance_id': '419'},
#  {'label': 'match', 'score_id': 'n427', 'performance_id': '422'},
#  {'label': 'match', 'score_id': 'n426', 'performance_id': '424'},
#  {'label': 'match', 'score_id': 'n425', 'performance_id': '423'},
#  {'label': 'match', 'score_id': 'n430', 'performance_id': '426'},
#  {'label': 'match', 'score_id': 'n430', 'performance_id': '435'},
#  {'label': 'match', 'score_id': 'n429', 'performance_id': '427'},
#  {'label': 'match', 'score_id': 'n428', 'performance_id': '425'},
#  {'label': 'match', 'score_id': 'n432', 'performance_id': '429'},
#  {'label': 'match', 'score_id': 'n431', 'performance_id': '428'},
#  {'label': 'match', 'score_id': 'n435', 'performance_id': '431'},
#  {'label': 'match', 'score_id': 'n434', 'performance_id': '432'},
#  {'label': 'match', 'score_id': 'n433', 'performance_id': '430'},
#  {'label': 'match', 'score_id': 'n433', 'performance_id': '447'},
#  {'label': 'match', 'score_id': 'n437', 'performance_id': '433'},
#  {'label': 'match', 'score_id': 'n436', 'performance_id': '434'},
#  {'label': 'match', 'score_id': 'n439', 'performance_id': '444'},
#  {'label': 'match', 'score_id': 'n438', 'performance_id': '436'},
#  {'label': 'match', 'score_id': 'n441', 'performance_id': '437'},
#  {'label': 'match', 'score_id': 'n440', 'performance_id': '438'},
#  {'label': 'match', 'score_id': 'n443', 'performance_id': '439'},
#  {'label': 'match', 'score_id': 'n442', 'performance_id': '440'},
#  {'label': 'match', 'score_id': 'n442', 'performance_id': '443'},
#  {'label': 'deletion', 'score_id': 'n445'},
#  {'label': 'deletion', 'score_id': 'n444'},
#  {'label': 'deletion', 'score_id': 'n447'},
#  {'label': 'deletion', 'score_id': 'n446'},
#  {'label': 'match', 'score_id': 'n449', 'performance_id': '446'},
#  {'label': 'match', 'score_id': 'n448', 'performance_id': '445'},
#  {'label': 'deletion', 'score_id': 'n454'},
#  {'label': 'match', 'score_id': 'n453', 'performance_id': '449'},
#  {'label': 'match', 'score_id': 'n452', 'performance_id': '451'},
#  {'label': 'match', 'score_id': 'n451', 'performance_id': '450'},
#  {'label': 'deletion', 'score_id': 'n450'},
#  {'label': 'insertion', 'performance_id': '441'},
#  {'label': 'insertion', 'performance_id': '442'}]

# %% [markdown]
# ## Improvement Phases
#
# The stated implementation of Music-Alignment only served as a blueprint for further experiments.

# %% [markdown]
# ### Improvements Phase 1 - Hyperparameter-Search
#
# In the first initial improvement phase, a Hyperparameter-Search for the individual values which are part of the given pipeline, was conducted. As stated before, we did not change anything of the steps, because of the following reasons: The initial computation of the features of the score and the performance array is necessary, because of the structural differences between these arrays. The most natural way to represent music is used by a piano-roll, such that we did not let an uninformed neural-network do the feature-encoding.
#
# After that, an alignment algorithm needs to be chosen and since Dynamic Time Warping calculates the optimal path under certain constraints, it serves as a good option. The greedy-note alignment is not optimal, which was also the reason for another improvement phase.

# %% [markdown]
# #### Defining the Parameter Space
#
# A hyperparameter search is conducted by defining the parameters of the pipeline, we want to try out altering. In general, a hyperparameter-search is rather a try-and-error procedure with some expert knowledge we can apply to choose certain parameters with some informed knowledge. In this process, the main goal is to try out different alternatives for different parameters to check, which parameters deliver the best results evaluated by a specific metric. In our case, this is the F1-Score for the predicted musical alignment.

# %% [markdown]
# In our scenario, the parameters we have chosen are defined by the API of the `pt.utils.music.compute_pianoroll()` method, and the `fastdtw()` method, which are explained in the corresponding sections in this documentation.
#
# The first five parameters correspond to the `pt.utils.music.compute_pianoroll()`-method and the last parameter is part of the `fastdtw()`-method:
#
# 1. `binary`: represents a boolean-value. If this is true, the velocity of notes is neglected and only 0 and 1 is used for velocity when computing the piano-roll, where 0 means that the note is not present and 1 means, that the note is present.
# 2. `time_div` is the accuracy of the piano-roll and the count of divisions within a time-unit (by default this is beat for scores and seconds for performances; see: `time_unit` = "auto")
# 3. `onset_only` = True means that the duration of a note is completely neglected and only the beginning of the note is used for computing the piano-roll.
# 4. `pitch_margin` and `time_margin` are two parameters which impose some contraints about the maximum time and range used. If a time-margin is established, for example, after a certain time, the piano-roll is not computed anymore, e.g. a few bars of the piece will not be present in the piano-roll. The same holds for the time_margin. Since a restriction in the pitch and time always leads to a loss of information, these values needs to be chosen carefully or completely not considered.
# 5. If `remove_silence` is true, the piece will not have any pauses before the start/onset of the first note.
# 6. The `dist` represents the cost-measure of two musical entities of a the two sequences $X, Y$, we want to align, where these parameters p define the order of the corresponding minkowski-distance. If p=1, this corresponds to the manhattan-distance and if p=2, this corresponds to the euclidean-distance. $D\left(X,Y\right) = \biggl(\sum_{i=1}^n |x_i-y_i|^p\biggr)^{\frac{1}{p}}.$
# (see https://en.wikipedia.org/wiki/Minkowski_distance)
# 7. `radius` specifies how many neighbors of the sequence (how many adjacent entities) are taken into account when calculating the optimal path between the two musical sequences after determining the distance-matrix. When this value is higher, the accuracy increases, but also the computational power needs to be higher.

# %% [markdown]
# #### Notes on the chosen parameters
#
# Why we have chosen these parameters and not the other, is due to the fact, that the other parameters of the API of the `pt.utils.music.compute_pianoroll()` offer only settings, which are already fixed regarding our specific Music Alignment Task.
#
# 1. `note_info` is a parameter which specifies the note-array that should be converted into the piano-roll. This cannot be changed, since this is input-feature-matrix.
# 2. `return_idx` returns an additional array containing the coordinates of each note in the computed piano-roll if this value is set to True. This additional array is not needed for the music-alignment-computation.
# 3. `piano_range` defines whether the given data is in the MIDI-range of an 88-key-piano. Since this is true, this boolean-value is also fixed to True.
# 4. `time_unit` specifies the time-unit which is used in the given note-array to compute the piano-roll from. This can be done automatically by setting this value to `auto`, which simplifies this process, because score-note array and performance-note array are using different values.
# 5. `end_time` is set to None, since we do not want to restrict the piano-roll in length and introduce some precision-error.
# 6. `remove_drums` is set to True, since we do not use any drums in our alignments.
#
# Everything other parameter is at least tried out for the hyperparameter-tuning. Note that `time_margin` and `pitch_margin` could also introduce some precision-errors, but in the tuning-process these parameters can take the value 0 or -1 which means, that this has no effect in these parameter-configurations.
#
# The `fast_dtw()`-method only allows to specify the `distance`-measure and the `radius`.

# %% [markdown]
# #### Implemention of the parameter-space
#
# In the following way, a parameter-space can be defined as a dictionary. The keys represent the parameters, we want to try out and the values corresponds to list of values, which we want to test. Then this dictionary is converted automatically into a list of tuples with the `itertools`-package of python. Each tuple represents one value-combination, we want to try.
#
# The only thing one need to keep in mind is, that the algorithm needs to try out each combination of these parameters, why we need to be careful, not choosing too much values, due to the combinatorial explosion issue.

# %%
param_space = {
                "is_binary": [False, True],    
               "time_div": [24, 48, 96],
               "onset_only": [False, True],
               "pitch_margin": [-1, 0, 5],
               "time_margin": [0, 5],
               "remove_silence": [False],
               "distance": [1, 2, 3],
                "radius": [1, 2, 3]
               }

import itertools as it

combinations_param = it.product(*(param_space[item] for item in param_space))
combination_list = list(combinations_param)

# %% [markdown]
# Here, you can see, that even if each parameter on its own has few values on each own, the number of combination is quite huge:

# %%
len(combination_list)
# Out:
# 648

# %% [markdown]
# This is the beginning of the list, representing the first 10 tuples.

# %%
combination_list[0:10]
# Out:
# [(False, 24, False, -1, 0, False, 1, 1),
#  (False, 24, False, -1, 0, False, 1, 2),
#  (False, 24, False, -1, 0, False, 1, 3),
#  (False, 24, False, -1, 0, False, 2, 1),
#  (False, 24, False, -1, 0, False, 2, 2),
#  (False, 24, False, -1, 0, False, 2, 3),
#  (False, 24, False, -1, 0, False, 3, 1),
#  (False, 24, False, -1, 0, False, 3, 2),
#  (False, 24, False, -1, 0, False, 3, 3),
#  (False, 24, False, -1, 5, False, 1, 1)]

# %% [markdown]
# #### Defining a pipeline for hyperparameter-tuning
#
# Before being able to tune hyperparameters, we need to specify a pipeline-function, which takes as an input the different hyperparameter-configurations and the dataset. This function applies all the necessary steps for musical alignment with all the configurations provided. After that some metrics will evaluate how good this parameter-configuration was on the given data with the provided pipeline. In our case this is the F1-Score, the Precision-Score and the Recall-Score which compares the ground-truth alignment and the predicted alignment. For calculating the scores, the function `compare_alignments()` of the `challenge_utils`-package is provided.
#
# Additionally, we do not want to apply the hyperparameter-tuning only on one musical-piece of the dataset, but on multiple ones to avoid bias when evaluating the parameter-configuration. But our computational power is not big enough to handle the complete training-dataset for all the configurations possible. Therefore, not only the complete dataset is provided in dictionary `dataset`, but also a `performance_string_list`. This list contains the keys for the dictionary `dataset` of the performances we want to put into the pipeline with the given parameter-configuration.
#
# In principle, in the `music_alignment_pipeline()`-function there are two nested loops implemented. One looping over the parameter-configuration. For each parameter-configuration we also need to put all the different performances of `performance_string_list` into the pipeline, such that another for-loop has to be introduced.
#
# The return value of this function is a dictionary containing all the three metrics. As a key, you can input the tuple which represents the parameter-configuration, and the value is a list. This list contains tuples as entries, where the first element is the string of the name of the musical performance which is evaluated with the current parameter-configuration and the second element is another tuple containing the three different metrics.
#
# After putting through every musical performance into the pipeline with one parameter-configuration, an average (arithmetic mean) of these values will be calculated. This is also stored in the dictionary as the last entry of the list.
#
# During training, the F1-Scores will be printed to immediately see the evaluation for the different hyperparameter-configurations on the different pieces.
#
# An important note is, that the combination-tuples in the `combinations`-list must correspond to the following format (specified in the section before):
# (`is_binary`, `time_div`, `onset_only`, `pitch_margin`, `time_margin`, `remove_silence`, `distance`, `radius`)

# %%
# imports the function which is providing the evaluation of the generated musical alignment with the ground-truth-alignment
from challenge_utils import compare_alignments

# %%
def music_alignment_pipeline(dataset: dict, performance_string_list: list, combinations: list) -> dict:
    """
    Parameters
    ----------
    dataset is a dictionary that contains the data of all the scores and the corresponding performances, as well as the ground-truth alignment. the key corresponds to a string identifying the musical piece
    performance_string_list is a list of strings which corresponds to some of the keys of the dataset dictionary representing performances. these performances will be used to evaluate when putting them into the pipeline
    combinations is a list with tuples representing the different hyperparameter-configurations: these tuples must correspond to the specification of the parameter-space in the section before

    Returns
    -------
    dict: evaluations of the different hyperparameter-configurations
    """
    
    
    # dictionary "scores" stores results
    # key: (item_1, item_2, ..., item_n) 
    # value: [(<Name of Piece 1>, ((<F1-Score>), (<Precision-Score>), (<Recall-Score>))), 
    #         (<Name of Piece 2>, ((<F1-Score>), (<Precision-Score>), (<Recall-Score>)))
    #         (<Name of Piece 3>, ((<F1-Score>), (<Precision-Score>), (<Recall-Score>)))
    #          ...
    #         (<Name of Piece n>, ((<F1-Score>), (<Precision-Score>), (<Recall-Score>)))
    #         ("Average", ((<F1-Score Avg.>), (<Precision-Score Avg.>), (<Recall-Score Avg.>)))]
    scores = {}
    
    # stores the best f1-score average
    best_f1_score_avg = 0
    # and the best hyperparameter-configuration so far
    best_item_avg = None
    
    # goes through every hyperparameter-combination
    for item in combinations:
        print("##############################")
        print(f"Start of processing hyperparameter-configuration {item}... \n\n")
        scores[item] = []
        
        # goes through every piece in "performance_string_list"
        for performance in performance_string_list:
            
            # extraction of the score-note-array, performance-note-array and ground-truth-alignment
            score_note_array, performance_note_array, gt_alignment = dataset[performance][1], dataset[performance][0], dataset[performance][2]
            
            # extraction of the arguments of the current combination
            is_binary = item[0]
            time_div = item[1]
            onset_only = item[2]
            pitch_margin = item[3]
            time_margin = item[4]
            remove_silence = item[5]
            distance = item[6]
            radius = item[7]
            
            #### START OF MUSIC ALIGNMENT PIPELINE ####
            
            ### calculation of piano-roll-features ###
            score_features, score_idx = pt.utils.music.compute_pianoroll(
                # fixed parameters
                note_info=score_note_array,
                return_idxs=True,
                piano_range=True, 
                time_unit="auto",
                end_time=None,             
                remove_drums=True,
                
                # parameters to change
                binary = is_binary,        
                time_div = time_div,  
                onset_only = onset_only,  
                pitch_margin = pitch_margin,
                time_margin = time_margin,
                remove_silence=remove_silence
            )
            score_features = score_features.toarray().T
                
            performance_features, performance_idx = pt.utils.music.compute_pianoroll(
                # fixed parameters
                note_info=performance_note_array,
                return_idxs=True,
                piano_range=True,
                time_unit="auto",
                end_time=None,
                remove_drums=True,
                    
                # parameters to change
                binary = is_binary,
                time_div=time_div,
                onset_only=onset_only,
                pitch_margin = pitch_margin,
                time_margin = time_margin,
                remove_silence = remove_silence
            )
            performance_features = performance_features.toarray().T
            
            ### calculation of the sequence alignment ###
            dtwd, warping_path = fastdtw(score_features, performance_features, 
                                         dist=distance, radius=radius) # parameters to change
            warping_path = np.array(warping_path, dtype=int)
            
            ### calculation of the greedy note alignment ###
            predicted_alignment = greedy_note_alignment(
                    warping_path=warping_path,
                    idx1=score_idx,
                    note_array1=score_note_array,
                    idx2=performance_idx,
                    note_array2=performance_note_array,
            )
            
            #### END OF MUSIC ALIGNMENT PIPELINE ####
            
            # returns a tuple with 3 metrics (F1-Score, Precision-Score, Recall-Score)
            # for the current score with the current hyperparameter configuration
            piece_eval = compare_alignments(
                prediction=predicted_alignment,
                ground_truth=gt_alignment,
            )
            
            # prints the f1-score with the current hyperparameter-combination for the current piece
            print(f"F1-Score for {item} in {performance}:")
            print(piece_eval[0], "\n")
           
            scores[item].append((performance, piece_eval))
        
        
        ### Averaging Scores for the current hyperparameter configuration ###
        
        avg_f1_score = 0
        avg_precision_score = 0
        avg_recall_score = 0
        
        temp_scores = scores[item]
        for t in temp_scores:
            # score_str = t[0]
            score_eval = t[1]
            
            avg_f1_score += score_eval[0]
            avg_precision_score += score_eval[1]
            avg_recall_score += score_eval[2]
        
        avg_f1_score = avg_f1_score / len(temp_scores)
        avg_precision_score = avg_precision_score / len(temp_scores)
        avg_recall_score = avg_recall_score / len(temp_scores)
        
        avg_score_tuple = (avg_f1_score, avg_precision_score, avg_recall_score)
        scores[item].append(("Average", avg_score_tuple))
        
        ### Averaging Scores for the current hyperparameter configuration ###
        
        
        # prints the average f1-score with the current hyperparameter-combination
        print(f"Average-F1-Score for {item}: {avg_f1_score} \n\n")
        
        print(f"End of processing hyperparameter-configuration {item}...")
        print("############################## \n\n")
        
        # stores the current average f1-score of the current hyperparameter-configuration
        # if it is better than the best one so far
        if avg_f1_score > best_f1_score_avg:
            best_f1_score_avg = avg_f1_score
            best_item_avg = item
        
    # prints the best results after the hyperparameter search
    print(f"Best Average-F1-Score: {best_f1_score_avg} \n")
    print(f"Best Combination: {best_item_avg} \n")
        
    return scores

# %%
pieces =  [ "Chopin_op10_no3_p02", "Chopin_op10_no3_p13", 
            "Chopin_op38_p05", "Chopin_op38_p19",
            "Mozart_K331_1st-mov_p08", "Mozart_K331_1st-mov_p22",
            "Schubert_D783_no15_p11", "Schubert_D783_no15_p20" ]

# %%
results = music_alignment_pipeline(dataset, pieces, combination_list)
# Out:
# ##############################
# Start of processing hyperparameter-configuration (False, 24, False, -1, 0, False, 1, 1)...
# C:\Users\chfei\anaconda3\envs\miws23\lib\site-packages\partitura\utils\music.py:1296: UserWarning: Do not consider drum track for computing piano roll
#   warnings.warn("Do not consider drum track for computing piano roll")
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Chopin_op10_no3_p02:
# 0.791497975708502
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Chopin_op10_no3_p13:
# 0.797979797979798
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Chopin_op38_p05:
# 0.015455950540958269
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Chopin_op38_p19:
# 0.014637904468412942
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Mozart_K331_1st-mov_p08:
# 0.010588235294117647
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Mozart_K331_1st-mov_p22:
# 0.016646848989298454
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Schubert_D783_no15_p11:
# 0.03852889667250438
# F1-Score for (False, 24, False, -1, 0, False, 1, 1) in Schubert_D783_no15_p20:
# 0.05123674911660778
#
# Average-F1-Score for (False, 24, False, -1, 0, False, 1, 1): 0.2170715448462749
#
#
# End of processing hyperparameter-configuration (False, 24, False, -1, 0, False, 1, 1)...
# ##############################
#
#
# ##############################
# Start of processing hyperparameter-configuration (False, 24, False, -1, 0, False, 1, 2)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 results = music_alignment_pipeline(dataset, pieces, combination_list)
#
# Cell In[25], line 99, in music_alignment_pipeline(dataset, performance_string_list, combinations)
#      96 warping_path = np.array(warping_path, dtype=int)
#      98 ### calculation of the greedy note alignment ###
# ---> 99 predicted_alignment = greedy_note_alignment(
#     100         warping_path=warping_path,
#     101         idx1=score_idx,
#     102         note_array1=score_note_array,
#     103         idx2=performance_idx,
#     104         note_array2=performance_note_array,
#     105 )
#     107 #### END OF MUSIC ALIGNMENT PIPELINE ####
#     108
#     109 # returns a tuple with 3 metrics (F1-Score, Precision-Score, Recall-Score)
#     110 # for the current score with the current hyperparameter configuration
#     111 piece_eval = compare_alignments(
#     112     prediction=predicted_alignment,
#     113     ground_truth=gt_alignment,
#     114 )
#
# Cell In[18], line 54, in greedy_note_alignment(warping_path, idx1, note_array1, idx2, note_array2)
#      50 pc1, s1, e1, pitch1 = coord1
#      52 # find the coordinates of the note in the warping_path
# ---> 54 idx_in_warping_path = np.all(
#      55     [warping_path[:, 0] >= s1, warping_path[:, 0] <= e1], axis=0
#      56 )
#      57 # print(idx_in_warping_path, idx_in_warping_path.shape)
#      58 range_in_sequence2 = warping_path[idx_in_warping_path, 1]
#
# File ~\anaconda3\envs\miws23\lib\site-packages\numpy\core\fromnumeric.py:2504, in all(a, axis, out, keepdims, where)
#    2421 @array_function_dispatch(_all_dispatcher)
#    2422 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2423     """
#    2424     Test whether all array elements along a given axis evaluate to True.
#    2425
#    (...)
#    2502
#    2503     """
# -> 2504     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2505                           keepdims=keepdims, where=where)
#
# File ~\anaconda3\envs\miws23\lib\site-packages\numpy\core\fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# #### Observations with Hyperparameter Tuning
#
# As you can see in the printed results, the scores for the Chopin-Piece op10 no3 were quite good, but unfortunately the performance dropped quite significantly for the other pieces. Therefore, we had to come up with a different approach...

# %% [markdown]
# ### Improvements Phase 2 - Research
#
# After checking, if the baseline could give already decent results, we took some research in the field of Music Alignment and stumbled across different papers.
#
# #### Implementation of Nakamura, E., Yoshii
#
# One of them was written by Nakamura, E., Yoshii et al., where Music Alignment is essentially performed in three different steps. One of them is the pre-processing-phase, where it is tried to correct player-mistakes. Sometimes player-mistakes in the beginning of a piece can lead to mis-alignments of the notes afterward, since this can cause continuing errors. This might also be the reason, why the base-line-method did not work out as good as we have thought. Only after that, the alignment is done and in the end, some post-processing is applied to correct the alignment. The main ingredient of this approach are hidden-markov-models.
#
# The approach of this paper was the best one regarding music alignments a long time and there is a version implemented C++ online at the following link: https://midialignment.github.io/demo.html.
#
# But then we have found another paper by the Institute of Computational Perception at the Johannes Kepler University in Austria, Linz.
#
# see paper: Nakamura, E., Yoshii, K., and Katayose, H. (2017). Performance error detection and post-processing for fast and accurate symbolic music alignment. In Proceedings of the International Society for Music Information Retrieval Conference (ISMIR), pages 347–353, Suzhou, China., https://eita-nakamura.github.io/articles/EN_etal_ErrorDetectionAndRealignment_ISMIR2017.pdf
#
#
# #### Implementation of Automatic-Note-Level Alignment (Institute of Computational Perception)
#
# In this paper, the authors proposed different techniques for musical alignment which are built upon the Dynamic Time Warping of the baseline, but also different variations of them. E.g. you could also use the Needleman-Wunsch-Algorithm, which is known in the field of bioinformatics, where you want to align DNA-sequences. This can be adapted to the field of music with some adaptations regarding this field, which is called Needleman-Wunsch-Time-Warping. The main goal of this paper was to establish algorithms which could align the so-called ASAP-Dataset (https://github.com/fosfrancesco/asap-dataset), which is one of the biggest dataset containing different musical performances of a few musical pieces with musical alignments, but the individual notes are not aligned. This paper also extended this dataset to the (n)ASAP-dataset with some additional note-alignments: https://github.com/CPJKU/asap-dataset
#
# There is also a reference to this link included: https://github.com/sildater/parangonar. It is a library called `Parangonar`, which provides various functions for Music-Alignment: One of them is the `AutomaticNoteMatcher()` which can provide musical note-alignments without additional musical annotations. In principle, the task of musical-alignment can be simplified, if there are additional information provided of the score and the performance. E.g. beat tapping, a task where people listen to music and tap according to the beat, can help, if you record this data and use it as an additional source for the musical alignment. The special thing of this library is that there are different algorithms implemented with different use-cases, e.g. there is a dedicated, specialized algorithm for alignment, if such information is available or not.
#
# If you have grace-notes (notes which are played quickly before another note) separately stored, then `DualDTWNoteMatcher()` is the best option. The `AnchorPointNoteMatcher()` is used, if there is additional information about anchor points. Anchor Points are time-stamp-windows in the piece, in which the note-alignment should be performed, following the assumption, that it is very likely, that notes which are potential candidates to be matched, are played not too far apart. If anchor-points are introduced, alignment-errors will not be propagated outside of these anchors.
#
# Even some online-note-matching-algorithms are provided as part of `OnlineTransformerMatcher()` and `OnlinePureTransformerMatcher()`, which are not needed for our task now.
#
# see paper: Peter, S. D., Cancino-Chacón, C. E., Foscarin, F., McLeod, A. P., Henkel, F., Karystinaios, E., & Widmer, G. (2023). Automatic Note-Level Scoreto-Performance Alignments in the ASAP Dataset. Transactions of the International Society for Music Information Retrieval, 6(1), 27–42. DOI: https://doi.org/10.5334/tismir.149

# %% [markdown]
# #### Automatic Note Matcher
#
# The `AutomaticNoteMatcher()` of the `Parangonar`-Package can be called without any parameters, and delivers very good results out of the box with the default-settings. We tried it on Performance 11 on the Schubert D783 No15 Piece (Schubert_D783_no15_p11), where the results were not very good with the baseline-algorithm.

# %%
# extraction of the performance note array
pna_schubert_D783_no15_p11 = dataset["Schubert_D783_no15_p11"][0]

# extraction of the score note array
sna_schubert_D783_no15_p11 = dataset["Schubert_D783_no15_p11"][1]

# extraction of the ground truth alignment
gt_align_schubert_D783_no15_p11 = dataset["Schubert_D783_no15_p11"][2]

# %% [markdown]
# At first, the `parangonar`-package has to be imported and an object of the `AutomaticNoteMatcher` class has to be initialized. Possible parameters can be set when creating this object.

# %%
import parangonar as pa

# %%
anm = pa.AutomaticNoteMatcher()

# %%
# if verbose_time is set to True, the method prints out additional time information into the console
pred_alignment_schubert_D783_no15_p11 = anm(sna_schubert_D783_no15_p11, pna_schubert_D783_no15_p11, verbose_time=True)
# Out:
# 1.222 sec : Initial coarse DTW pass
# 0.001 sec : Cutting
# 0.689 sec : Fine-grained DTW passes, symbolic matching
# 0.014 sec : Mending

# %% [markdown]
# There is also another function of the `Parangonar`-package, which is called `fscore_alignments()`. This takes a predicted alignment, and the ground-truth and compares them. There is also a third parameter for specifying the alignment-type, which checks the alignment only regarding different aspects, namely `match`, `insertion` and `deletion`. If this parameter is specified, then only matching-notes, insertion-notes and/or deletion-notes will be compared regarding f1-score.
#
# This code is provided by the Parangonar-GitHub-Repository at https://github.com/sildater/parangonar.

# %%
types = ['match','insertion', 'deletion']
for alignment_type in types:
    precision, recall, f_score = pa.fscore_alignments(pred_alignment_schubert_D783_no15_p11, gt_align_schubert_D783_no15_p11, alignment_type)
    
    print('Evaluate ',alignment_type)
    print('Precision: ',format(precision, '.3f'),
          'Recall ',format(recall, '.3f'),
          'F-Score ',format(f_score, '.3f'))
    
    print('------------------')
# Out:
# Evaluate  match
# Precision:  0.966 Recall  0.969 F-Score  0.967
# ------------------
# Evaluate  insertion
# Precision:  0.250 Recall  0.222 F-Score  0.235
# ------------------
# Evaluate  deletion
# Precision:  0.778 Recall  0.700 F-Score  0.737
# ------------------

# %% [markdown]
# #### Observations
#
# As you can see, the results above are very good and can be seen in comparison with other Music-Alignment-Methods. Therefore, we played around with the interface of the `AutomaticNoteMatcher`-constructor and tried out different parameters.
#
# Basically the `AutomaticNoteMatcher` is only an alias for the `PianoRollNoNodeMatcher`-class, when examining the source-code.

# %% [markdown]
# The `inspect`-package of python allows to print out the source-code of the individual classes.

# %%
import inspect
print(inspect.getsource(pa.AutomaticNoteMatcher))
# Out:
# class PianoRollNoNodeMatcher(object):
#     def __init__(self,
#                  note_matcher=DTW,
#                  matcher_kwargs=dict(metric="euclidean"),#"cosine"),
#                  node_cutter=cut_note_arrays,
#                  node_mender=mend_note_alignments,
#                  symbolic_note_matcher=SequenceAugmentedGreedyMatcher(),
#                  greedy_symbolic_note_matcher=SimplestGreedyMatcher(),
#                  alignment_type="dtw",
#                  SCORE_FINE_NODE_LENGTH=0.25,
#                  s_time_div=16,
#                  p_time_div=16,
#                  sfuzziness=4.0,#0.5,
#                  pfuzziness=4.0,#0.5,
#                  window_size=1,
#                  pfuzziness_relative_to_tempo=True,
#                  shift_onsets=False,
#                  cap_combinations=100):
#
#         self.note_matcher = note_matcher(**matcher_kwargs)
#         self.symbolic_note_matcher = symbolic_note_matcher
#         self.node_cutter = node_cutter
#         self.node_mender = node_mender
#         self.greedy_symbolic_note_matcher = greedy_symbolic_note_matcher
#         self.alignment_type = alignment_type
#         self.SCORE_FINE_NODE_LENGTH = SCORE_FINE_NODE_LENGTH
#         self.s_time_div = s_time_div
#         self.p_time_div = p_time_div
#         self.sfuzziness = sfuzziness
#         self.pfuzziness = pfuzziness
#         self.window_size = window_size
#         self.pfuzziness_relative_to_tempo = pfuzziness_relative_to_tempo
#         self.shift_onsets = shift_onsets
#         self.cap_combinations = cap_combinations
#
#     def __call__(self, score_note_array,
#                  performance_note_array,
#                  verbose_time=False):
#
#         t1 = time.time()
#         # start with DTW
#         dtw_alignment_times_init = alignment_times_from_dtw(
#                             score_note_array,
#                             performance_note_array,
#                             matcher=self.note_matcher,
#                             SCORE_FINE_NODE_LENGTH=4.0,
#                             s_time_div=self.s_time_div,
#                             p_time_div=self.p_time_div
#                             )
#         # cut arrays to windows
#         t11 = time.time()
#         if verbose_time:
#             print(format(t11-t1, ".3f"), "sec : Initial coarse DTW pass")
#         score_note_arrays, performance_note_arrays = self.node_cutter(
#             performance_note_array,
#             score_note_array,
#             np.array(dtw_alignment_times_init),
#             sfuzziness=self.sfuzziness,
#             pfuzziness=self.pfuzziness,
#             window_size=self.window_size,
#             pfuzziness_relative_to_tempo=self.pfuzziness_relative_to_tempo)
#
#         # compute windowed alignments
#         note_alignments = []
#         dtw_al = []
#
#         t2 = time.time()
#         if verbose_time:
#             print(format(t2-t11, ".3f"), "sec : Cutting")
#
#         for window_id in range(len(score_note_arrays)):
#             if self.alignment_type == "greedy":
#                 alignment = self.greedy_symbolic_note_matcher(
#                     score_note_arrays[window_id],
#                     performance_note_arrays[window_id])
#                 note_alignments.append(alignment)
#             else:
#                 # _____________ fine alignment ____________
#                 if self.alignment_type == "dtw":
#                     if score_note_arrays[window_id].shape[0] == 0 or \
#                         performance_note_arrays[window_id].shape[0] == 0:
#                         # for empty arrays fall back to linear
#                         dtw_alignment_times = np.array(dtw_alignment_times_init)[
#                                 window_id:window_id+2, :]
#
#                     else:
#                         dtw_alignment_times = alignment_times_from_dtw(
#                             score_note_arrays[window_id],
#                             performance_note_arrays[window_id],
#                             matcher=self.note_matcher,
#                             SCORE_FINE_NODE_LENGTH=self.SCORE_FINE_NODE_LENGTH,
#                             s_time_div=self.s_time_div,
#                             p_time_div=self.p_time_div)
#                 else:
#                     dtw_alignment_times = np.array(dtw_alignment_times_init)[
#                         window_id:window_id+2, :]
#
#                 dtw_al.append(dtw_alignment_times)
#
#                 # distance augmented greedy align
#                 fine_local_alignment = self.symbolic_note_matcher(
#                     score_note_arrays[window_id],
#                     performance_note_arrays[window_id],
#                     dtw_alignment_times,
#                     shift=self.shift_onsets,
#                     cap_combinations=self.cap_combinations)
#
#                 note_alignments.append(fine_local_alignment)
#         t41 = time.time()
#         if verbose_time:
#             print(format(t41-t2, ".3f"), "sec : Fine-grained DTW passes, symbolic matching")
#
#
#         # MEND windows to global alignment
#         global_alignment, score_alignment, \
#             performance_alignment = self.node_mender(note_alignments,
#                                                     performance_note_array,
#                                                     score_note_array,
#                                                     node_times=np.array(dtw_alignment_times_init),
#                                                     symbolic_note_matcher= self.symbolic_note_matcher,
#                                                     max_traversal_depth=150)
#         t5 = time.time()
#         if verbose_time:
#             print(format(t5-t41, ".3f"), "sec : Mending")
#
#         return global_alignment

# %%
sdm = pa.AutomaticNoteMatcher(s_time_div=32, p_time_div=32, window_size=2)

# %%
pred_alignment_schubert_D783_no15_p11_2 = sdm(sna_schubert_D783_no15_p11, pna_schubert_D783_no15_p11, verbose_time=True)
# Out:
# 5.443 sec : Initial coarse DTW pass
# 0.001 sec : Cutting
# high number of combinations:  210.0 low number sampled  100
# high number of combinations:  220.0 low number sampled  100
# high number of combinations:  210.0 low number sampled  100
# 3.492 sec : Fine-grained DTW passes, symbolic matching
# 0.013 sec : Mending

# %%
types = ['match','insertion', 'deletion']
for alignment_type in types:
    precision, recall, f_score = pa.fscore_alignments(pred_alignment_schubert_D783_no15_p11_2, gt_align_schubert_D783_no15_p11, alignment_type)
    
    print('Evaluate ',alignment_type)
    print('Precision: ',format(precision, '.3f'),
          'Recall ',format(recall, '.3f'),
          'F-Score ',format(f_score, '.3f'))
    
    print('------------------')
# Out:
# Evaluate  match
# Precision:  0.984 Recall  0.987 F-Score  0.986
# ------------------
# Evaluate  insertion
# Precision:  1.000 Recall  0.889 F-Score  0.941
# ------------------
# Evaluate  deletion
# Precision:  0.778 Recall  0.700 F-Score  0.737
# ------------------

# %% [markdown]
# ## Evaluation of the Test-Set
#
# In the end after determining the best model in the sections prior, we can use it on the test-dataset. The test-dataset provides a score and a performance, but no ground-truth-alignment is given.
#
# At first, we need to load the test-dataset in the same way as the trainings-dataset:

# %%
dataset_test = cu.load_dataset("testset")

# %% [markdown]
# After that, we can run through every piece and predict the musical alignment. The alignments will be stored in a list `alignments`.

# %%
alignments = []
piece_names = []

for piece_idx, piece_name in enumerate(dataset_test):
    print(f"Processing Piece {piece_idx+1}/{len(dataset_test)}: {piece_name}")
    
    performance_note_array, score_note_array, gt_alignment = (
        dataset_test[piece_name][0], 
        dataset_test[piece_name][1], 
        dataset_test[piece_name][2]
    )
    
    anm_test = pa.AutomaticNoteMatcher(s_time_div=32, p_time_div=32, window_size=2)
    pred_alignment = anm_test(score_note_array, performance_note_array)
    
    alignments.append(pred_alignment)
    piece_names.append(piece_name)
    
    # additional whitespaces for the console-log
    print("\n\n")
# Out:
# Processing Piece 1/39: mozart_batik_kv279_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 14
#       7 performance_note_array, score_note_array, gt_alignment = (
#       8     dataset_test[piece_name][0],
#       9     dataset_test[piece_name][1],
#      10     dataset_test[piece_name][2]
#      11 )
#      13 anm_test = pa.AutomaticNoteMatcher(s_time_div=32, p_time_div=32, window_size=2)
# ---> 14 pred_alignment = anm_test(score_note_array, performance_note_array)
#      16 alignments.append(pred_alignment)
#      17 piece_names.append(piece_name)
#
# File ~\anaconda3\envs\miws23\lib\site-packages\parangonar\match\matchers.py:1414, in PianoRollNoNodeMatcher.__call__(self, score_note_array, performance_note_array, verbose_time)
#    1412 t1 = time.time()
#    1413 # start with DTW
# -> 1414 dtw_alignment_times_init = alignment_times_from_dtw(
#    1415                     score_note_array,
#    1416                     performance_note_array,
#    1417                     matcher=self.note_matcher,
#    1418                     SCORE_FINE_NODE_LENGTH=4.0,
#    1419                     s_time_div=self.s_time_div,
#    1420                     p_time_div=self.p_time_div
#    1421                     )
#    1422 # cut arrays to windows
#    1423 t11 = time.time()
#
# File ~\anaconda3\envs\miws23\lib\site-packages\parangonar\match\preprocessors.py:54, in alignment_times_from_dtw(score_note_array, performance_note_array, matcher, SCORE_FINE_NODE_LENGTH, s_time_div, p_time_div)
#      52 p_pianoroll_ones[p_pianoroll > 0.0] = 1.0
#      53 # align the piano rolls
# ---> 54 _, path = matcher(s_pianoroll.T, p_pianoroll_ones.T)
#      55 # compute an alignment of times using the DTW path
#      56 path_array = np.array(path)
#
# File ~\anaconda3\envs\miws23\lib\site-packages\parangonar\match\dtw.py:53, in DynamicTimeWarping.__call__(self, X, Y, return_path, return_cost_matrix)
#      51     D = cdist_local(X, Y, self.metric)
#      52 else:
# ---> 53     D = cdist(X, Y, self.metric)
#      54 # Compute accumulated cost matrix
#      55 dtwd_matrix = dtw_dmatrix_from_pairwise_dmatrix(D)
#
# File ~\anaconda3\envs\miws23\lib\site-packages\scipy\spatial\distance.py:3006, in cdist(XA, XB, metric, out, **kwargs)
#    3004     cdist_fn = metric_info.cdist_func
#    3005     _extra_windows_error_checks(XA, out, (mA, mB), **kwargs)
# -> 3006     return cdist_fn(XA, XB, out=out, **kwargs)
#    3007 elif mstr.startswith("test_"):
#    3008     metric_info = _TEST_METRICS.get(mstr, None)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Export for the challenge
#
# Now, we can export the alignments for the challenge by using the package `challenge_utils`. In essence, there will be a `.npz`-file generated, which is a compressed numpy file with the alignments in it.

# %%
from challenge_utils import export_to_challenge
import os

# name of the challenge-file
outfile = os.path.join(f"export_challenge.npz")

export_to_challenge (
    alignments=alignments,
    piece_names=piece_names,
    out=outfile
)
